# %%
import pandas as pd
ppt_df = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/dataset2.csv',encoding='cp949',index_col=0)

# %%
ppt_df.head()
# Out:
#    고객번호      구매금액   14년 1분기   14년 2분기   14년 3분기  ...  총구매등급  평일/주말  방문횟수  방문등급  종합등급
# 0     1  85042550   9141590  10783765  10781550  ...      4     평일   681     4     4
# 1     2  99880760  14123470  10199760  14841180  ...      4     평일   676     4     4
# 2     3   3165167    302782    548433    648188  ...      1     평일   490     2     2
# 3     4  16693810   1309643   3732463   2434410  ...      2     평일   533     2     2
# 4     5  13237070   3145330   2314820   1827290  ...      2     평일   426     1     2
#
# [5 rows x 25 columns]

# %%
c = ppt_df['14년도 구매액'].sum()
v = ppt_df['15년도 구매액'].sum()

# %%
v/c
# Out:
# 1.054051505742796

# %%
ppt_df
# Out:
#         고객번호      구매금액   14년 1분기   14년 2분기  ...  방문등급  종합등급    14년상반기    15년상반기
# 0          1  85042550   9141590  10783765  ...     4     4  19925355  17898365
# 1          2  99880760  14123470  10199760  ...     4     4  24323230  27791610
# 2          3   3165167    302782    548433  ...     2     2    851215    592280
# 3          4  16693810   1309643   3732463  ...     2     2   5042106   3656937
# 4          5  13237070   3145330   2314820  ...     1     2   5460150   2934930
# ...      ...       ...       ...       ...  ...   ...   ...       ...       ...
# 19378  19379   5779280         0         0  ...     1     1         0   2395920
# 19379  19380   3912977         0         0  ...     1     1         0    837950
# 19380  19381   6040669         0         0  ...     1     1         0   2797171
# 19381  19382   4401773         0         0  ...     1     1         0   1826739
# 19382  19383   2384400         0         0  ...     1     1         0     27000
#
# ...

# %%
ppt_dt_2014 =  ppt_df[ppt_df['14년도 구매액']>0]

# %%
ppt_dt_2014['매출변화율']=(ppt_dt_2014['15년도 구매액']/ppt_dt_2014['14년도 구매액'])-1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def cat_first(x):
  ''
  if x<0:
    y = '하락'
  else:
    y = '상승'
  ''
  return y

# %%
ppt_dt_2014['매출증감카테고리']=ppt_dt_2014['매출변화율'].apply(lambda x: cat_first(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ppt_dt_2014
# Out:
#         고객번호      구매금액   14년 1분기  ...    15년상반기      매출변화율  매출증감카테고리
# 0          1  85042550   9141590  ...  17898365  -0.426352        하락
# 1          2  99880760  14123470  ...  27791610   0.159802        상승
# 2          3   3165167    302782  ...    592280  -0.328641        하락
# 3          4  16693810   1309643  ...   3656937  -0.204893        하락
# 4          5  13237070   3145330  ...   2934930  -0.277742        하락
# ...      ...       ...       ...  ...       ...        ...       ...
# 19375  19376   7068554         0  ...   2687151  23.864001        상승
# 19376  19377   6271312         0  ...   3210252  26.852190        상승
# 19377  19378  18482940         0  ...  11586106  36.931123        상승
# 19378  19379   5779280         0  ...   2395920   2.854009        상승
# 19379  19380   3912977         0  ...    837950   5.486086        상승
#
# [19338 rows x 29 columns]

# %%
ppt_dt_2014['매출증감카테고리'].value_counts()
# Out:
# 상승    10706
# 하락     8632
# Name: 매출증감카테고리, dtype: int64

# %%
# 매출하락고객 비율 
8632/(10706+8632)
# Out:
# 0.44637501292791393

# %%
ppt_dt_2014_up = ppt_dt_2014[ppt_dt_2014['매출증감카테고리']=='상승']

# %%
a = ppt_dt_2014_up['14년도 구매액'].sum()
b = ppt_dt_2014_up['15년도 구매액'].sum()

# %%
a
# Out:
# 148629140366

# %%
b
# Out:
# 221129171479

# %%
b/a-1
# Out:
# 0.4877914985881524

# %%
# Out:
# 0.576730869338886

# %%
ppt_dt_2015 =  ppt_df[ppt_df['15년상반기']>0]

# %%
a = ppt_dt_2014['14년상반기'].sum()
b = ppt_dt_2015['15년상반기'].sum()

# %%
b/a-1
# Out:
# 0.06982033004540078

# %%
import pandas as pd
ch = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/ch.csv', encoding='cp949',index_col=0)
ch
# Out:
#                 제휴사  이용횟수
# 고객번호
# 1477   B_MOBILE/APP    13
# 1480   B_MOBILE/APP    25
# 1493   B_MOBILE/APP    20
# 1498   A_MOBILE/APP     2
# 1507   B_MOBILE/APP     8
# ...             ...   ...
# 19168  C_ONLINEMALL    18
# 19291  C_ONLINEMALL     1
# 19312  B_ONLINEMALL   137
# 19351  C_ONLINEMALL    19
# 19356  C_ONLINEMALL    16
#
# [8824 rows x 2 columns]

# %%
ch.reset_index(inplace=True)

# %%
11/(19147+155+37+33+11)
# Out:
# 0.0005675076097611309

# %% [markdown]
# 14년도 1분기 ~ 14년도 2분기 매출 증감율 = 1페이즈
# 개인 페이즈 평균 / 전체 페이즈 평균 = 개인 별 페이즈 영향력?
