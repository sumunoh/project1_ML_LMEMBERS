# %%
import pandas as pd
ppcd_df =pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/ppcd_df.csv',encoding='cp949', index_col=0)
ppcd_df
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#          제휴사    영수증번호    소분류코드   고객번호      구매일자  ...   대분류명  뉴중분류명 성별  연령대 거주지역
# 0          B  8664000  B150401  17218  20140222  ...     식품     음료  F  50대  100
# 1          B  8664000  B160101  17218  20140222  ...     식품     주류  F  50대  100
# 2          B  8664000  B160201  17218  20140222  ...     식품     주류  F  50대  100
# 3          B  8664000  B180301  17218  20140222  ...  생활/건강   여성용품  F  50대  100
# 4          B  8664001  B050901  17674  20140222  ...     식품    농산품  F  30대  100
# ...       ..      ...      ...    ...       ...  ...    ...    ... ..  ...  ...
# 28593025   B  7693179  B150101   8397  20140129  ...     식품     음료  M  30대  100
# 28593026   B  7693180  B480202  15386  20140129  ...     식품     육류  F  50대  100
# ...

# %%
ppcd = ppcd_df[['대분류명','뉴중분류명']].drop_duplicates()
ppcd1 = ppcd.groupby('대분류명')
ppcd2 = ppcd.groupby('대분류명')['뉴중분류명'].apply(list)
ppcd2[0]
# Out:
# ['인테리어', '침구', '전자기기', '가전', '디지털', '가구', '게임']

# %%
ppcd1 = list(ppcd1)
ppcd1[0][0]
# Out:
# '가구/가전/전자기기'

# %%
s = [] 
for i in ppcd2[0]:
  s.append(i)
# Out:
# ['가구/가전/전자기기', 15       인테리어
#  497        침구
#  2311     전자기기
#  2839       가전
#  2842      디지털
#  3489       가구
#  22964      게임
#  Name: 뉴중분류명, dtype: object]

# %%
for i in range(8):
  print('{}\n{}\n'.format(ppcd1[i][0],ppcd2[i]))
# Out:
# 가구/가전/전자기기
# ['인테리어', '침구', '전자기기', '가전', '디지털', '가구', '게임']
#
# 기타
# ['바디용품', '다이소', '화장', '일반식당', '편의시설', '헤어', '케어', '화장소품', '담배', '풋/핸드', '남성케어', '남성향수', '일반의약외품', '여성향수', '패스트푸드', '카페', '레스토랑', '해외직구']
#
# 반려/취미/문구/도서
# ['문구', '미술', '파티/팬시', '반려', '교육', '장난감', '도서', '핫팩', '식물', '음악', '스포츠', '여성의류']
#
# 생활/건강
# ['여성용품', '세제/방향/탈취', '주방용품', '생활잡화', '청소용품', '정리용품', '욕실용품', '구강용품', '위생용품', '세탁용품', '안전용품', '헬스용품', '공구/안전용품']
#
# 스포츠/레저/자동차
# ['아웃도어', '스포츠', '인테리어', '레저', '자동차']
#
# 식품
# ['음료', '주류', '농산품', '유제품', '가공식품', '수산품', '라면/통조림/즉석밥', '빵류', '육류', '과일', '반찬', '소스/양념/조미료', '간식', '농산물', '쌀/잡곡', '건강식품', '건해산물', '견과류', '회/초밥', '수산물']
#
# 의류/잡화
# ['남성의류', 'ACC', '속옷', '패션잡화', '여성의류', '신발', '명품', '주얼리', '가방', '시계']
#
# 출산유아동
# ['출산유아동']

# %%
LMEMBERS[LMEMBERS['1ps']=='증가']['1ps']=0
LMEMBERS[LMEMBERS['1ps']=='감소']['1ps']=1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
cust_z = LMEMBERS['1P_GAP','2P_GAP','3P_GAP']
cust_z
# Out:
#          고객번호         대분류명    구매금액_1    구매금액_2  ...  3ps    1P_GAP    2P_GAP   3P_GAP
# 0           1   가구/가전/전자기기    177650  13832340  ...   증가  13654690 -12964090  1069500
# 1           1           기타   1711450   1189900  ...   감소   -521550   -589400  -417900
# 2           1        생활/건강    519620   3582100  ...   증가   3062480  -3058740   189100
# 3           1           식품   4747205   3080192  ...   감소  -1667013   -178407 -1810747
# 4           1        의류/잡화  10448770  12431780  ...   감소   1983010    -27290 -3610470
# ...       ...          ...       ...       ...  ...  ...       ...       ...      ...
# 128746  19379        의류/잡화         0    453050  ...   증가    453050    246950    70530
# 128747  19380   가구/가전/전자기기         0      9900  ...   증가      9900     -7450    33590
# 128748  19380           기타         0    493000  ...   증가    493000    131180  1360280
# 128749  19380  반려/취미/문구/도서         0      3000  ...   증가      3000     -3000     6000
# ...

# %%
LMEMBERS['1P_GAP'] = (LMEMBERS['구매금액_2'] - LMEMBERS['구매금액_1'])
LMEMBERS['2P_GAP'] = (LMEMBERS['구매금액_3'] - LMEMBERS['구매금액_2'])
LMEMBERS['3P_GAP'] = (LMEMBERS['구매금액_4'] - LMEMBERS['구매금액_3'])

# %%
import pandas as pd
LMEMBERS = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1008/페이즈별 _금액_변화.csv',encoding='cp949',index_col=0)
LMEMBERS
# Out:
#          고객번호         대분류명    구매금액_1    구매금액_2  ...         3p  1ps  2ps  3ps
# 0           1   가구/가전/전자기기    177650  13832340  ...   1.231788   증가   감소   증가
# 1           1           기타   1711450   1189900  ...  -0.695920   감소   감소   감소
# 2           1        생활/건강    519620   3582100  ...   0.361319   증가   감소   증가
# 3           1           식품   4747205   3080192  ...  -0.624011   감소   감소   감소
# 4           1        의류/잡화  10448770  12431780  ...  -0.291062   증가   감소   감소
# ...       ...          ...       ...       ...  ...        ...  ...  ...  ...
# 128746  19379        의류/잡화         0    453050  ...   0.100757   증가   증가   증가
# 128747  19380   가구/가전/전자기기         0      9900  ...  13.710204   증가   감소   증가
# 128748  19380           기타         0    493000  ...   2.179307   증가   증가   증가
# 128749  19380  반려/취미/문구/도서         0      3000  ...        inf   증가   감소   증가
# 128750  19380           식품         0     16800  ...   1.840278   증가   증가   증가
#
# [128751 rows x 12 columns]

# %%
LMEMBERS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128751 entries, 0 to 128750
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   고객번호    128751 non-null  int64
#  1   대분류명    128751 non-null  object
#  2   구매금액_1  128751 non-null  int64
#  3   구매금액_2  128751 non-null  int64
#  4   구매금액_3  128751 non-null  int64
#  5   구매금액_4  128751 non-null  int64
#  6   1p      128751 non-null  float64
#  7   2p      128751 non-null  float64
#  8   3p      124140 non-null  float64
#  9   1ps     128751 non-null  object
#  10  2ps     128751 non-null  object
#  11  3ps     128751 non-null  object
# dtypes: float64(3), int64(5), object(4)
# memory usage: 12.8+ MB

# %%
lm2 = LMEMBERS.pivot_table(values=['구매금액_1','구매금액_2','구매금액_3','구매금액_4'], index='고객번호', columns='대분류명')
lm2
# Out:
#           구매금액_1                         ...     구매금액_4
# 대분류명  가구/가전/전자기기         기타 반려/취미/문구/도서  ...         식품      의류/잡화    출산유아동
# 고객번호                                     ...
# 1       177650.0  1711450.0         NaN  ...  1091038.0  8794020.0      NaN
# 2      1952400.0  7457460.0     30500.0  ...  3086330.0  9962600.0  71900.0
# 3            0.0        NaN         NaN  ...   608768.0        NaN      NaN
# 4            0.0    33250.0         NaN  ...  1479057.0  1829680.0      0.0
# 5        49900.0   897310.0         NaN  ...  1698920.0   727050.0      NaN
# ...          ...        ...         ...  ...        ...        ...      ...
# 19376        NaN        NaN         NaN  ...  2981176.0        NaN      NaN
# 19377        NaN        0.0         NaN  ...   306650.0  1015590.0      NaN
# 19378        NaN        NaN         NaN  ...  1991874.0  1351010.0      NaN
# 19379        NaN        0.0         NaN  ...   279770.0   770530.0      NaN
# ...

# %%
lm2.columns = ['1P_가구/가전/전자기기','1P_기타','1P_반려/취미/문구/도서','1P_생활/건강','1P_스포츠/레저/자동차','1P_식품','1P_의류/잡화','1P_출산유아동','2P_가구/가전/전자기기','2P_기타','2P_반려/취미/문구/도서','2P_생활/건강','2P_스포츠/레저/자동차','2P_식품','2P_의류/잡화','2P_출산유아동','3P_가구/가전/전자기기','3P_기타','3P_반려/취미/문구/도서','3P_생활/건강','3P_스포츠/레저/자동차','3P_식품','3P_의류/잡화','3P_출산유아동','4P_가구/가전/전자기기','4P_기타','4P_반려/취미/문구/도서','4P_생활/건강','4P_스포츠/레저/자동차','4P_식품','4P_의류/잡화','4P_출산유아동']

# %%
lm2.reset_index(inplace=True)

# %%
lm2
# Out:
#         고객번호  1P_가구/가전/전자기기      1P_기타  ...      4P_식품   4P_의류/잡화  4P_출산유아동
# 0          1       177650.0  1711450.0  ...  1091038.0  8794020.0       NaN
# 1          2      1952400.0  7457460.0  ...  3086330.0  9962600.0   71900.0
# 2          3            0.0        NaN  ...   608768.0        NaN       NaN
# 3          4            0.0    33250.0  ...  1479057.0  1829680.0       0.0
# 4          5        49900.0   897310.0  ...  1698920.0   727050.0       NaN
# ...      ...            ...        ...  ...        ...        ...       ...
# 19293  19376            NaN        NaN  ...  2981176.0        NaN       NaN
# 19294  19377            NaN        0.0  ...   306650.0  1015590.0       NaN
# 19295  19378            NaN        NaN  ...  1991874.0  1351010.0       NaN
# 19296  19379            NaN        0.0  ...   279770.0   770530.0       NaN
# 19297  19380            0.0        0.0  ...   471827.0        NaN       NaN
#
# [19298 rows x 33 columns]

# %%
lm2.fillna(0,inplace=True)

# %%
lm2
# Out:
#         고객번호  1P_가구/가전/전자기기      1P_기타  ...      4P_식품   4P_의류/잡화  4P_출산유아동
# 0          1       177650.0  1711450.0  ...  1091038.0  8794020.0       0.0
# 1          2      1952400.0  7457460.0  ...  3086330.0  9962600.0   71900.0
# 2          3            0.0        0.0  ...   608768.0        0.0       0.0
# 3          4            0.0    33250.0  ...  1479057.0  1829680.0       0.0
# 4          5        49900.0   897310.0  ...  1698920.0   727050.0       0.0
# ...      ...            ...        ...  ...        ...        ...       ...
# 19293  19376            0.0        0.0  ...  2981176.0        0.0       0.0
# 19294  19377            0.0        0.0  ...   306650.0  1015590.0       0.0
# 19295  19378            0.0        0.0  ...  1991874.0  1351010.0       0.0
# 19296  19379            0.0        0.0  ...   279770.0   770530.0       0.0
# 19297  19380            0.0        0.0  ...   471827.0        0.0       0.0
#
# [19298 rows x 33 columns]

# %%
lm2.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/a_sort_got.csv',encoding='cp949')

# %%
all2 = pd.merge(allss,lm2, on='고객번호',how='left')
all2
# Out:
#         고객번호  성별  연령대  14년 상반기  ...  3P_스포츠/레저/자동차     3P_식품  3P_의류/잡화  3P_출산유아동
# 0          1   1    5       10  ...            NaN -0.624011 -0.291062       NaN
# 1          2   1    5       10  ...      -0.295755  0.085310  0.018056 -0.930805
# 2          3   1    5        1  ...            NaN  0.130992       NaN       NaN
# 3          4   0    5        6  ...       2.556774 -0.180499  0.320277 -1.000000
# 4          5   1    5        7  ...            NaN -0.145812  0.572340       NaN
# ...      ...  ..  ...      ...  ...            ...       ...       ...       ...
# 19142  19356   0    3        1  ...            inf  0.057351  4.050000       NaN
# 19143  19357   0    3        1  ...      15.024390 -0.255253 -0.470545 -0.239237
# 19144  19359   1    4        1  ...            NaN  0.405348       inf       NaN
# 19145  19360   0    3        1  ...      -0.929694 -0.468867  0.785486       NaN
# 19146  19364   0    1        2  ...       2.660377 -0.746012 -0.644739 -0.218750
#
# ...

# %%
all2.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1010/dataset_d_all.csv',encoding='cp949')

# %%
allss = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1010/dataset_d_all.csv',encoding='cp949',index_col=0)
allss
# Out:
#         고객번호  성별  연령대  14년 상반기  ...  3P_스포츠/레저/자동차     3P_식품  3P_의류/잡화  3P_출산유아동
# 0          1   1    5       10  ...            NaN -0.624011 -0.291062       NaN
# 1          2   1    5       10  ...      -0.295755  0.085310  0.018056 -0.930805
# 2          3   1    5        1  ...            NaN  0.130992       NaN       NaN
# 3          4   0    5        6  ...       2.556774 -0.180499  0.320277 -1.000000
# 4          5   1    5        7  ...            NaN -0.145812  0.572340       NaN
# ...      ...  ..  ...      ...  ...            ...       ...       ...       ...
# 19142  19356   0    3        1  ...            inf  0.057351  4.050000       NaN
# 19143  19357   0    3        1  ...      15.024390 -0.255253 -0.470545 -0.239237
# 19144  19359   1    4        1  ...            NaN  0.405348       inf       NaN
# 19145  19360   0    3        1  ...      -0.929694 -0.468867  0.785486       NaN
# 19146  19364   0    1        2  ...       2.660377 -0.746012 -0.644739 -0.218750
#
# ...

# %%
import pandas as pd 
allss = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1010/dataset_d_drop.csv',encoding='cp949',index_col=0)
allss
# Out:
#         고객번호  성별  연령대  ...  1P_sort_de  2P_sort_de  3P_sort_de
# 0          1   1    5  ...          13          -5          -6
# 1          2   1    5  ...           4           3          -5
# 2          3   1    5  ...           1          -6           7
# 3          4   0    5  ...           5          -2          -3
# 4          5   1    5  ...          -4          -2           1
# ...      ...  ..  ...  ...         ...         ...         ...
# 19142  19356   0    3  ...          15          -1           0
# 19143  19357   0    3  ...          28          -3          -2
# 19144  19359   1    4  ...          16          -1          -3
# 19145  19360   0    3  ...          14          -4          -5
# 19146  19364   0    1  ...          20          -5          -6
#
# [19147 rows x 29 columns]

# %%
allss2 = allss.copy()
allss2
# Out:
#         고객번호 성별  연령대   14년 상반기  ...  4_중분류갯수  1P_sort_de  2P_sort_de  3P_sort_de
# 0          1  M  60대  19925355  ...       23          13          -5          -6
# 1          2  M  60대  24323230  ...       21           4           3          -5
# 2          3  M  60대    851215  ...       23           1          -6           7
# 3          4  F  60대   5042106  ...       24           5          -2          -3
# 4          5  M  60대   5460150  ...       13          -4          -2           1
# ...      ... ..  ...       ...  ...      ...         ...         ...         ...
# 19142  19356  F  40대    170160  ...       27          15          -1           0
# 19143  19357  F  40대     91950  ...       32          28          -3          -2
# 19144  19359  M  50대     43190  ...       19          16          -1          -3
# 19145  19360  F  40대    368050  ...       16          14          -4          -5
# 19146  19364  F  20대   2032420  ...       21          20          -5          -6
#
# ...

# %%
all2 = pd.merge(allss2,lm, on='고객번호',how='left')
all2
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py:643: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)
#         고객번호 성별  연령대  ...  (구매금액_4, 식품)  (구매금액_4, 의류/잡화)  (구매금액_4, 출산유아동)
# 0          1  M  60대  ...     1091038.0        8794020.0              NaN
# 1          2  M  60대  ...     3086330.0        9962600.0          71900.0
# 2          3  M  60대  ...      608768.0              NaN              NaN
# 3          4  F  60대  ...     1479057.0        1829680.0              0.0
# 4          5  M  60대  ...     1698920.0         727050.0              NaN
# ...      ... ..  ...  ...           ...              ...              ...
# 19142  19356  F  40대  ...     1894337.0         141400.0              NaN
# 19143  19357  F  40대  ...     1469635.0         308090.0         139600.0
# 19144  19359  M  50대  ...     1020170.0           2990.0              NaN
# ...

# %%
all3 = pd.merge(all2,lm, on='고객번호',how='left')
all3
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/merge.py:643: UserWarning: merging between different levels can give an unintended result (1 levels on the left,2 on the right)
#   warnings.warn(msg, UserWarning)
#         고객번호 성별  연령대  ...  (3p, 식품)  (3p, 의류/잡화)  (3p, 출산유아동)
# 0          1  M  60대  ... -0.624011    -0.291062          NaN
# 1          2  M  60대  ...  0.085310     0.018056    -0.930805
# 2          3  M  60대  ...  0.130992          NaN          NaN
# 3          4  F  60대  ... -0.180499     0.320277    -1.000000
# 4          5  M  60대  ... -0.145812     0.572340          NaN
# ...      ... ..  ...  ...       ...          ...          ...
# 19142  19356  F  40대  ...  0.057351     4.050000          NaN
# 19143  19357  F  40대  ... -0.255253    -0.470545    -0.239237
# 19144  19359  M  50대  ...  0.405348          inf          NaN
# 19145  19360  F  40대  ... -0.468867     0.785486          NaN
# 19146  19364  F  20대  ... -0.746012    -0.644739    -0.218750
#
# ...

# %%
import pandas as pd 
alls = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1010/기준데이터셋_d_drop.csv',encoding='cp949',index_col=0)
alls
# Out:
#         고객번호 성별  연령대  14년 상반기  ...  4_평균구매시간_cat  1P_sort_de  2P_sort_de  3P_sort_de
# 0          1  M  60대     1733  ...             0          13          -5          -6
# 1          2  M  60대     1225  ...             0           4           3          -5
# 2          3  M  60대    18509  ...             0           1          -6           7
# 3          4  F  60대     7745  ...             0           5          -2          -3
# 4          5  M  60대     7209  ...             0          -4          -2           1
# ...      ... ..  ...      ...  ...           ...         ...         ...         ...
# 19142  19356  F  40대    19008  ...             0          15          -1           0
# 19143  19357  F  40대    19073  ...             1          28          -3          -2
# 19144  19359  M  50대    19115  ...             1          16          -1          -3
# 19145  19360  F  40대    18882  ...             1          14          -4          -5
# ...

# %%
def w(x):
  if x>=0:
    result = 0
  else:
    result = 1
  return result

# %%
alls['1P'] = alls['1P'].apply(lambda x: w(x))
alls['2P'] = alls['2P'].apply(lambda x: w(x))
alls['3P'] = alls['3P'].apply(lambda x: w(x))

# %%
alls
# Out:
#         고객번호 성별  연령대  14년 상반기  ...  4_평균구매시간_cat  1P_sort_de  2P_sort_de  3P_sort_de
# 0          1  M  60대     1733  ...             0          13          -5          -6
# 1          2  M  60대     1225  ...             0           4           3          -5
# 2          3  M  60대    18509  ...             0           1          -6           7
# 3          4  F  60대     7745  ...             0           5          -2          -3
# 4          5  M  60대     7209  ...             0          -4          -2           1
# ...      ... ..  ...      ...  ...           ...         ...         ...         ...
# 19142  19356  F  40대    19008  ...             0          15          -1           0
# 19143  19357  F  40대    19073  ...             1          28          -3          -2
# 19144  19359  M  50대    19115  ...             1          16          -1          -3
# 19145  19360  F  40대    18882  ...             1          14          -4          -5
# ...

# %%
pd.merge(alls,)

# %%
import pandas as pd 
allss = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1010/dataset_d_drop.csv',encoding='cp949',index_col=0)
allss
# Out:
#         고객번호  성별  연령대  ...  1P_sort_de  2P_sort_de  3P_sort_de
# 0          1   1    5  ...          13          -5          -6
# 1          2   1    5  ...           4           3          -5
# 2          3   1    5  ...           1          -6           7
# 3          4   0    5  ...           5          -2          -3
# 4          5   1    5  ...          -4          -2           1
# ...      ...  ..  ...  ...         ...         ...         ...
# 19142  19356   0    3  ...          15          -1           0
# 19143  19357   0    3  ...          28          -3          -2
# 19144  19359   1    4  ...          16          -1          -3
# 19145  19360   0    3  ...          14          -4          -5
# 19146  19364   0    1  ...          20          -5          -6
#
# [19147 rows x 29 columns]

# %%
from xgboost import XGBClassifier

xgb_wrapper = XGBClassifier(n_estimators = 400, learning_rate = 0.1, max_depth = 3)
xgb_wrapper.fit(X_train, y_train)
w_preds = xgb_wrapper.predict(X_test)
# Out:
# 15317 3830
# [14:01:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.08, max_delta_step=0,
#              max_depth=7, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=0.75, verbosity=1)

# %%
xgboost.plot_importance(xgb_model)

# %%
predictions = xgb_model.predict(X_test)
predictions

# %%
r_sq = xgb_model.score(X_train, y_train)
print(r_sq)
print(explained_variance_score(predictions,y_test))

# %%
import seaborn as sns
import pandas as pd

# VIF기능을 제공하는 라이브러리 불러오기
from statsmodels.stats.outliers_influence import variance_inflation_factor


# 범주형 변수 제거(type)
alls.drop(['고객번호','연령대'],inplace = True,axis=1)

vif = []



# values atribution(속성) 이용해 train 데이터의 값만 추출

train_val = allss.values



#  variance_inflation_factor 함수에 인자로 train_val (train 데이터의 값)과 인덱스 번호 지정  

# for문 이용

for i in range(len(allss.columns)):
  vif.append(variance_inflation_factor(allss.values, i))



vif
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py:1638: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss
# [1.206386912576552,
#  9.1359556583066,
#  24.099334444959037,
#  32.07341871857616,
#  31.4175649017274,
#  23.94786968418251,
#  nan,
#  nan,
#  nan,
#  6.035947678941249,
#  5.88227022570464,
#  6.138080510957455,
#  6.2527414969320585,
#  6.400618402146171,
#  6.389539086331948,
#  6.188928263104426,
#  6.390598080232311,
#  6.260514177864293,
#  6.043634160834363,
#  6.092311993349214,
#  5.9146275679622535,
#  4.393739685123695,
#  5.4524211404676155,
#  5.380115011796825,
#  4.360150425569398,
#  1.5017505450672954,
#  1.5513123904791832,
#  1.3704849094361202]
