# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')
my_path = '/content/notebooks'
os.symlink('/content/drive/My Drive/Colab Notebooks', my_path)
sys.path.insert(0,my_path)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/the_new_ddf',encoding='cp949',index_col=0)

# %%
the_new_df = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/the_new_ddf2.csv',encoding='cp949',index_col=0)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')

def scale_modeling(data,model):

  y = data[['3P']]
  x = data.drop(['고객번호','3P','3D_가구/가전/전자기기_rank','3D_기타_rank','3D_반려/취미/문구/도서_rank','3D_생활/건강_rank','3D_스포츠/레저/자동차_rank','3D_식품_rank','3D_의류/잡화_rank','3D_출산유아동_rank','3P_sort_de','3P고객매출등급','3P고객방문등급'],axis=1)

  scaler = StandardScaler()
  new_x = scaler.fit_transform(x)

  X_train, X_test, y_train, y_test = train_test_split(new_x,y,test_size=0.2,random_state=0)


  if model == 'rf':  
    rf_clf = RandomForestClassifier(random_state=0)
    rf_clf.fit(X_train,y_train)
    rf_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test,rf_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'lr':
    lr_clf = LogisticRegression(random_state=0)
    lr_clf.fit(X_train,y_train)
    lr_pred = lr_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lr_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'xgb':
    xgb_clf = XGBClassifier(random_state=0)
    evals = [(X_test,y_test)]
    xgb_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    xgb_pred = xgb_clf.predict(X_test)
    accuracy = accuracy_score(y_test,xgb_pred)
    print(model,'정확도 : ',round(accuracy,2))
  elif model == 'lgbm':
    lgbm_clf = LGBMClassifier(random_state=0)
    evals = [(X_test,y_test)]
    lgbm_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    lgbm_pred = lgbm_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lgbm_pred)
    print(model,'정확도 : ',round(accuracy,2))

  else :
    print('모델 인자 값을 확인하세요')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')

def modeling(data,model):

  y = data[['3P']]
  x = data.drop(['고객번호','3P','3D_가구/가전/전자기기_rank','3D_기타_rank','3D_반려/취미/문구/도서_rank','3D_생활/건강_rank','3D_스포츠/레저/자동차_rank','3D_식품_rank','3D_의류/잡화_rank','3D_출산유아동_rank','3P_sort_de','3P고객매출등급','3P고객방문등급'],axis=1)



  X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)


  if model == 'rf':  
    rf_clf = RandomForestClassifier(random_state=0)
    rf_clf.fit(X_train,y_train)
    rf_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test,rf_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'lr':
    lr_clf = LogisticRegression(random_state=0)
    lr_clf.fit(X_train,y_train)
    lr_pred = lr_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lr_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'xgb':
    xgb_clf = XGBClassifier(random_state=0)
    evals = [(X_test,y_test)]
    xgb_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    xgb_pred = xgb_clf.predict(X_test)
    accuracy = accuracy_score(y_test,xgb_pred)
    print(model,'정확도 : ',round(accuracy,2))
  elif model == 'lgbm':
    lgbm_clf = LGBMClassifier(random_state=0)
    evals = [(X_test,y_test)]
    lgbm_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    lgbm_pred = lgbm_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lgbm_pred)
    print(model,'정확도 : ',round(accuracy,2))

  else :
    print('모델 인자 값을 확인하세요')

# %%
li = ['lr','rf','xgb','lgbm']
for i in li:
  modeling(the_new_df,i)
  scale_modeling(the_new_df,i)
# Out:
# lr 정확도 :  0.63
# lr 정확도 :  0.63
# rf 정확도 :  0.6
# rf 정확도 :  0.61
# xgb 정확도 :  0.63
# xgb 정확도 :  0.63
# lgbm 정확도 :  0.62
# lgbm 정확도 :  0.62

# %%
ppcd_df = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/ppcd_df.csv',encoding='cp949',index_col=0)

# %%
ppcd_df_15 = ppcd_df[ppcd_df['구매일자'] > 20150000]
ppcd_df_14 = ppcd_df[ppcd_df['구매일자'] < 20150000]

ppcd_df_14_uq = ppcd_df_14[ppcd_df_14['구매일자'] < 20140700]
ppcd_df_14_dq = ppcd_df_14[ppcd_df_14['구매일자'] > 20140700]
ppcd_df_15_uq = ppcd_df_15[ppcd_df_15['구매일자'] < 20150700]
ppcd_df_15_dq = ppcd_df_15[ppcd_df_15['구매일자'] > 20150700]

# %%
ppcd_df_1 = ppcd_df_14_uq.groupby(['고객번호'])[['영수증번호']].count()
ppcd_df_2 = ppcd_df_14_dq.groupby(['고객번호'])[['영수증번호']].count()
ppcd_df_3 = ppcd_df_15_uq.groupby(['고객번호'])[['영수증번호']].count()
ppcd_df_4 = ppcd_df_15_dq.groupby(['고객번호'])[['영수증번호']].count()

ppcd_df_1.reset_index(inplace=True)
ppcd_df_2.reset_index(inplace=True)
ppcd_df_3.reset_index(inplace=True)
ppcd_df_4.reset_index(inplace=True)

# %%
ppcd_df_1.rename(columns={'영수증번호':'구매횟수_1'},inplace=True)
ppcd_df_2.rename(columns={'영수증번호':'구매횟수_2'},inplace=True)
ppcd_df_3.rename(columns={'영수증번호':'구매횟수_3'},inplace=True)
ppcd_df_4.rename(columns={'영수증번호':'구매횟수_4'},inplace=True)

# %%
li = [ppcd_df_1,ppcd_df_2,ppcd_df_3,ppcd_df_4]
for i in li:
  print(i.count()[0])
# Out:
# 19210
# 19298
# 19343
# 19346

# %%
count_df = ppcd_df_4.merge(ppcd_df_2,how='left',on='고객번호')
count_df = count_df.merge(ppcd_df_3,how='left',on='고객번호')
count_df = count_df.merge(ppcd_df_1,how='left',on='고객번호')

# %%
count_df.fillna(0,inplace=True)

# %%
count_df = count_df.astype(int)

# %%
count_df = count_df[['고객번호','구매횟수_1','구매횟수_2','구매횟수_3','구매횟수_4']]

# %%
result_df = df.merge(count_df,how='left',on='고객번호')

# %%
# result_df.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/result_df.csv',encoding='cp949')

# %%
print(result_df['구매횟수_1'].describe()['max'])
print(result_df['구매횟수_2'].describe()['max'])
print(result_df['구매횟수_3'].describe()['max'])
print(result_df['구매횟수_4'].describe()['max'])
# Out:
# 2398.0
# 3049.0
# 2542.0
# 3309.0

# %%
result_df['구매횟수_1P'] = result_df['구매횟수_2'] - result_df['구매횟수_1']
result_df['구매횟수_2P'] = result_df['구매횟수_3'] - result_df['구매횟수_2']
result_df['구매횟수_3P'] = result_df['구매횟수_4'] - result_df['구매횟수_3']

# %%
df_1012 = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/a12.csv',encoding='cp949',index_col=0)
ndf_1012 = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1007/기준_3P_분기제휴사_구매금액_1006_2.csv',index_col=0)

# %%
quter_df = ndf_1012[['고객번호','14년 상반기','14년 하반기','15년 상반기','15년 하반기']]

# %%
pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/a12.csv',encoding='cp949',index_col=0)
# Out:
#         고객번호  성별  연령대  ...  1P_방문횟수_RANK  2P_방문횟수_RANK  3P_방문횟수_RANK
# 0          1   1    5  ...            -2             1             3
# 1          2   1    5  ...             2             0             0
# 2          3   1    5  ...            -1             4            -1
# 3          4   0    5  ...             3            -2             1
# 4          5   1    5  ...             6             0             0
# ...      ...  ..  ...  ...           ...           ...           ...
# 19142  19356   0    3  ...            -5            -1             0
# 19143  19357   0    3  ...            -6             0             1
# 19144  19359   1    4  ...            -7             1             1
# 19145  19360   0    3  ...            -3             2             1
# 19146  19364   0    1  ...            -3             0             1
#
# [19147 rows x 39 columns]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def vif(data):

  vif = []

  data_val = data.values

  for i in range(len(data.columns)):
    vif.append(variance_inflation_factor(data_val, i))

  vif_dataframe = pd.DataFrame()
  vif_dataframe['columns'] = data.columns
  vif_dataframe['VIF'] = vif
  return vif_dataframe

# %%
vif(df_1012.drop(['고객번호','3P'],axis=1))
# Out:
#                 columns       VIF
# 0                    성별  1.194120
# 1                   연령대  4.301476
# 2                    1P  3.364170
# 3                    2P  3.946387
# 4            1P_sort_de  1.921471
# 5            2P_sort_de  1.985000
# 6            3P_sort_de  1.716801
# 7    1D_가구/가전/전자기기_rank  1.292457
# 8    2D_가구/가전/전자기기_rank  1.479858
# 9    3D_가구/가전/전자기기_rank  1.277653
# 10           1D_기타_rank  1.265790
# 11           2D_기타_rank  1.408185
# 12           3D_기타_rank  1.241812
# 13  1D_반려/취미/문구/도서_rank  1.193238
# 14  2D_반려/취미/문구/도서_rank  1.256312
# 15  3D_반려/취미/문구/도서_rank  1.167097
# 16        1D_생활/건강_rank  1.337512
# 17        2D_생활/건강_rank  1.550388
# 18        3D_생활/건강_rank  1.339916
# 19   1D_스포츠/레저/자동차_rank  1.258999
# 20   2D_스포츠/레저/자동차_rank  1.447747
# 21   3D_스포츠/레저/자동차_rank  1.222456
# 22           1D_식품_rank  1.990132
# 23           2D_식품_rank  2.128142
# 24           3D_식품_rank  1.850457
# 25        1D_의류/잡화_rank  1.747420
# ...

# %%
vi_df = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1010/dataset_d_drop.csv',encoding='cp949',index_col=0)

# %%
vif(vi_df)
# Out:
#          columns        VIF
# 0           고객번호   4.182327
# 1             성별   1.217819
# 2            연령대   9.457009
# 3        14년 상반기  24.430650
# 4        14년 하반기  33.103247
# 5        15년 상반기  32.509875
# 6        15년 하반기  24.122277
# 7             1P   1.045878
# 8             2P   1.083403
# 9             3P   1.020285
# 10      구매금액_1_A   6.097135
# 11      구매금액_1_B   5.932606
# 12      구매금액_1_C   6.245747
# 13      구매금액_2_A   6.286813
# 14      구매금액_2_B   6.448818
# 15      구매금액_2_C   6.468322
# 16      구매금액_3_A   6.220660
# 17      구매금액_3_B   6.428038
# 18      구매금액_3_C   6.333568
# 19      구매금액_4_A   6.073168
# 20      구매금액_4_B   6.139280
# 21      구매금액_4_C   6.020235
# 22  1_평균구매시간_cat   4.397046
# 23  2_평균구매시간_cat   5.456977
# 24  3_평균구매시간_cat   5.381928
# 25  4_평균구매시간_cat   4.364235
# 26    1P_sort_de   1.521886
# 27    2P_sort_de   1.564509
# 28    3P_sort_de   1.372578

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

def pca(data,inja,value):
  df_features = data[inja]
  df_scaler = MinMaxScaler().fit_transform(df_features)

  pca = PCA(n_components=value)

  df_pca = pca.fit_transform(df_scaler)
  df_pca = pd.DataFrame(df_pca)
  return df_pca

# %%
sli = vi_df.columns
new_df = pca(vi_df,sli,10)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')

def modeling(data,model):

  y = data[['3P']]
  x = data.drop(['3P'],axis=1)



  X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)


  if model == 'rf':  
    rf_clf = RandomForestClassifier(random_state=0)
    rf_clf.fit(X_train,y_train)
    rf_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test,rf_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'lr':
    lr_clf = LogisticRegression(random_state=0)
    lr_clf.fit(X_train,y_train)
    lr_pred = lr_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lr_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'xgb':
    xgb_clf = XGBClassifier(random_state=0)
    evals = [(X_test,y_test)]
    xgb_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    xgb_pred = xgb_clf.predict(X_test)
    accuracy = accuracy_score(y_test,xgb_pred)
    print(model,'정확도 : ',round(accuracy,2))
  elif model == 'lgbm':
    lgbm_clf = LGBMClassifier(random_state=0)
    evals = [(X_test,y_test)]
    lgbm_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    lgbm_pred = lgbm_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lgbm_pred)
    print(model,'정확도 : ',round(accuracy,2))

  else :
    print('모델 인자 값을 확인하세요')

# %%
last_df = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/good_o1nam.csv',encoding='cp949',index_col=0)

# %%
last_df = last_df[['2P','3P','2P_sort_de','2P_매출등급_RANK','2P_방문횟수_RANK','2PP_가구/가전/전자기기','2PP_반려/취미/문구/도서','2PP_스포츠/레저/자동차','2PP_식품','2PP_의류/잡화','2PP_출산유아동']]

# %%
li = ['lr','rf','xgb','lgbm']
for i in li:
  modeling(last_df,i)
# Out:
# lr 정확도 :  0.61
# rf 정확도 :  0.58
# xgb 정확도 :  0.6
# lgbm 정확도 :  0.6

# %%
end_df = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1012/end_game.csv',encoding='cp949',index_col=0)

# %%
# end_df = end_df.rank(ascending=False).astype(int)

# %%
# end_df.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1012/end_game_rank.csv',encoding='cp949')

# %%
end_df.reset_index(inplace=True) # 1 ~ 10까지 등급화

# %%
end_df.columns
# Out:
# Index(['고객번호', '1P_가구/가전/전자기기', '2P_가구/가전/전자기기', '3P_가구/가전/전자기기',
#        '4P_가구/가전/전자기기', '1P_기타', '2P_기타', '3P_기타', '4P_기타', '1P_반려/취미/문구/도서',
#        '2P_반려/취미/문구/도서', '3P_반려/취미/문구/도서', '4P_반려/취미/문구/도서', '1P_생활/건강',
#        '2P_생활/건강', '3P_생활/건강', '4P_생활/건강', '1P_스포츠/레저/자동차', '2P_스포츠/레저/자동차',
#        '3P_스포츠/레저/자동차', '4P_스포츠/레저/자동차', '1P_식품', '2P_식품', '3P_식품', '4P_식품',
#        '1P_의류/잡화', '2P_의류/잡화', '3P_의류/잡화', '4P_의류/잡화', '1P_출산유아동', '2P_출산유아동',
#        '3P_출산유아동', '4P_출산유아동'],
#       dtype='object')

# %%
end_df_tran = end_df[['1P_가구/가전/전자기기', '2P_가구/가전/전자기기', '3P_가구/가전/전자기기',
       '4P_가구/가전/전자기기', '1P_기타', '2P_기타', '3P_기타', '4P_기타', '1P_반려/취미/문구/도서',
       '2P_반려/취미/문구/도서', '3P_반려/취미/문구/도서', '4P_반려/취미/문구/도서', '1P_생활/건강',
       '2P_생활/건강', '3P_생활/건강', '4P_생활/건강', '1P_스포츠/레저/자동차', '2P_스포츠/레저/자동차',
       '3P_스포츠/레저/자동차', '4P_스포츠/레저/자동차', '1P_식품', '2P_식품', '3P_식품', '4P_식품',
       '1P_의류/잡화', '2P_의류/잡화', '3P_의류/잡화', '4P_의류/잡화', '1P_출산유아동', '2P_출산유아동',
       '3P_출산유아동', '4P_출산유아동']]

# %%
end_df_tran
# Out:
#        1P_가구/가전/전자기기  2P_가구/가전/전자기기  ...  3P_출산유아동  4P_출산유아동
# 0              59004          76711  ...         1         1
# 1              72161          68011  ...     71970     52440
# 2                  1          41288  ...         1         1
# 3                  1          64764  ...     52113         1
# 4              47362          60400  ...         1         1
# ...              ...            ...  ...       ...       ...
# 19293              1              1  ...         1         1
# 19294              1              1  ...         1         1
# 19295              1              1  ...         1         1
# 19296              1              1  ...         1         1
# 19297              1          33578  ...         1         1
#
# [19298 rows x 32 columns]

# %%
end_df_tran.describe()
# Out:
#        1P_가구/가전/전자기기  2P_가구/가전/전자기기  ...      3P_출산유아동      4P_출산유아동
# count   19298.000000   19298.000000  ...  19298.000000  19298.000000
# mean    30480.884703   38893.703959  ...  26334.856514  25591.139082
# std     28628.467611   25941.483296  ...  30278.937437  30157.640500
# min         1.000000       1.000000  ...      1.000000      1.000000
# 25%         1.000000       1.000000  ...      1.000000      1.000000
# 50%     35111.500000   44395.000000  ...      1.000000      1.000000
# 75%     57233.250000   60006.750000  ...  57248.750000  56657.000000
# max     77189.000000   77188.000000  ...  77182.000000  77188.000000
#
# [8 rows x 32 columns]

# %%
def cla(data):
  fault = 77192 / 9

  if data == 1:
    result = 1

  elif 1 < data <= fault:
    result = 2

  elif fault <= data <= (fault*2):
    result = 3

  elif (fault*2) <= data <= (fault*3):
    result = 4

  elif (fault*3) <= data <= (fault*4):
    result = 5

  elif (fault*4) <= data <= (fault*5):
    result = 6

  elif (fault*5) <= data <= (fault*6):
    result = 7

  elif (fault*6) <= data <= (fault*7):
    result = 8

  elif (fault*7) <= data <= (fault*8):
    result = 9

  elif (fault*8) <= data <= (fault*9):
    result = 10

  return result

# %%
end_df_result = end_df_tran['1P_기타'].apply(lambda x: cla(x))

# %%
tran_li = ['1P_가구/가전/전자기기', '2P_가구/가전/전자기기', '3P_가구/가전/전자기기',
       '4P_가구/가전/전자기기', '1P_기타', '2P_기타', '3P_기타', '4P_기타', '1P_반려/취미/문구/도서',
       '2P_반려/취미/문구/도서', '3P_반려/취미/문구/도서', '4P_반려/취미/문구/도서', '1P_생활/건강',
       '2P_생활/건강', '3P_생활/건강', '4P_생활/건강', '1P_스포츠/레저/자동차', '2P_스포츠/레저/자동차',
       '3P_스포츠/레저/자동차', '4P_스포츠/레저/자동차', '1P_식품', '2P_식품', '3P_식품', '4P_식품',
       '1P_의류/잡화', '2P_의류/잡화', '3P_의류/잡화', '4P_의류/잡화', '1P_출산유아동', '2P_출산유아동',
       '3P_출산유아동', '4P_출산유아동']

for i in tran_li:
  end_df[f'{i}'] = end_df[f'{i}'].apply(lambda x:cla(x))

# %%
import numpy as np

end_df.replace(1,np.nan,inplace=True)

# %%
feature_li = ['가구/가전/전자기기','기타','반려/취미/문구/도서','생활/건강','스포츠/레저/자동차','식품','의류/잡화','출산유아동']

# %%
for feature in feature_li:
  for i in range(1,4):
    end_df[f'{i}P_{feature}'] = end_df[f'{i}P_{feature}'].rank()

# %%
def checker(data,default):
  if data == 0:
    result = 0

  elif data <= default:
    result = 1

  elif data <= (default*2):
    result = 2

  elif data <= (default*3):
    result = 3

  elif data <= (default*4):
    result = 4

  elif data <= (default*5):
    result = 5

  elif data <= (default*6):
    result = 6

  elif data <= (default*7):
    result = 7

  elif data <= (default*8):
    result = 8

  elif data <= (default*9):
    result = 9
  
  else :
    result = '문제발생'

  return result

# %%
end_df.fillna(0,inplace=True)

# %%
end_df = end_df.astype(int)

# %%
for feature in feature_li:
  for i in range(1,4):
    fault = end_df[f'{i}P_{feature}'].describe()['max'].astype(int)
    default = fault / 9
    end_df[f'{i}P_{feature}'] = end_df[f'{i}P_{feature}'].apply(lambda x: checker(x,default))

# %%
for feature in feature_li:
  end_df.drop([f'4P_{feature}'],axis=1,inplace=True)

# %%
end_df.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1012/end_game_result.csv',encoding='cp949')

# %%
end_df['2P_가구/가전/전자기기'].value_counts()
# Out:
# 0    5024
# 6    2662
# 4    2573
# 3    2539
# 8    2499
# 9    2317
# 1    1684
# Name: 2P_가구/가전/전자기기, dtype: int64

# %%
#end_df.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1012/end_game_rank.csv',encoding='cp949')

# %%
import numpy as np

end_df = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1012/end_game.csv',encoding='cp949',index_col=0)


end_df.replace(1,np.nan,inplace=True)

feature_li = ['가구/가전/전자기기','기타','반려/취미/문구/도서','생활/건강','스포츠/레저/자동차','식품','의류/잡화','출산유아동']

end_df.fillna(0,inplace=True)
end_df = end_df.astype(int)

for feature in feature_li:
  for i in range(1,4):
    end_df[f'{i}P_{feature}'] = end_df[f'{i}P_{feature}'].rank()
    
for feature in feature_li:
  for i in range(1,4):
    fault = end_df[f'{i}P_{feature}'].describe()['max'].astype(int)
    default = fault / 9
    end_df[f'{i}P_{feature}'] = end_df[f'{i}P_{feature}'].apply(lambda x: checker(x,default))




for feature in feature_li:
  end_df.drop([f'4P_{feature}'],axis=1,inplace=True)

# %%
end_df
# Out:
#        1P_가구/가전/전자기기  2P_가구/가전/전자기기  ...  2P_출산유아동  3P_출산유아동
# 고객번호                                 ...
# 1                  7              9  ...         2         3
# 2                  9              8  ...         7         9
# 3                  2              5  ...         2         3
# 4                  2              8  ...         5         7
# 5                  6              7  ...         2         3
# ...              ...            ...  ...       ...       ...
# 19376              2              2  ...         2         3
# 19377              2              2  ...         2         3
# 19378              2              2  ...         2         3
# 19379              2              2  ...         2         3
# 19380              2              4  ...         2         3
#
# [19298 rows x 24 columns]

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')
my_path = '/content/notebooks'
os.symlink('/content/drive/My Drive/Colab Notebooks', my_path)
sys.path.insert(0,my_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-173-917b5458b89a> in <module>()
#       3 drive.mount('/content/drive')
#       4 my_path = '/content/notebooks'
# ----> 5 os.symlink('/content/drive/My Drive/Colab Notebooks', my_path)
#       6 sys.path.insert(0,my_path)
#
# FileExistsError: [Errno 17] File exists: '/content/drive/My Drive/Colab Notebooks' -> '/content/notebooks'

# %%
import pandas as pd

ppcd_df = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/ppcd_df.csv',encoding='cp949',index_col=0)

# %%
ppcd_df_15 = ppcd_df[ppcd_df['구매일자'] > 20150000]
ppcd_df_14 = ppcd_df[ppcd_df['구매일자'] < 20150000]

quter_1 = ppcd_df_14[ppcd_df_14['구매일자'] < 20140700]
quter_2 = ppcd_df_14[ppcd_df_14['구매일자'] > 20140700]
quter_3 = ppcd_df_15[ppcd_df_15['구매일자'] < 20150700]
quter_4 = ppcd_df_15[ppcd_df_15['구매일자'] > 20150700]

# %%
quter_1 = quter_1.groupby(['고객번호','대분류명'])[['구매금액']].sum().reset_index().rename(columns={'구매금액':'구매금액_1'})
quter_2 = quter_2.groupby(['고객번호','대분류명'])[['구매금액']].sum().reset_index().rename(columns={'구매금액':'구매금액_2'})
quter_3 = quter_3.groupby(['고객번호','대분류명'])[['구매금액']].sum().reset_index().rename(columns={'구매금액':'구매금액_3'})
quter_4 = quter_4.groupby(['고객번호','대분류명'])[['구매금액']].sum().reset_index().rename(columns={'구매금액':'구매금액_4'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-1fd18cc84dfc> in <module>()
# ----> 1 quter_1 = quter_1.groupby(['고객번호','대분류명'])[['구매금액']].sum().reset_index().rename(columns={'구매금액':'구매금액_1'})
#       2 quter_2 = quter_2.groupby(['고객번호','대분류명'])[['구매금액']].sum().reset_index().rename(columns={'구매금액':'구매금액_2'})
#       3 quter_3 = quter_3.groupby(['고객번호','대분류명'])[['구매금액']].sum().reset_index().rename(columns={'구매금액':'구매금액_3'})
#       4 quter_4 = quter_4.groupby(['고객번호','대분류명'])[['구매금액']].sum().reset_index().rename(columns={'구매금액':'구매금액_4'})
#
# NameError: name 'quter_1' is not defined

# %%
total_1 = quter_1.groupby(['고객번호'])[['구매금액_1']].sum()
total_2 = quter_2.groupby(['고객번호'])[['구매금액_2']].sum()
total_3 = quter_3.groupby(['고객번호'])[['구매금액_3']].sum()
total_4 = quter_4.groupby(['고객번호'])[['구매금액_4']].sum()

# %%
total_1

# %%
quter_fin = quter_2.merge(quter_1,how='left',on=['고객번호','대분류명'])
quter_fin = quter_fin.merge(quter_3,how='left',on=['고객번호','대분류명'])
quter_fin = quter_fin.merge(quter_4,how='left',on=['고객번호','대분류명'])
quter_fin = quter_fin[['고객번호','대분류명','구매금액_1','구매금액_2','구매금액_3','구매금액_4']]

# %%
quter_fin = quter_fin.fillna(0)

# %%
quter_fin[['구매금액_1','구매금액_2','구매금액_3','구매금액_4']] = quter_fin[['구매금액_1','구매금액_2','구매금액_3','구매금액_4']].astype(int)

# %%
lis = ['가구/가전/전자기기', '기타', '생활/건강', '식품', '의류/잡화', '반려/취미/문구/도서', '스포츠/레저/자동차', '출산유아동']
for z in lis:
  for i in range(1,5):
    quter_fin[f'{z}_{i}'] = quter_fin[quter_fin['대분류명'] == f'{z}'][[f'구매금액_{i}']]

# %%
quter_fin.columns

# %%
result_df = quter_fin.groupby(['고객번호'])[['가구/가전/전자기기_1',
       '가구/가전/전자기기_2', '가구/가전/전자기기_3', '가구/가전/전자기기_4', '기타_1', '기타_2', '기타_3',
       '기타_4', '생활/건강_1', '생활/건강_2', '생활/건강_3', '생활/건강_4', '식품_1', '식품_2',
       '식품_3', '식품_4', '의류/잡화_1', '의류/잡화_2', '의류/잡화_3', '의류/잡화_4',
       '반려/취미/문구/도서_1', '반려/취미/문구/도서_2', '반려/취미/문구/도서_3', '반려/취미/문구/도서_4',
       '스포츠/레저/자동차_1', '스포츠/레저/자동차_2', '스포츠/레저/자동차_3', '스포츠/레저/자동차_4',
       '출산유아동_1', '출산유아동_2', '출산유아동_3', '출산유아동_4']].sum().reset_index().astype(int)

# %%
cat_li_ = ['가구/가전/전자기기_1', '기타_1', '생활/건강_1', '식품_1', '의류/잡화_1', '반려/취미/문구/도서_1', '스포츠/레저/자동차_1', '출산유아동_1']

# %%
f_df = quter_fin.groupby(['고객번호'])[['구매금액_1','구매금액_2','구매금액_3','구매금액_4']].sum().reset_index()

# %%
final_df = result_df.merge(f_df,how='left',on='고객번호')

# %%
features = ['가구/가전/전자기기', '기타', '생활/건강', '식품', '의류/잡화', '반려/취미/문구/도서', '스포츠/레저/자동차', '출산유아동']

for feature in features:
  for i in range(1,5):
    final_df[f'{feature}_{i}'] = final_df[f'{feature}_{i}'] / final_df[f'구매금액_{i}']

# %%
final_df.fillna(0,inplace=True)

# %%
final_df.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1012/cat_pay.csv',encoding='cp949')

# %%
final_df

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')

def modeling(data,model):

  y = data[['3P']]
  x = data.drop(['3P'],axis=1)



  X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)


  if model == 'rf':  
    rf_clf = RandomForestClassifier(random_state=0)
    rf_clf.fit(X_train,y_train)
    rf_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test,rf_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'lr':
    lr_clf = LogisticRegression(random_state=0)
    lr_clf.fit(X_train,y_train)
    lr_pred = lr_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lr_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'xgb':
    xgb_clf = XGBClassifier(random_state=0)
    evals = [(X_test,y_test)]
    xgb_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    xgb_pred = xgb_clf.predict(X_test)
    accuracy = accuracy_score(y_test,xgb_pred)
    print(model,'정확도 : ',round(accuracy,2))
  elif model == 'lgbm':
    lgbm_clf = LGBMClassifier(random_state=0)
    evals = [(X_test,y_test)]
    lgbm_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    lgbm_pred = lgbm_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lgbm_pred)
    print(model,'정확도 : ',round(accuracy,2))

  else :
    print('모델 인자 값을 확인하세요')

# %%
### 전진석택법(step=1)

def forward(X,y,predictors):

  # predictor - 현재 선택되어있는 변수
  # 데이터 변수들이 미리정의된 predictors에 있는지 없는지 확인 및 분류
  
  remaining_predictors = [p for p in X.columns.difference(['const']) if p not in predictors]
  tic = time.time()
  results = []
  for p in remaining_predictors :
    results.append(processSubset(X=X,y=y,feature_set=predictors+[p]+['const']))
  
  # 데이터프레임으로 변환
  models = pd.DataFrame(results)
  
  # AIC가 가장 낮은 것을 선택
  best_model = models.loc[models['AIC'].argmin()]
  toc = time.time()
  print("Processed ",models.shape[0], "models on", len(predictors)+1, "predictors in", (toc-tic))
  print("Selected predictors:",best_model["model"].model.exog_names,"AIC: ",best_model[0])
  return best_model
  
### 전진선택법 모델

def forward_model(X,y):

  Fmodels = pd.DataFrame(columns=["AIC","model"])
  tic = time.time()
  
  # 미리 정의된 데이터 변수
  predictors = []
  
  # 변수 1~10개 : 0-9 -> 1-10
  for i in range(1,len(X,columns.difference(['const']))+1):
    Forward_result = forward(X=X,y=y,predictors=predictors)
      if i > 1 :
        if Forward_result["AIC"] > Fmodel_before:
            break
      Fmodels.loc[i] = Forward_result
      predictors = Fmodels.loc[i]["model"].model.exog_names
      Fmodel_before = Fmodels.loc[i]["AIC"]
      predictors = [k for k in predictors if k != 'const']
  toc = time.time()
  print("Total elapsed time:",(toc-tic), "seconds.")
  
  return (Fmodels['model'][len(Fmodels['model'])])

### 후진소거법(step=1)

def backward(X,y,predictors):
  tic = time.time()
  results = []
  
  # 데이터 변수들이 미리 정의된 predictors 조합 확인
  
  for combo in itertools.combinations(predictors, len(predictors) - 1):
    results.append(processSubset(X=X,y=y,feature_set=list(combo)+['const']))
  models = pd.DataFrame(results)
  
  # 가장 낮은 AIC를 가진 모델을 선택
  best_model = models.loc[models['AIC'].argmin()]
  toc = time.time()
  
  print("Processed ",models.shape[0], "models on", len(predictors) - 1, "predictors in",(toc-tic))
  print("Selected predictors:",best_model['model'].model.exog_names,' AIC:',best_model[0])
  return best_model
  
def backward_model(X,y) :
  Bmodels = pd.DataFrame(columns=["AIC","model"], index = range(1,len(X.columns))
  tic = time.time()
  predictors = X.columns.difference(['const'])
  Bmodel_before = processSubset(X,y,predictors)['AIC']
  while (len(predictors) > 1):
    Backward_result = backward(X=train_x, y= train_y, predictors=predictors)
      if Backward_result['AIC'] > Bmodel_before :
        break
      Bmodels.loc[len(predictors) -1] = Backward_result
      predictors = Bmodel.loc[len(predictors) - 1]['model'].model.exog_names
      Bmodel_before = Backward_result["AIC"]
      predictors = [k for k in predictors if k != 'const']
  
  toc = time.time()
  print("Total elapsed time:",(toc-tic),"seconds.")
  return (Bmodels["model"].dropna().iloc[0]
          
### 단계적 선택법

def Stepwise_model(X,y):
  Stepmodels = pd.DataFrame(columns = ["AIC","model"])
  tic = time.time()
  predictors = []
  Smodel_before = processSubset(X,y,predictors + ['const'])['AIC']
  
  # 변수 1~10개 0-9 -> 1-10
  for i in range(1,len(X.columns.difference(['const']))+1) :
      Forward_result = forward(X=X,y=y,predictors = predictors) # constant added
      print('forward')
      predictors = Stepmodels.loc[i]['model'].model.exog_names
      predictors = [k for k in predictors if k != 'const']
      Backward_result = backward(X=X,y=y,predictors = predictors)
      if Backward_result["AIC"] < Forward_result["AIC"]
          Stepmodels.loc[i] = Backward_result
          predictors = Stepmodels.loc[i]["model"].model.exog_names
          Smodel_before = Stepmodels.loc[i]["AIC"]
          predictors = [k for k in predictors k != "const"]
          print('backward')
      if Stepmodels.loc[i]["AIC"] > Smodel_before:
          break
      else :
          Smodel_before = Stepmodels.loc[i]["AIC"]
  toc = time.time()
  print("Total elapsed time:",(toc-tic),"seconds.")
  return (Stepmodels["model"][len(Stepmodels["model"])])
# Out:
#   File "<ipython-input-1-e836f798a8c0>", line 37
#     if i > 1 :
#     ^
# IndentationError: unexpected indent

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
result = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1012/dongju_1013.csv',encoding='cp949',index_col=0)
ppcd_df = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/ppcd_df.csv',encoding='cp949')

# %%
import pandas as pd
ppcd_df = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/ppcd_df.csv',encoding='cp949')

# %%
ppcd_df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
ppcd_df
# Out:
#          제휴사    영수증번호    소분류코드   고객번호      구매일자  ...   대분류명  뉴중분류명 성별  연령대 거주지역
# 0          B  8664000  B150401  17218  20140222  ...     식품     음료  F  50대  100
# 1          B  8664000  B160101  17218  20140222  ...     식품     주류  F  50대  100
# 2          B  8664000  B160201  17218  20140222  ...     식품     주류  F  50대  100
# 3          B  8664000  B180301  17218  20140222  ...  생활/건강   여성용품  F  50대  100
# 4          B  8664001  B050901  17674  20140222  ...     식품    농산품  F  30대  100
# ...       ..      ...      ...    ...       ...  ...    ...    ... ..  ...  ...
# 28593025   B  7693179  B150101   8397  20140129  ...     식품     음료  M  30대  100
# 28593026   B  7693180  B480202  15386  20140129  ...     식품     육류  F  50대  100
# 28593027   B  7693181  B160402   9835  20140129  ...     식품     음료  F  30대  100
# 28593028   B  7693181  B580102   9835  20140129  ...     식품     육류  F  30대  100
# 28593029   B  7693185  B100305  13806  20140129  ...     식품    유제품  F  40대  100
#
# ...

# %%
ppcd_df_15 = ppcd_df[ppcd_df['구매일자'] > 20150000]
ppcd_df_14 = ppcd_df[ppcd_df['구매일자'] < 20150000]

quter_1 = ppcd_df_14[ppcd_df_14['구매일자'] < 20140700]
quter_2 = ppcd_df_14[ppcd_df_14['구매일자'] > 20140700]
quter_3 = ppcd_df_15[ppcd_df_15['구매일자'] < 20150700]
quter_4 = ppcd_df_15[ppcd_df_15['구매일자'] > 20150700]

# %%
qu1 = quter_1.groupby(['고객번호'])[['구매금액']].sum().reset_index().rename(columns={'구매금액':'구매금액_1'})
qu2 = quter_2.groupby(['고객번호'])[['구매금액']].sum().reset_index().rename(columns={'구매금액':'구매금액_2'})
qu3 = quter_3.groupby(['고객번호'])[['구매금액']].sum().reset_index().rename(columns={'구매금액':'구매금액_3'})
qu4 = quter_4.groupby(['고객번호'])[['구매금액']].sum().reset_index().rename(columns={'구매금액':'구매금액_4'})

# %%
ldf = qu1.merge(qu2,how='left',on='고객번호')
ldf = ldf.merge(qu3,how='left',on='고객번호')
ldf = ldf.merge(qu4,how='left',on='고객번호')

# %%
ldf.fillna(0,inplace=True)

# %%
ldf = ldf.astype(int)

# %%
ldf.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1013/real_last_pay.csv',encoding='cp949')

# %%
quter_num1 = quter_1.groupby(['고객번호'])[['영수증번호']].count().reset_index().rename(columns={'영수증번호':'방문횟수_1'})
quter_num2 = quter_2.groupby(['고객번호'])[['영수증번호']].count().reset_index().rename(columns={'영수증번호':'방문횟수_2'})
quter_num3 = quter_3.groupby(['고객번호'])[['영수증번호']].count().reset_index().rename(columns={'영수증번호':'방문횟수_3'})
quter_num4 = quter_4.groupby(['고객번호'])[['영수증번호']].count().reset_index().rename(columns={'영수증번호':'방문횟수_4'})

# %%
def adder(data):
  result = data[1].merge(data[2],how='left',on='고객번호')
  result = result.merge(data[3],how='left',on='고객번호')
  result = result.merge(data[4],how='left',on='고객번호')
  return result

# %%
quter_count = adder([quter_1,quter_2,quter_3,quter_4])

# %%
ldf['CP'] = ldf['구매금액_4'] - ldf['구매금액_1']

# %%
def ltran(data):
  if data < 0 :
    result = 1
  elif data > 0 :
    result = 0
  else :
    result = '문제발생'
  return result

# %%
ldf['CP'] = ldf['CP'].apply(lambda x: ltran(x))

# %%
ldf['CP'].unique()
# Out:
# array([1, 0])

# %%
last_df = ldf[['고객번호','CP']]

# %%
result = result.merge(last_df,how='left',on='고객번호')

# %%
result.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1012/incheol_1013.csv',encoding='cp949')

# %%
result.drop('3P',axis=1,inplace=True)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')

def modeling(data,model):

  y = data[['CP']]
  x = data.drop(['CP'],axis=1)



  X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)


  if model == 'rf':  
    rf_clf = RandomForestClassifier(random_state=0)
    rf_clf.fit(X_train,y_train)
    rf_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test,rf_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'lr':
    lr_clf = LogisticRegression(random_state=0)
    lr_clf.fit(X_train,y_train)
    lr_pred = lr_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lr_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'xgb':
    xgb_clf = XGBClassifier(random_state=0)
    evals = [(X_test,y_test)]
    xgb_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    xgb_pred = xgb_clf.predict(X_test)
    accuracy = accuracy_score(y_test,xgb_pred)
    print(model,'정확도 : ',round(accuracy,2))
  elif model == 'lgbm':
    lgbm_clf = LGBMClassifier(random_state=0)
    evals = [(X_test,y_test)]
    lgbm_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    lgbm_pred = lgbm_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lgbm_pred)
    print(model,'정확도 : ',round(accuracy,2))

  else :
    print('모델 인자 값을 확인하세요')

# %%
li = ['rf','lr','xgb','lgbm']
for i in li:
  modeling(result,i)
# Out:
# rf 정확도 :  0.72
# lr 정확도 :  0.72
# xgb 정확도 :  0.73
# lgbm 정확도 :  0.74
