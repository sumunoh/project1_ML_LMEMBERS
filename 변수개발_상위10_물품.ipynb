# %%
import pandas as pd
cat_rate = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1012/cat_pay.csv',encoding='cp949',index_col=0)
cat_rate
# Out:
#         고객번호  가구/가전/전자기기_1  가구/가전/전자기기_2  ...    구매금액_2    구매금액_3    구매금액_4
# 0          1      0.010091      0.405447  ...  34116312  17298385  12717868
# 1          2      0.080269      0.033163  ...  21922100  27791610  25843820
# 2          3      0.000000      0.025802  ...   1042554    592280    667318
# 3          4      0.000000      0.094891  ...   4257510   3656937   3737257
# 4          5      0.009265      0.095384  ...   2225730   2934930   2616260
# ...      ...           ...           ...  ...       ...       ...       ...
# 19293  19376      0.000000      0.000000  ...    273297   2356111   3112696
# 19294  19377      0.000000      0.000000  ...    217360   2777062   2550720
# 19295  19378      0.000000      0.000000  ...    474760   9560756   6083224
# 19296  19379      0.000000      0.000000  ...   1190620   2379920   2175740
# 19297  19380      0.000000      0.018940  ...    522700    792750   2498327
#
# [19298 rows x 37 columns]

# %%
catos = cat_rate[['고객번호','구매금액_2','구매금액_3','구매금액_4']]
catos
# Out:
#         고객번호    구매금액_2    구매금액_3    구매금액_4
# 0          1  34116312  17298385  12717868
# 1          2  21922100  27791610  25843820
# 2          3   1042554    592280    667318
# 3          4   4257510   3656937   3737257
# 4          5   2225730   2934930   2616260
# ...      ...       ...       ...       ...
# 19293  19376    273297   2356111   3112696
# 19294  19377    217360   2777062   2550720
# 19295  19378    474760   9560756   6083224
# 19296  19379   1190620   2379920   2175740
# 19297  19380    522700    792750   2498327
#
# [19298 rows x 4 columns]

# %%
catos['구매변동_2-4']= catos['구매금액_4']-catos['구매금액_2']

# %%
catos
# Out:
#         고객번호    구매금액_2    구매금액_3    구매금액_4  구매변동_2-4
# 0          1  34116312  17298385  12717868 -21398444
# 1          2  21922100  27791610  25843820   3921720
# 2          3   1042554    592280    667318   -375236
# 3          4   4257510   3656937   3737257   -520253
# 4          5   2225730   2934930   2616260    390530
# ...      ...       ...       ...       ...       ...
# 19293  19376    273297   2356111   3112696   2839399
# 19294  19377    217360   2777062   2550720   2333360
# 19295  19378    474760   9560756   6083224   5608464
# 19296  19379   1190620   2379920   2175740    985120
# 19297  19380    522700    792750   2498327   1975627
#
# [19298 rows x 5 columns]

# %%
def cx(x):
  ''
  if x>=0:
    y=0
  elif x<0:
    y=1
  ''
  return y

# %%
catos['구매변동_2-4']=catos['구매변동_2-4'].apply(lambda x: cx(x))

# %%
catos
# Out:
#         고객번호    구매금액_2    구매금액_3    구매금액_4  구매변동_2-4
# 0          1  34116312  17298385  12717868         1
# 1          2  21922100  27791610  25843820         0
# 2          3   1042554    592280    667318         1
# 3          4   4257510   3656937   3737257         1
# 4          5   2225730   2934930   2616260         0
# ...      ...       ...       ...       ...       ...
# 19293  19376    273297   2356111   3112696         0
# 19294  19377    217360   2777062   2550720         0
# 19295  19378    474760   9560756   6083224         0
# 19296  19379   1190620   2379920   2175740         0
# 19297  19380    522700    792750   2498327         0
#
# [19298 rows x 5 columns]

# %%
catost = catos[['고객번호','구매변동_2-4']]
catost
# Out:
#         고객번호  구매변동_2-4
# 0          1         1
# 1          2         0
# 2          3         1
# 3          4         1
# 4          5         0
# ...      ...       ...
# 19293  19376         0
# 19294  19377         0
# 19295  19378         0
# 19296  19379         0
# 19297  19380         0
#
# [19298 rows x 2 columns]

# %%
catost
# Out:
#         고객번호  구매변동_2-4
# 0          1         1
# 1          2         0
# 2          3         1
# 3          4         1
# 4          5         0
# ...      ...       ...
# 19293  19376         0
# 19294  19377         0
# 19295  19378         0
# 19296  19379         0
# 19297  19380         0
#
# [19298 rows x 2 columns]

# %%
all_row = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1013/final_dataset.csv',encoding='cp949',index_col=0)
all_row
# Out:
#         고객번호  성별  연령대    구매금액_1  ...  1_중분류갯수  2_중분류갯수  3_중분류갯수  4_중분류갯수
# 0          1   1    5  19925355  ...       21       34       29       23
# 1          2   1    5  24323230  ...       19       23       26       21
# 2          3   1    5    851215  ...       21       22       16       23
# 3          4   0    5   5042106  ...       24       29       27       24
# 4          5   1    5   5460150  ...       18       14       12       13
# ...      ...  ..  ...       ...  ...      ...      ...      ...      ...
# 19142  19356   0    3    170160  ...       13       28       27       27
# 19143  19357   0    3     91950  ...        9       37       34       32
# 19144  19359   1    4     43190  ...        7       23       22       19
# 19145  19360   0    3    368050  ...       11       25       21       16
# 19146  19364   0    1   2032420  ...       12       32       27       21
#
# [19147 rows x 63 columns]

# %%
all_row.columns
# Out:
# Index(['고객번호', '성별', '연령대', '구매금액_1', '구매금액_2', '구매금액_3', '구매금액_4', '구매금액_1_A',
#        '구매금액_1_B', '구매금액_1_C', '구매금액_1_D', '구매금액_2_A', '구매금액_2_B', '구매금액_2_C',
#        '구매금액_2_D', '구매금액_3_A', '구매금액_3_B', '구매금액_3_C', '구매금액_3_D', '구매금액_4_A',
#        '구매금액_4_B', '구매금액_4_C', '구매금액_4_D', '가구/가전/전자기기_1', '가구/가전/전자기기_2',
#        '가구/가전/전자기기_3', '가구/가전/전자기기_4', '기타_1', '기타_2', '기타_3', '기타_4',
#        '생활/건강_1', '생활/건강_2', '생활/건강_3', '생활/건강_4', '식품_1', '식품_2', '식품_3',
#        '식품_4', '의류/잡화_1', '의류/잡화_2', '의류/잡화_3', '의류/잡화_4', '반려/취미/문구/도서_1',
#        '반려/취미/문구/도서_2', '반려/취미/문구/도서_3', '반려/취미/문구/도서_4', '스포츠/레저/자동차_1',
#        '스포츠/레저/자동차_2', '스포츠/레저/자동차_3', '스포츠/레저/자동차_4', '출산유아동_1', '출산유아동_2',
#        '출산유아동_3', '출산유아동_4', '방문횟수_1', '방문횟수_2', '방문횟수_3', '방문횟수_4', '1_중분류갯수',
#        '2_중분류갯수', '3_중분류갯수', '4_중분류갯수'],
#       dtype='object')

# %%
all_row2 = all_row[['고객번호', '성별', '연령대','구매금액_1', '구매금액_2', '구매금액_3','구매금액_1_A','구매금액_2_A','구매금액_3_A',
         '구매금액_1_B','구매금액_2_B','구매금액_3_B','구매금액_1_C','구매금액_2_C','구매금액_3_C','구매금액_1_D','구매금액_2_D','구매금액_3_D',
         '가구/가전/전자기기_1', '가구/가전/전자기기_2','가구/가전/전자기기_3','기타_1', '기타_2', '기타_3','생활/건강_1', '생활/건강_2', '생활/건강_3',
         '식품_1', '식품_2', '식품_3','의류/잡화_1', '의류/잡화_2', '의류/잡화_3','반려/취미/문구/도서_1',
       '반려/취미/문구/도서_2', '반려/취미/문구/도서_3', '스포츠/레저/자동차_1',
       '스포츠/레저/자동차_2', '스포츠/레저/자동차_3','출산유아동_1', '출산유아동_2',
       '출산유아동_3','방문횟수_1', '방문횟수_2', '방문횟수_3','1_중분류갯수',
       '2_중분류갯수', '3_중분류갯수']]

# %%
all_row2
# Out:
#         고객번호  성별  연령대    구매금액_1  ...  방문횟수_3  1_중분류갯수  2_중분류갯수  3_중분류갯수
# 0          1   1    5  19925355  ...     312       21       34       29
# 1          2   1    5  24323230  ...     261       19       23       26
# 2          3   1    5    851215  ...     220       21       22       16
# 3          4   0    5   5042106  ...     263       24       29       27
# 4          5   1    5   5460150  ...     123       18       14       12
# ...      ...  ..  ...       ...  ...     ...      ...      ...      ...
# 19142  19356   0    3    170160  ...     434       13       28       27
# 19143  19357   0    3     91950  ...     453        9       37       34
# 19144  19359   1    4     43190  ...     412        7       23       22
# 19145  19360   0    3    368050  ...     152       11       25       21
# 19146  19364   0    1   2032420  ...     254       12       32       27
#
# [19147 rows x 48 columns]

# %%
all_row2.rename(columns={'1_중분류갯수':'중분류갯수_1',	'2_중분류갯수':'중분류갯수_2','3_중분류갯수':'중분류갯수_3'},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
all_row2
# Out:
#         고객번호  성별  연령대    구매금액_1  ...  방문횟수_3  중분류갯수_1  중분류갯수_2  중분류갯수_3
# 0          1   1    5  19925355  ...     312       21       34       29
# 1          2   1    5  24323230  ...     261       19       23       26
# 2          3   1    5    851215  ...     220       21       22       16
# 3          4   0    5   5042106  ...     263       24       29       27
# 4          5   1    5   5460150  ...     123       18       14       12
# ...      ...  ..  ...       ...  ...     ...      ...      ...      ...
# 19142  19356   0    3    170160  ...     434       13       28       27
# 19143  19357   0    3     91950  ...     453        9       37       34
# 19144  19359   1    4     43190  ...     412        7       23       22
# 19145  19360   0    3    368050  ...     152       11       25       21
# 19146  19364   0    1   2032420  ...     254       12       32       27
#
# [19147 rows x 48 columns]

# %%
all_row2.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1013/final_dataset_cut.csv',encoding='cp949')

# %%
s=[8436080	,5543340	,2379680	,349680	,53300	,177800	,486780	,433540	,3493332	,1803640	,98340	,440800	,334580	,662,	62]

# %%
def cat(x,i):
  k = s[i]/9
  ''
  if x==0:
    y=1
  elif x<k:
    y=2
  elif x<2*k:
    y=3
  elif x<3*k:
    y=4
  elif x<4*k:
    y=5
  elif x<5*k:
    y=6
  elif x<6*k:
    y=7
  elif x<7*k:
    y=8
  elif x<8*k:
    y=9
  elif x<9*k:
    y=10
  elif x<10*k:
    y=11
  elif x<11*k:
    y=12    
  elif x<12*k:
    y=13
  elif x<13*k:
    y=14
  elif 13*k<=x:
    y=15
    ''
  return y

# %%
all_row2.columns
# Out:
# Index(['고객번호', '성별', '연령대', '구매금액_1', '구매금액_2', '구매금액_3', '구매금액_1_A',
#        '구매금액_2_A', '구매금액_3_A', '구매금액_1_B', '구매금액_2_B', '구매금액_3_B', '구매금액_1_C',
#        '구매금액_2_C', '구매금액_3_C', '구매금액_1_D', '구매금액_2_D', '구매금액_3_D',
#        '가구/가전/전자기기_1', '가구/가전/전자기기_2', '가구/가전/전자기기_3', '기타_1', '기타_2', '기타_3',
#        '생활/건강_1', '생활/건강_2', '생활/건강_3', '식품_1', '식품_2', '식품_3', '의류/잡화_1',
#        '의류/잡화_2', '의류/잡화_3', '반려/취미/문구/도서_1', '반려/취미/문구/도서_2', '반려/취미/문구/도서_3',
#        '스포츠/레저/자동차_1', '스포츠/레저/자동차_2', '스포츠/레저/자동차_3', '출산유아동_1', '출산유아동_2',
#        '출산유아동_3', '방문횟수_1', '방문횟수_2', '방문횟수_3', '중분류갯수_1', '중분류갯수_2',
#        '중분류갯수_3'],
#       dtype='object')

# %%
all_row23 = ['구매금액_1', '구매금액_2', '구매금액_3', '구매금액_1_A',
       '구매금액_2_A', '구매금액_3_A', '구매금액_1_B', '구매금액_2_B', '구매금액_3_B', '구매금액_1_C',
       '구매금액_2_C', '구매금액_3_C', '구매금액_1_D', '구매금액_2_D', '구매금액_3_D',
       '가구/가전/전자기기_1', '가구/가전/전자기기_2', '가구/가전/전자기기_3', '기타_1', '기타_2', '기타_3',
       '생활/건강_1', '생활/건강_2', '생활/건강_3', '식품_1', '식품_2', '식품_3', '의류/잡화_1',
       '의류/잡화_2', '의류/잡화_3', '반려/취미/문구/도서_1', '반려/취미/문구/도서_2', '반려/취미/문구/도서_3',
       '스포츠/레저/자동차_1', '스포츠/레저/자동차_2', '스포츠/레저/자동차_3', '출산유아동_1', '출산유아동_2',
       '출산유아동_3', '방문횟수_1', '방문횟수_2', '방문횟수_3', '중분류갯수_1', '중분류갯수_2',
       '중분류갯수_3']

# %%
for i in range(15):
  j=3*i
  all_row2[all_row23[j]] = all_row2[all_row23[j]].apply(lambda x : cat(x,i))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
for i in range(15):
  j=3*i+1
  all_row2[all_row23[j]] = all_row2[all_row23[j]].apply(lambda x : cat(x,i))

for i in range(15):
  j=3*i+2
  all_row2[all_row23[j]] = all_row2[all_row23[j]].apply(lambda x : cat(x,i))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
all_row2
# Out:
#         고객번호  성별  연령대  구매금액_1  ...  방문횟수_3  중분류갯수_1  중분류갯수_2  중분류갯수_3
# 0          1   1    5      15  ...       6        5        6        6
# 1          2   1    5      15  ...       5        4        5        5
# 2          3   1    5       2  ...       4        5        5        4
# 3          4   0    5       7  ...       5        5        6        5
# 4          5   1    5       7  ...       3        4        4        3
# ...      ...  ..  ...     ...  ...     ...      ...      ...      ...
# 19142  19356   0    3       2  ...       7        3        6        5
# 19143  19357   0    3       2  ...       8        3        7        6
# 19144  19359   1    4       2  ...       7        3        5        5
# 19145  19360   0    3       2  ...       4        3        5        5
# 19146  19364   0    1       4  ...       5        3        6        5
#
# [19147 rows x 48 columns]

# %%
all_row2['중분류갯수_3'].value_counts()
# Out:
# 6     5330
# 7     4360
# 5     4191
# 4     2249
# 8     2204
# 3      388
# 9      314
# 2       91
# 10      20
# Name: 중분류갯수_3, dtype: int64

# %%
all_row3=all_row2.copy()

# %%
all_row3.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1013/15등급_all.csv',encoding='cp949')

# %%
all_row3
# Out:
#         고객번호  성별  연령대  구매금액_1  ...  방문횟수_3  중분류갯수_1  중분류갯수_2  중분류갯수_3
# 0          1   1    5      15  ...       6        5        6        6
# 1          2   1    5      15  ...       5        4        5        5
# 2          3   1    5       2  ...       4        5        5        4
# 3          4   0    5       7  ...       5        5        6        5
# 4          5   1    5       7  ...       3        4        4        3
# ...      ...  ..  ...     ...  ...     ...      ...      ...      ...
# 19142  19356   0    3       2  ...       7        3        6        5
# 19143  19357   0    3       2  ...       8        3        7        6
# 19144  19359   1    4       2  ...       7        3        5        5
# 19145  19360   0    3       2  ...       4        3        5        5
# 19146  19364   0    1       4  ...       5        3        6        5
#
# [19147 rows x 48 columns]

# %%
all_row3.columns
# Out:
# Index(['고객번호', '성별', '연령대', '구매금액_1', '구매금액_2', '구매금액_3', '구매금액_1_A',
#        '구매금액_2_A', '구매금액_3_A', '구매금액_1_B', '구매금액_2_B', '구매금액_3_B', '구매금액_1_C',
#        '구매금액_2_C', '구매금액_3_C', '구매금액_1_D', '구매금액_2_D', '구매금액_3_D',
#        '가구/가전/전자기기_1', '가구/가전/전자기기_2', '가구/가전/전자기기_3', '기타_1', '기타_2', '기타_3',
#        '생활/건강_1', '생활/건강_2', '생활/건강_3', '식품_1', '식품_2', '식품_3', '의류/잡화_1',
#        '의류/잡화_2', '의류/잡화_3', '반려/취미/문구/도서_1', '반려/취미/문구/도서_2', '반려/취미/문구/도서_3',
#        '스포츠/레저/자동차_1', '스포츠/레저/자동차_2', '스포츠/레저/자동차_3', '출산유아동_1', '출산유아동_2',
#        '출산유아동_3', '방문횟수_1', '방문횟수_2', '방문횟수_3', '중분류갯수_1', '중분류갯수_2',
#        '중분류갯수_3'],
#       dtype='object')

# %%
ss = ['고객번호', '성별', '연령대', '구매금액_1', '구매금액_2', '구매금액_3', '구매금액_1_A',
       '구매금액_2_A', '구매금액_3_A', '구매금액_1_B', '구매금액_2_B', '구매금액_3_B', '구매금액_1_C',
       '구매금액_2_C', '구매금액_3_C', '구매금액_1_D', '구매금액_2_D', '구매금액_3_D',
       '가구/가전/전자기기_1', '가구/가전/전자기기_2', '가구/가전/전자기기_3', '기타_1', '기타_2', '기타_3',
       '생활/건강_1', '생활/건강_2', '생활/건강_3', '식품_1', '식품_2', '식품_3', '의류/잡화_1',
       '의류/잡화_2', '의류/잡화_3', '반려/취미/문구/도서_1', '반려/취미/문구/도서_2', '반려/취미/문구/도서_3',
       '스포츠/레저/자동차_1', '스포츠/레저/자동차_2', '스포츠/레저/자동차_3', '출산유아동_1', '출산유아동_2',
       '출산유아동_3', '방문횟수_1', '방문횟수_2', '방문횟수_3', '중분류갯수_1', '중분류갯수_2',
       '중분류갯수_3']

# %%
vv = ['고객번호', '성별', '연령대', '구매금액_1P', '구매금액_2P', '구매금액_1_3P', '구매금액_1P_A',
       '구매금액_2P_A', '구매금액_1_3P_A', '구매금액_1P_B', '구매금액_2P_B', '구매금액_1_3P_B', '구매금액_1P_C',
       '구매금액_2P_C', '구매금액_1_3P_C', '구매금액_1P_D', '구매금액_2P_D', '구매금액_1_3P_D',
       '가구/가전/전자기기_1P', '가구/가전/전자기기_2P', '가구/가전/전자기기_1_3P', '기타_1P', '기타_2P', '기타_1_3P',
       '생활/건강_1P', '생활/건강_2P', '생활/건강_1_3P', '식품_1P', '식품_2P', '식품_1_3P', '의류/잡화_1P',
       '의류/잡화_2P', '의류/잡화_1_3P', '반려/취미/문구/도서_1P', '반려/취미/문구/도서_2P', '반려/취미/문구/도서_1_3P',
       '스포츠/레저/자동차_1P', '스포츠/레저/자동차_2P', '스포츠/레저/자동차_1_3P', '출산유아동_1P', '출산유아동_2P',
       '출산유아동_1_3P', '방문횟수_1P', '방문횟수_2P', '방문횟수_1_3P', '중분류갯수_1P', '중분류갯수_2P',
       '중분류갯수_1_3P']

# %%
for i in range(1,16):
    j=3*i
    all_row3[vv[j]]=all_row3[ss[j+1]]-all_row3[ss[j]]
    all_row3[vv[j+1]]=all_row3[ss[j+2]]-all_row3[ss[j+1]]
    all_row3[vv[j+2]]=all_row3[ss[j+2]]-all_row3[ss[j]]

# %%
all_row3
# Out:
#         고객번호  성별  연령대  구매금액_1  ...  방문횟수_1_3P  중분류갯수_1P  중분류갯수_2P  중분류갯수_1_3P
# 0          1   1    5      15  ...          1         1         0           1
# 1          2   1    5      15  ...         -1         1         0           1
# 2          3   1    5       2  ...         -2         0        -1          -1
# 3          4   0    5       7  ...          0         1        -1           0
# 4          5   1    5       7  ...         -4         0        -1          -1
# ...      ...  ..  ...     ...  ...        ...       ...       ...         ...
# 19142  19356   0    3       2  ...          5         3        -1           2
# 19143  19357   0    3       2  ...          6         4        -1           3
# 19144  19359   1    4       2  ...          5         2         0           2
# 19145  19360   0    3       2  ...          2         2         0           2
# 19146  19364   0    1       4  ...          2         3        -1           2
#
# [19147 rows x 93 columns]

# %%
all_row3.columns
# Out:
# Index(['고객번호', '성별', '연령대', '구매금액_1', '구매금액_2', '구매금액_3', '구매금액_1_A',
#        '구매금액_2_A', '구매금액_3_A', '구매금액_1_B', '구매금액_2_B', '구매금액_3_B', '구매금액_1_C',
#        '구매금액_2_C', '구매금액_3_C', '구매금액_1_D', '구매금액_2_D', '구매금액_3_D',
#        '가구/가전/전자기기_1', '가구/가전/전자기기_2', '가구/가전/전자기기_3', '기타_1', '기타_2', '기타_3',
#        '생활/건강_1', '생활/건강_2', '생활/건강_3', '식품_1', '식품_2', '식품_3', '의류/잡화_1',
#        '의류/잡화_2', '의류/잡화_3', '반려/취미/문구/도서_1', '반려/취미/문구/도서_2', '반려/취미/문구/도서_3',
#        '스포츠/레저/자동차_1', '스포츠/레저/자동차_2', '스포츠/레저/자동차_3', '출산유아동_1', '출산유아동_2',
#        '출산유아동_3', '방문횟수_1', '방문횟수_2', '방문횟수_3', '중분류갯수_1', '중분류갯수_2',
#        '중분류갯수_3', '구매금액_1P', '구매금액_2P', '구매금액_1_3P', '구매금액_1P_A', '구매금액_2P_A',
#        '구매금액_1_3P_A', '구매금액_1P_B', '구매금액_2P_B', '구매금액_1_3P_B', '구매금액_1P_C',
#        '구매금액_2P_C', '구매금액_1_3P_C', '구매금액_1P_D', '구매금액_2P_D', '구매금액_1_3P_D',
#        '가구/가전/전자기기_1P', '가구/가전/전자기기_2P', '가구/가전/전자기기_1_3P', '기타_1P', '기타_2P',
# ...

# %%
all_row4=all_row3[['고객번호', '성별', '연령대', '구매금액_1P', '구매금액_2P', '구매금액_1_3P', '구매금액_1P_A', '구매금액_2P_A',
       '구매금액_1_3P_A', '구매금액_1P_B', '구매금액_2P_B', '구매금액_1_3P_B', '구매금액_1P_C',
       '구매금액_2P_C', '구매금액_1_3P_C', '구매금액_1P_D', '구매금액_2P_D', '구매금액_1_3P_D',
       '가구/가전/전자기기_1P', '가구/가전/전자기기_2P', '가구/가전/전자기기_1_3P', '기타_1P', '기타_2P',
       '기타_1_3P', '생활/건강_1P', '생활/건강_2P', '생활/건강_1_3P', '식품_1P', '식품_2P',
       '식품_1_3P', '의류/잡화_1P', '의류/잡화_2P', '의류/잡화_1_3P', '반려/취미/문구/도서_1P',
       '반려/취미/문구/도서_2P', '반려/취미/문구/도서_1_3P', '스포츠/레저/자동차_1P', '스포츠/레저/자동차_2P',
       '스포츠/레저/자동차_1_3P', '출산유아동_1P', '출산유아동_2P', '출산유아동_1_3P', '방문횟수_1P',
       '방문횟수_2P', '방문횟수_1_3P', '중분류갯수_1P', '중분류갯수_2P', '중분류갯수_1_3P']]

# %%
all_row4.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1013/15등급_gap.csv',encoding='cp949')

# %%
all_row4
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  방문횟수_1_3P  중분류갯수_1P  중분류갯수_2P  중분류갯수_1_3P
# 0          1   1    5        0  ...          1         1         0           1
# 1          2   1    5        0  ...         -1         1         0           1
# 2          3   1    5        1  ...         -2         0        -1          -1
# 3          4   0    5       -1  ...          0         1        -1           0
# 4          5   1    5       -3  ...         -4         0        -1          -1
# ...      ...  ..  ...      ...  ...        ...       ...       ...         ...
# 19142  19356   0    3        1  ...          5         3        -1           2
# 19143  19357   0    3        3  ...          6         4        -1           3
# 19144  19359   1    4        1  ...          5         2         0           2
# 19145  19360   0    3        2  ...          2         2         0           2
# 19146  19364   0    1        5  ...          2         3        -1           2
#
# ...

# %%
import pandas as pd
all_15 = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1013/15등급_all.csv',encoding='cp949',index_col=0)
all_15
# Out:
#         고객번호  성별  연령대  구매금액_1  ...  방문횟수_3  중분류갯수_1  중분류갯수_2  중분류갯수_3
# 0          1   1    5      15  ...       6        5        6        6
# 1          2   1    5      15  ...       5        4        5        5
# 2          3   1    5       2  ...       4        5        5        4
# 3          4   0    5       7  ...       5        5        6        5
# 4          5   1    5       7  ...       3        4        4        3
# ...      ...  ..  ...     ...  ...     ...      ...      ...      ...
# 19142  19356   0    3       2  ...       7        3        6        5
# 19143  19357   0    3       2  ...       8        3        7        6
# 19144  19359   1    4       2  ...       7        3        5        5
# 19145  19360   0    3       2  ...       4        3        5        5
# 19146  19364   0    1       4  ...       5        3        6        5
#
# [19147 rows x 48 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cat_rate = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1012/cat_pay.csv',encoding='cp949',index_col=0)
cat_rate
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-593ecf173e6e> in <module>()
# ----> 1 cat_rate = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1012/cat_pay.csv',encoding='cp949',index_col=0)
#       2 cat_rate
#
# NameError: name 'pd' is not defined

# %%
cat_rate.columns
# Out:
# Index(['고객번호', '가구/가전/전자기기_1', '가구/가전/전자기기_2', '가구/가전/전자기기_3', '가구/가전/전자기기_4',
#        '기타_1', '기타_2', '기타_3', '기타_4', '생활/건강_1', '생활/건강_2', '생활/건강_3',
#        '생활/건강_4', '식품_1', '식품_2', '식품_3', '식품_4', '의류/잡화_1', '의류/잡화_2',
#        '의류/잡화_3', '의류/잡화_4', '반려/취미/문구/도서_1', '반려/취미/문구/도서_2', '반려/취미/문구/도서_3',
#        '반려/취미/문구/도서_4', '스포츠/레저/자동차_1', '스포츠/레저/자동차_2', '스포츠/레저/자동차_3',
#        '스포츠/레저/자동차_4', '출산유아동_1', '출산유아동_2', '출산유아동_3', '출산유아동_4', '구매금액_1',
#        '구매금액_2', '구매금액_3', '구매금액_4'],
#       dtype='object')

# %%
import pandas as pd
aaa = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/ppcd_df.csv',encoding='cp949',index_col=0)
aaa
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#          제휴사    영수증번호    소분류코드   고객번호      구매일자  ...   대분류명  뉴중분류명 성별  연령대 거주지역
# 0          B  8664000  B150401  17218  20140222  ...     식품     음료  F  50대  100
# 1          B  8664000  B160101  17218  20140222  ...     식품     주류  F  50대  100
# 2          B  8664000  B160201  17218  20140222  ...     식품     주류  F  50대  100
# 3          B  8664000  B180301  17218  20140222  ...  생활/건강   여성용품  F  50대  100
# 4          B  8664001  B050901  17674  20140222  ...     식품    농산품  F  30대  100
# ...       ..      ...      ...    ...       ...  ...    ...    ... ..  ...  ...
# 28593025   B  7693179  B150101   8397  20140129  ...     식품     음료  M  30대  100
# 28593026   B  7693180  B480202  15386  20140129  ...     식품     육류  F  50대  100
# ...

# %%
time_all = aaa[aaa['구매일자']<=20141231]
time_all
# Out:
#          제휴사    영수증번호    소분류코드   고객번호      구매일자  ...   대분류명  뉴중분류명 성별  연령대 거주지역
# 0          B  8664000  B150401  17218  20140222  ...     식품     음료  F  50대  100
# 1          B  8664000  B160101  17218  20140222  ...     식품     주류  F  50대  100
# 2          B  8664000  B160201  17218  20140222  ...     식품     주류  F  50대  100
# 3          B  8664000  B180301  17218  20140222  ...  생활/건강   여성용품  F  50대  100
# 4          B  8664001  B050901  17674  20140222  ...     식품    농산품  F  30대  100
# ...       ..      ...      ...    ...       ...  ...    ...    ... ..  ...  ...
# 28593025   B  7693179  B150101   8397  20140129  ...     식품     음료  M  30대  100
# 28593026   B  7693180  B480202  15386  20140129  ...     식품     육류  F  50대  100
# 28593027   B  7693181  B160402   9835  20140129  ...     식품     음료  F  30대  100
# 28593028   B  7693181  B580102   9835  20140129  ...     식품     육류  F  30대  100
# 28593029   B  7693185  B100305  13806  20140129  ...     식품    유제품  F  40대  100
#
# ...

# %%
time_all = all[all['구매일자']<=20141231]
bbb = time_all.sort_values(by=['구매금액'],ascending=False)
bbb
# Out:
#          제휴사     영수증번호    소분류코드   고객번호  ...     뉴중분류명  성별  연령대 거주지역
# 11714577   A   1416069  A080106  14323  ...        명품   M  30대  100
# 6745611    A   1500785  A080106  14323  ...        명품   M  30대  100
# 16213899   A   1677262  A080106  14323  ...        명품   M  30대  100
# 11259392   A   2220608  A020303   8079  ...        화장   M  30대  100
# 10092999   A   1862939  A080106  14323  ...        명품   M  30대  100
# ...       ..       ...      ...    ...  ...       ...  ..  ...  ...
# 8824068    C  10235205  C160104  18496  ...  세제/방향/탈취   F  50대  500
# 4065547    C    461396  C030505  12552  ...       농산품   M  30대  100
# 20484880   B  10627200  B270315  13652  ...        반려   F  30대  540
# 11368102   C    639002  C060506  10452  ...      가공식품   M  40대  100
# 26950256   B  10699136  B180201  13476  ...      생활잡화   M  40대  610
#
# [13871514 rows x 13 columns]

# %%
bbb.reset_index(inplace=True)

# %%
bbb
# Out:
#              index 제휴사     영수증번호    소분류코드  ...     뉴중분류명  성별  연령대  거주지역
# 0         11714577   A   1416069  A080106  ...        명품   M  30대   100
# 1          6745611   A   1500785  A080106  ...        명품   M  30대   100
# 2         16213899   A   1677262  A080106  ...        명품   M  30대   100
# 3         11259392   A   2220608  A020303  ...        화장   M  30대   100
# 4         10092999   A   1862939  A080106  ...        명품   M  30대   100
# ...            ...  ..       ...      ...  ...       ...  ..  ...   ...
# 13871509   8824068   C  10235205  C160104  ...  세제/방향/탈취   F  50대   500
# 13871510   4065547   C    461396  C030505  ...       농산품   M  30대   100
# 13871511  20484880   B  10627200  B270315  ...        반려   F  30대   540
# 13871512  11368102   C    639002  C060506  ...      가공식품   M  40대   100
# 13871513  26950256   B  10699136  B180201  ...      생활잡화   M  40대   610
#
# [13871514 rows x 14 columns]

# %%
bbb['구매금액'].sum()
# Out:
# 329601840581

# %%
a = 258738072622/329601840581
a
# Out:
# 0.7850019046189606

# %%
b = 329601840581-258738072622
b
# Out:
# 70863767959

# %%
a1 = 13871514/10
a25 = 28593029/4

# %%
bbb.iloc[[a1]]
# Out:
#             index 제휴사    영수증번호    소분류코드  고객번호  ...  대분류명  뉴중분류명  성별    연령대 거주지역
# 1387151  25876705   B  6450546  B060114   679  ...    식품    수산품   F  60세이상   60
#
# [1 rows x 14 columns]

# %%
ccc = bbb[bbb['구매금액']>29000]
ccc
# Out:
#             index 제휴사    영수증번호    소분류코드   고객번호  ...   대분류명  뉴중분류명  성별  연령대 거주지역
# 0        11714577   A  1416069  A080106  14323  ...  의류/잡화     명품   M  30대  100
# 1         6745611   A  1500785  A080106  14323  ...  의류/잡화     명품   M  30대  100
# 2        16213899   A  1677262  A080106  14323  ...  의류/잡화     명품   M  30대  100
# 3        11259392   A  2220608  A020303   8079  ...     기타     화장   M  30대  100
# 4        10092999   A  1862939  A080106  14323  ...  의류/잡화     명품   M  30대  100
# ...           ...  ..      ...      ...    ...  ...    ...    ...  ..  ...  ...
# 1365680  28363684   B  9116154  B460305  12858  ...     식품     육류   F  30대  100
# 1365681  24322336   B  7720038  B480301   5469  ...     식품     육류   F  40대   30
# 1365682   8595102   C  5899081  C050414  12552  ...     식품     육류   M  30대  100
# 1365683  15067549   C  5922198  C050408   3628  ...     식품     육류   F  40대   27
# 1365684  27952018   B  7992412  B480203  11067  ...     식품     육류   F  40대  100
#
# ...

# %%
ccc['구매금액'].sum()
# Out:
# 258738072622

# %%
time_1 = ccc[(ccc['구매일자']<=20140630)]
time_2 = ccc[(ccc['구매일자']>20140630)&(ccc['구매일자']<=20141231)]
time_3 = ccc[(ccc['구매일자']<=20150630)&(ccc['구매일자']>20141231)]
time_4 = ccc[(ccc['구매일자']<=20151231)&(ccc['구매일자']>20150630)]

# %%
time_1_c = time_1.groupby('고객번호')['index'].count()
time_2_c = time_2.groupby('고객번호')['index'].count()
time_3_c = time_3.groupby('고객번호')['index'].count()
time_4_c = time_4.groupby('고객번호')['index'].count()

# %%
time_1_c = time_1_c.reset_index()

# %%
time_1_c[time_1_c['고객번호']==14323]
# Out:
#         고객번호  index
# 14069  14323      9

# %%
p = tot[['고객번호']]
p
# Out:
#         고객번호
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
# ...      ...
# 19142  19356
# 19143  19357
# 19144  19359
# 19145  19360
# 19146  19364
#
# [19147 rows x 1 columns]

# %%
p.drop_duplicates(inplace=True)
p
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         고객번호
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
# ...      ...
# 19142  19356
# 19143  19357
# 19144  19359
# 19145  19360
# 19146  19364
#
# [19147 rows x 1 columns]

# %%
p =pd.merge(p,time_1_c,on='고객번호',how='left')
p =pd.merge(p,time_2_c,on='고객번호',how='left')
p =pd.merge(p,time_3_c,on='고객번호',how='left')
p
# Out:
#         고객번호  index_x  index_y  index
# 0          1    114.0    122.0   87.0
# 1          2    124.0    104.0  118.0
# 2          3      1.0      NaN    2.0
# 3          4     40.0     31.0   24.0
# 4          5     31.0     17.0   12.0
# ...      ...      ...      ...    ...
# 19142  19356      1.0      6.0    4.0
# 19143  19357      NaN     16.0   10.0
# 19144  19359      NaN      1.0    1.0
# 19145  19360      2.0     10.0   10.0
# 19146  19364     19.0     51.0   28.0
#
# [19147 rows x 4 columns]

# %%
p.describe()
# Out:
#                고객번호       index_x       index_y         index
# count  19147.000000  18772.000000  18921.000000  18885.000000
# mean    9631.673891     36.407788     38.099678     37.927244
# std     5572.190726     35.091557     34.703643     35.855762
# min        1.000000      1.000000      1.000000      1.000000
# 25%     4810.500000     10.000000     11.000000     11.000000
# 50%     9614.000000     24.000000     26.000000     25.000000
# 75%    14441.500000     55.000000     58.000000     57.000000
# max    19364.000000    481.000000    377.000000    685.000000

# %%
p.fillna(0,inplace=True)

# %%
p
# Out:
#         고객번호  index_x  index_y  index
# 0          1    114.0    122.0   87.0
# 1          2    124.0    104.0  118.0
# 2          3      1.0      0.0    2.0
# 3          4     40.0     31.0   24.0
# 4          5     31.0     17.0   12.0
# ...      ...      ...      ...    ...
# 19142  19356      1.0      6.0    4.0
# 19143  19357      0.0     16.0   10.0
# 19144  19359      0.0      1.0    1.0
# 19145  19360      2.0     10.0   10.0
# 19146  19364     19.0     51.0   28.0
#
# [19147 rows x 4 columns]

# %%
p['index_x'] = p['index_x'].astype(int)
p['index_y'] = p['index_y'].astype(int)
p['index'] = p['index'].astype(int)

# %%
p.columns=['고객번호','상위10%물품_1','상위10%물품_2','상위10%물품_3']

# %%
p
# Out:
#         고객번호  상위10%물품_1  상위10%물품_2  상위10%물품_3
# 0          1        114        122         87
# 1          2        124        104        118
# 2          3          1          0          2
# 3          4         40         31         24
# 4          5         31         17         12
# ...      ...        ...        ...        ...
# 19142  19356          1          6          4
# 19143  19357          0         16         10
# 19144  19359          0          1          1
# 19145  19360          2         10         10
# 19146  19364         19         51         28
#
# [19147 rows x 4 columns]

# %%
def catr(x):
  k = 5
  ''
  if x==0:
    y=1
  elif x<k:
    y=2
  elif x<2*k:
    y=3
  elif x<3*k:
    y=4
  elif x<4*k:
    y=5
  elif x<5*k:
    y=6
  elif x<6*k:
    y=7
  elif x<7*k:
    y=8
  elif x<8*k:
    y=9
  elif x<9*k:
    y=10
  elif x<10*k:
    y=11
  elif x<11*k:
    y=12    
  elif x<12*k:
    y=13
  elif x<13*k:
    y=14
  elif x<14*k:
    y=15
  elif x<15*k:
    y=16
  elif x<16*k:
    y=17
  elif x<17*k:
    y=18
  elif x<18*k:
    y=19
  elif 18*k<=x:
    y=20
    ''
  return y

# %%
p['상위10%물품_1'] = p['상위10%물품_1'].apply(lambda x: catr(x))
p['상위10%물품_2'] = p['상위10%물품_2'].apply(lambda x: catr(x))
p['상위10%물품_3'] = p['상위10%물품_3'].apply(lambda x: catr(x))

# %%
p['상위10%물품_1'].value_counts()
# Out:
# 3     2573
# 4     2139
# 2     1897
# 20    1689
# 5     1653
# 6     1313
# 7     1069
# 8      866
# 9      731
# 10     653
# 12     583
# 13     556
# 11     540
# 15     493
# 14     475
# 16     449
# 17     411
# 1      375
# 18     360
# 19     322
# Name: 상위10%물품_1, dtype: int64

# %%
p['상위10%물품_1P']=p['상위10%물품_2']-p['상위10%물품_1']
p['상위10%물품_2P']=p['상위10%물품_3']-p['상위10%물품_2']
p['상위10%물품_1_3P']=p['상위10%물품_3']-p['상위10%물품_1']

# %%
p.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1014/상위10%_total.csv',encoding='cp949')

# %%
p2=p[['고객번호','상위10%물품_1P','상위10%물품_2P','상위10%물품_1_3P']]

# %%
p2.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1014/상위10%_gap.csv',encoding='cp949')

# %%
p2
# Out:
#         고객번호  상위10%물품_1P  상위10%물품_2P  상위10%물품_1_3P
# 0          1           0          -1            -1
# 1          2           0           0             0
# 2          3          -1           1             0
# 3          4          -2          -2            -4
# 4          5          -3          -1            -4
# ...      ...         ...         ...           ...
# 19142  19356           1          -1             0
# 19143  19357           4          -1             3
# 19144  19359           1           0             1
# 19145  19360           2           0             2
# 19146  19364           7          -5             2
#
# [19147 rows x 4 columns]

# %%
p2['상위10%물품_1P'].value_counts()
# Out:
#  0     5103
#  1     3382
# -1     2628
#  2     1832
# -2     1338
#  3     1048
# -3      724
#  4      636
#  5      504
# -4      470
#  6      290
# -5      280
#  7      172
# -6      159
#  8      123
# -7       91
# -8       76
#  9       53
#  10      42
#  11      39
# -9       38
#  12      21
# -10      18
#  13      14
# -11      12
# -12      10
#  14      10
#  17       8
#  16       6
#  15       5
# -14       5
# -13       3
# -15       2
# -17       2
#  19       1
#  18       1
# -18       1
# Name: 상위10%물품_1P, dtype: int64

# %%
tot =pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1013/15등급_gap.csv',encoding='cp949',index_col=0)
tot
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  방문횟수_1_3P  중분류갯수_1P  중분류갯수_2P  중분류갯수_1_3P
# 0          1   1    5        0  ...          1         1         0           1
# 1          2   1    5        0  ...         -1         1         0           1
# 2          3   1    5        1  ...         -2         0        -1          -1
# 3          4   0    5       -1  ...          0         1        -1           0
# 4          5   1    5       -3  ...         -4         0        -1          -1
# ...      ...  ..  ...      ...  ...        ...       ...       ...         ...
# 19142  19356   0    3        1  ...          5         3        -1           2
# 19143  19357   0    3        3  ...          6         4        -1           3
# 19144  19359   1    4        1  ...          5         2         0           2
# 19145  19360   0    3        2  ...          2         2         0           2
# 19146  19364   0    1        5  ...          2         3        -1           2
#
# ...

# %%
ppap = pd.merge(tot,p2, on='고객번호',how='left')
ppap
# Out:
#         고객번호  성별  연령대  ...  상위10%물품_1P  상위10%물품_2P  상위10%물품_1_3P
# 0          1   1    5  ...           0          -1            -1
# 1          2   1    5  ...           0           0             0
# 2          3   1    5  ...          -1           1             0
# 3          4   0    5  ...          -2          -2            -4
# 4          5   1    5  ...          -3          -1            -4
# ...      ...  ..  ...  ...         ...         ...           ...
# 19142  19356   0    3  ...           1          -1             0
# 19143  19357   0    3  ...           4          -1             3
# 19144  19359   1    4  ...           1           0             1
# 19145  19360   0    3  ...           2           0             2
# 19146  19364   0    1  ...           7          -5             2
#
# [19147 rows x 51 columns]

# %%
ppap['상위10%물품_1P'].value_counts()
# Out:
#  0     5103
#  1     3382
# -1     2628
#  2     1832
# -2     1338
#  3     1048
# -3      724
#  4      636
#  5      504
# -4      470
#  6      290
# -5      280
#  7      172
# -6      159
#  8      123
# -7       91
# -8       76
#  9       53
#  10      42
#  11      39
# -9       38
#  12      21
# -10      18
#  13      14
# -11      12
# -12      10
#  14      10
#  17       8
#  16       6
#  15       5
# -14       5
# -13       3
# -15       2
# -17       2
#  19       1
#  18       1
# -18       1
# Name: 상위10%물품_1P, dtype: int64

# %%
ppap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19147 entries, 0 to 19146
# Data columns (total 51 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   고객번호              19147 non-null  int64
#  1   성별                19147 non-null  int64
#  2   연령대               19147 non-null  int64
#  3   구매금액_1P           19147 non-null  int64
#  4   구매금액_2P           19147 non-null  int64
#  5   구매금액_1_3P         19147 non-null  int64
#  6   구매금액_1P_A         19147 non-null  int64
#  7   구매금액_2P_A         19147 non-null  int64
#  8   구매금액_1_3P_A       19147 non-null  int64
#  9   구매금액_1P_B         19147 non-null  int64
#  10  구매금액_2P_B         19147 non-null  int64
#  11  구매금액_1_3P_B       19147 non-null  int64
#  12  구매금액_1P_C         19147 non-null  int64
#  13  구매금액_2P_C         19147 non-null  int64
#  14  구매금액_1_3P_C       19147 non-null  int64
#  15  구매금액_1P_D         19147 non-null  int64
# ...

# %%
ppap.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1014/total_gap.csv',encoding='cp949')

# %%
ppap
# Out:
#         고객번호  성별  연령대  ...  상위10%물품_1P  상위10%물품_2P  상위10%물품_1_3P
# 0          1   1    5  ...           0          -1            -1
# 1          2   1    5  ...           0           0             0
# 2          3   1    5  ...          -1           1             0
# 3          4   0    5  ...          -2          -2            -4
# 4          5   1    5  ...          -3          -1            -4
# ...      ...  ..  ...  ...         ...         ...           ...
# 19142  19356   0    3  ...           1          -1             0
# 19143  19357   0    3  ...           4          -1             3
# 19144  19359   1    4  ...           1           0             1
# 19145  19360   0    3  ...           2           0             2
# 19146  19364   0    1  ...           7          -5             2
#
# [19147 rows x 51 columns]

# %%
ppap.columns
# Out:
# Index(['고객번호', '성별', '연령대', '구매금액_1P', '구매금액_2P', '구매금액_1_3P', '구매금액_1P_A',
#        '구매금액_2P_A', '구매금액_1_3P_A', '구매금액_1P_B', '구매금액_2P_B', '구매금액_1_3P_B',
#        '구매금액_1P_C', '구매금액_2P_C', '구매금액_1_3P_C', '구매금액_1P_D', '구매금액_2P_D',
#        '구매금액_1_3P_D', '가구/가전/전자기기_1P', '가구/가전/전자기기_2P', '가구/가전/전자기기_1_3P',
#        '기타_1P', '기타_2P', '기타_1_3P', '생활/건강_1P', '생활/건강_2P', '생활/건강_1_3P',
#        '식품_1P', '식품_2P', '식품_1_3P', '의류/잡화_1P', '의류/잡화_2P', '의류/잡화_1_3P',
#        '반려/취미/문구/도서_1P', '반려/취미/문구/도서_2P', '반려/취미/문구/도서_1_3P', '스포츠/레저/자동차_1P',
#        '스포츠/레저/자동차_2P', '스포츠/레저/자동차_1_3P', '출산유아동_1P', '출산유아동_2P',
#        '출산유아동_1_3P', '방문횟수_1P', '방문횟수_2P', '방문횟수_1_3P', '중분류갯수_1P', '중분류갯수_2P',
#        '중분류갯수_1_3P', '상위10%물품_1P', '상위10%물품_2P', '상위10%물품_1_3P'],
#       dtype='object')

# %%
ppap[['성별','연령대', '구매금액_1P', '구매금액_1P_A',
       ,'구매금액_1P_B','구매금액_1P_C', '구매금액_1P_D', '가구/가전/전자기기_1P',
       '기타_1P', '생활/건강_1P','식품_1P', '의류/잡화_1P',
       '반려/취미/문구/도서_1P', '스포츠/레저/자동차_1P', '출산유아동_1P','방문횟수_1P',  '상위10%물품_1P']]

# %%
ppap = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1014/total_gap.csv',encoding='cp949',index_col=0)
ppap
# Out:
#         고객번호  성별  연령대  ...  상위10%물품_1P  상위10%물품_2P  상위10%물품_1_3P
# 0          1   1    5  ...           0          -1            -1
# 1          2   1    5  ...           0           0             0
# 2          3   1    5  ...          -1           1             0
# 3          4   0    5  ...          -2          -2            -4
# 4          5   1    5  ...          -3          -1            -4
# ...      ...  ..  ...  ...         ...         ...           ...
# 19142  19356   0    3  ...           1          -1             0
# 19143  19357   0    3  ...           4          -1             3
# 19144  19359   1    4  ...           1           0             1
# 19145  19360   0    3  ...           2           0             2
# 19146  19364   0    1  ...           7          -5             2
#
# [19147 rows x 51 columns]

# %%
import pandas as pd
sos =pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1013/new_gap.csv',encoding='cp949',index_col=0)
sos
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  구매변동_2-3  구매변동_1-3  구매변동_1-4  구매변동_3-4
# 0          1   1    5        0  ...         1         1         1         1
# 1          2   1    5        0  ...         0         0         0         1
# 2          3   1    5        1  ...         1         1         1         0
# 3          4   0    5       -1  ...         1         1         1         0
# 4          5   1    5       -3  ...         0         1         1         1
# ...      ...  ..  ...      ...  ...       ...       ...       ...       ...
# 19142  19356   0    3        1  ...         0         0         0         0
# 19143  19357   0    3        3  ...         1         0         0         1
# 19144  19359   1    4        1  ...         1         0         0         0
# 19145  19360   0    3        2  ...         1         0         0         1
# 19146  19364   0    1        5  ...         1         0         0         0
#
# [19147 rows x 53 columns]

# %%
sos2 = sos[['고객번호','구매변동_1-2','구매변동_2-3','구매변동_1-3','구매변동_1-4','구매변동_3-4']]
sos2
# Out:
#         고객번호  구매변동_1-2  구매변동_2-3  구매변동_1-3  구매변동_1-4  구매변동_3-4
# 0          1         0         1         1         1         1
# 1          2         1         0         0         0         1
# 2          3         0         1         1         1         0
# 3          4         1         1         1         1         0
# 4          5         1         0         1         1         1
# ...      ...       ...       ...       ...       ...       ...
# 19142  19356         0         0         0         0         0
# 19143  19357         0         1         0         0         1
# 19144  19359         0         1         0         0         0
# 19145  19360         0         1         0         0         1
# 19146  19364         0         1         0         0         0
#
# [19147 rows x 6 columns]

# %%
pizza = pd.merge(ppap,sos2,on='고객번호',how='left')
pizza
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  구매변동_2-3  구매변동_1-3  구매변동_1-4  구매변동_3-4
# 0          1   1    5        0  ...         1         1         1         1
# 1          2   1    5        0  ...         0         0         0         1
# 2          3   1    5        1  ...         1         1         1         0
# 3          4   0    5       -1  ...         1         1         1         0
# 4          5   1    5       -3  ...         0         1         1         1
# ...      ...  ..  ...      ...  ...       ...       ...       ...       ...
# 19142  19356   0    3        1  ...         0         0         0         0
# 19143  19357   0    3        3  ...         1         0         0         1
# 19144  19359   1    4        1  ...         1         0         0         0
# 19145  19360   0    3        2  ...         1         0         0         1
# 19146  19364   0    1        5  ...         1         0         0         0
#
# [19147 rows x 56 columns]

# %%
import pandas as pd
pizza = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1014/pizza_gap.csv',encoding='cp949',index_col=0)
pizza
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  구매변동_2-3  구매변동_1-3  구매변동_1-4  구매변동_3-4
# 0          1   1    5        0  ...         1         1         1         1
# 1          2   1    5        0  ...         0         0         0         1
# 2          3   1    5        1  ...         1         1         1         0
# 3          4   0    5       -1  ...         1         1         1         0
# 4          5   1    5       -3  ...         0         1         1         1
# ...      ...  ..  ...      ...  ...       ...       ...       ...       ...
# 19142  19356   0    3        1  ...         0         0         0         0
# 19143  19357   0    3        3  ...         1         0         0         1
# 19144  19359   1    4        1  ...         1         0         0         0
# 19145  19360   0    3        2  ...         1         0         0         1
# 19146  19364   0    1        5  ...         1         0         0         0
#
# [19147 rows x 56 columns]

# %%
pizza2 = pizza[['고객번호','성별','연령대', '구매금액_1_3P', '구매금액_1_3P_A',
       '구매금액_1_3P_B','구매금액_1_3P_C', '구매금액_1_3P_D', '가구/가전/전자기기_1_3P',
       '기타_1_3P', '생활/건강_1_3P','식품_1_3P', '의류/잡화_1_3P',
       '반려/취미/문구/도서_1_3P', '스포츠/레저/자동차_1_3P', '출산유아동_1_3P','방문횟수_1_3P','상위10%물품_1_3P','구매변동_1-4','구매변동_1-3']]

# %%
pizza2
# Out:
#         고객번호  성별  연령대  구매금액_1_3P  ...  방문횟수_1_3P  상위10%물품_1_3P  구매변동_1-4  구매변동_1-3
# 0          1   1    5          0  ...          1            -1         1         1
# 1          2   1    5          0  ...         -1             0         0         0
# 2          3   1    5          0  ...         -2             0         1         1
# 3          4   0    5         -2  ...          0            -4         1         1
# 4          5   1    5         -2  ...         -4            -4         1         1
# ...      ...  ..  ...        ...  ...        ...           ...       ...       ...
# 19142  19356   0    3          2  ...          5             0         0         0
# 19143  19357   0    3          3  ...          6             3         0         0
# 19144  19359   1    4          0  ...          5             1         0         0
# 19145  19360   0    3          1  ...          2             2         0         0
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')

def modeling(data,model):
  y = data[['구매변동_1-3']]
  x = data.drop(['구매변동_1-3','고객번호'], axis=1)

  scaler = StandardScaler()

  new_x = scaler.fit_transform(x)

  X_train, X_test, y_train, y_test = train_test_split(new_x,y,test_size=0.2,random_state=0)


  if model == 'rf':  
    rf_clf = RandomForestClassifier(random_state=0)
    rf_clf.fit(X_train,y_train)
    rf_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test,rf_pred)
    print(model,'정확도 : ',round(accuracy,4))

  elif model == 'lr':
    lr_clf = LogisticRegression(random_state=0)
    lr_clf.fit(X_train,y_train)
    lr_pred = lr_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lr_pred)
    print(model,'정확도 : ',round(accuracy,4))

  elif model == 'xgb':
    xgb_clf = XGBClassifier(random_state=0)
    evals = [(X_test,y_test)]
    xgb_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    xgb_pred = xgb_clf.predict(X_test)
    accuracy = accuracy_score(y_test,xgb_pred)
    print(model,'정확도 : ',round(accuracy,4))
  
  elif model == 'lgbm':
    lgbm_clf = LGBMClassifier(random_state=0)
    evals = [(X_test,y_test)]
    lgbm_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    lgbm_pred = lgbm_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lgbm_pred)
    print(model,'정확도 : ',round(accuracy,4))

  else :
    print('모델 인자 값을 확인하세요')

# %%
li = ['lr','rf','xgb','lgbm']
for i in li:
  modeling(pizza123,i)
# Out:
# lr 정확도 :  0.7178
# rf 정확도 :  0.7141
# xgb 정확도 :  0.7222
# lgbm 정확도 :  0.7225

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def vif(data):
  vif = []
  data_val = data.values
  for i in range(len(data.columns)):
    vif.append(variance_inflation_factor(data_val, i))
  vif_dataframe = pd.DataFrame()
  vif_dataframe['columns'] = data.columns
  vif_dataframe['VIF'] = vif
  return vif_dataframe

# %%
vif2 = pizza11.drop(columns = ['구매변동_1-3'])

# %%
vif(vif2)
# Out:
#            columns       VIF
# 0             고객번호  2.707618
# 1               성별  1.213215
# 2              연령대  3.318439
# 3          구매금액_1P  4.067569
# 4        구매금액_1P_A  3.401390
# 5        구매금액_1P_B  1.644138
# 6        구매금액_1P_C  1.090812
# 7        구매금액_1P_D  1.020158
# 8    가구/가전/전자기기_1P  1.142166
# 9            기타_1P  1.136965
# 10        생활/건강_1P  1.177118
# 11           식품_1P  1.902163
# 12        의류/잡화_1P  1.778500
# 13  반려/취미/문구/도서_1P  1.102498
# 14   스포츠/레저/자동차_1P  1.135133
# 15        출산유아동_1P  1.064150
# 16         방문횟수_1P  2.138738
# 17        중분류갯수_1P  1.554247
# 18      상위10%물품_1P  2.199076
# 19        구매변동_1-2  2.723918

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import RandomizedSearchCV

import warnings

warnings.filterwarnings('ignore')

def random_modeling(data,model):

  y = data[['구매변동_1-3']]
  x = data.drop(['구매변동_1-3'],axis=1)



  X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=0)

  rf_clf = RandomForestClassifier(random_state=0, n_jobs=-1)
  lr_clf = LogisticRegression(random_state=0, n_jobs=-1)
  xgb_clf = XGBClassifier(random_state=0, n_jobs=-1)
  lgbm_clf = LGBMClassifier(random_state=0, n_jobs=-1)

  if model == 'rf':  
    
    rf_clf.fit(X_train,y_train)
    rf_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test,rf_pred)
    print(model,'정확도 : ',round(accuracy,4))

    rf_clf_params ={
        'n_estimators':[int(x) for x in range(1,1000,10)],
        'max_features':['log2','sqrt'],
        'max_depth':[int(i) for i in range(1, 200)],
        'min_samples_leaf':[20,40,60,80],
        'min_samples_split':[1,2,3,4,5],
        'bootstrap':[True, False]
    }

    rf_random_cv = RandomizedSearchCV(rf_clf, param_distributions=rf_clf_params, n_iter=50, scoring='accuracy', cv=2, n_jobs=-1)
    rf_random_cv.fit(X_train,y_train)
    print('최적의 파라미터 :',rf_random_cv.best_params_)
    print('최고의 정확도 :',rf_random_cv.best_score_)

 
  elif model == 'lr':
    
    lr_clf.fit(X_train,y_train)
    lr_pred = lr_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lr_pred)
    print(model,'정확도 : ',round(accuracy,4))

    lr_clf_params ={
        'C' : [0.001,0.01,0.1,1,10,100],
        'max_iter' : [1,200,400,600,800,1000],

    }

    lr_grid_cv = GridSearchCV(lr_clf, param_grid=lr_clf_params, scoring='accuracy', cv=2, n_jobs=-1)
    lr_grid_cv.fit(X_train,y_train)
    print('최적의 파라미터 :',lr_grid_cv.best_params_)
    print('최고의 정확도 :',lr_grid_cv.best_score_)

  elif model == 'xgb':
    
    evals = [(X_test,y_test)]
    xgb_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    xgb_pred = xgb_clf.predict(X_test)
    accuracy = accuracy_score(y_test,xgb_pred)
    print(model,'정확도 : ',round(accuracy,4))

    xgb_clf_params ={
        'n_estimators':[190,200,210],
        'max_depth':[2,4,6,8,10],
        'min_samples_leaf':[20,40,60,80],
        'min_samples_split':[1,2,3,4,5]
    }

    xgb_grid_cv = GridSearchCV(xgb_clf, param_grid=xgb_clf_params, scoring='accuracy', cv=2, n_jobs=-1)
    xgb_grid_cv.fit(X_train,y_train)
    print('최적의 파라미터 :',xgb_grid_cv.best_params_)
    print('최고의 정확도 :',xgb_grid_cv.best_score_)

  elif model == 'lgbm':
    
    evals = [(X_test,y_test)]
    lgbm_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    lgbm_pred = lgbm_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lgbm_pred)
    print(model,'정확도 : ',round(accuracy,4))

    lgbm_clf_params ={
        'n_estimators':[210,215,220],
        'max_depth':[10,11,12,13,14],
        'min_samples_leaf':[20,40,60,80],
        'min_samples_split':[1,2,3,4,5]
    }

    lgbm_grid_cv = GridSearchCV(lgbm_clf, param_grid=lgbm_clf_params, scoring='accuracy', cv=2, n_jobs=-1)
    lgbm_grid_cv.fit(X_train,y_train)
    print('최적의 파라미터 :',lgbm_grid_cv.best_params_)
    print('최고의 정확도 :',lgbm_grid_cv.best_score_)

  else :
    print('모델 인자 값을 확인하세요')

# %%
li = ['rf','lr','xgb','lgbm']
for i in li:
  modeling(pizza2,i)

# %%
import pandas as pd
chicken = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1014/pizza_gap.csv',encoding='cp949',index_col=0)
chicken
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  구매변동_2-3  구매변동_1-3  구매변동_1-4  구매변동_3-4
# 0          1   1    5        0  ...         1         1         1         1
# 1          2   1    5        0  ...         0         0         0         1
# 2          3   1    5        1  ...         1         1         1         0
# 3          4   0    5       -1  ...         1         1         1         0
# 4          5   1    5       -3  ...         0         1         1         1
# ...      ...  ..  ...      ...  ...       ...       ...       ...       ...
# 19142  19356   0    3        1  ...         0         0         0         0
# 19143  19357   0    3        3  ...         1         0         0         1
# 19144  19359   1    4        1  ...         1         0         0         0
# 19145  19360   0    3        2  ...         1         0         0         1
# 19146  19364   0    1        5  ...         1         0         0         0
#
# [19147 rows x 56 columns]

# %%
chicken['구매금액_2P'].value_counts()
# Out:
#  0     8033
#  1     3048
# -1     2741
#  2     1156
# -2     1138
# -3      612
#  3      578
# -4      352
#  4      342
# -5      251
#  5      179
# -6      171
#  6      122
# -7       99
#  7       80
# -8       65
#  8       47
# -9       28
#  9       26
# -10      25
# -11      17
#  10      16
# -13       7
#  12       6
#  11       5
#  13       2
# -12       1
# Name: 구매금액_2P, dtype: int64

# %%
import pandas as pd
pizza = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1014/pizza_gap.csv',encoding='cp949',index_col=0)
pizza
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  구매변동_2-3  구매변동_1-3  구매변동_1-4  구매변동_3-4
# 0          1   1    5        0  ...         1         1         1         1
# 1          2   1    5        0  ...         0         0         0         1
# 2          3   1    5        1  ...         1         1         1         0
# 3          4   0    5       -1  ...         1         1         1         0
# 4          5   1    5       -3  ...         0         1         1         1
# ...      ...  ..  ...      ...  ...       ...       ...       ...       ...
# 19142  19356   0    3        1  ...         0         0         0         0
# 19143  19357   0    3        3  ...         1         0         0         1
# 19144  19359   1    4        1  ...         1         0         0         0
# 19145  19360   0    3        2  ...         1         0         0         1
# 19146  19364   0    1        5  ...         1         0         0         0
#
# [19147 rows x 56 columns]

# %%
pizza2 = pd.merge(pizza,catost,on='고객번호',how='left')
pizza2
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  구매변동_1-3  구매변동_1-4  구매변동_3-4  구매변동_2-4
# 0          1   1    5        0  ...         1         1         1         1
# 1          2   1    5        0  ...         0         0         1         0
# 2          3   1    5        1  ...         1         1         0         1
# 3          4   0    5       -1  ...         1         1         0         1
# 4          5   1    5       -3  ...         1         1         1         0
# ...      ...  ..  ...      ...  ...       ...       ...       ...       ...
# 19142  19356   0    3        1  ...         0         0         0         0
# 19143  19357   0    3        3  ...         0         0         1         1
# 19144  19359   1    4        1  ...         0         0         0         1
# 19145  19360   0    3        2  ...         0         0         1         1
# 19146  19364   0    1        5  ...         0         0         0         1
#
# [19147 rows x 57 columns]

# %%
pizza = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1014/pizza_gap.csv',encoding='cp949',index_col=0)
pizza
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  구매변동_1-3  구매변동_1-4  구매변동_3-4  구매변동_2-4
# 0          1   1    5        0  ...         1         1         1         1
# 1          2   1    5        0  ...         0         0         1         0
# 2          3   1    5        1  ...         1         1         0         1
# 3          4   0    5       -1  ...         1         1         0         1
# 4          5   1    5       -3  ...         1         1         1         0
# ...      ...  ..  ...      ...  ...       ...       ...       ...       ...
# 19142  19356   0    3        1  ...         0         0         0         0
# 19143  19357   0    3        3  ...         0         0         1         1
# 19144  19359   1    4        1  ...         0         0         0         1
# 19145  19360   0    3        2  ...         0         0         1         1
# 19146  19364   0    1        5  ...         0         0         0         1
#
# [19147 rows x 57 columns]

# %%
pizza.columns
# Out:
# Index(['고객번호', '성별', '연령대', '구매금액_1P', '구매금액_2P', '구매금액_1_3P', '구매금액_1P_A',
#        '구매금액_2P_A', '구매금액_1_3P_A', '구매금액_1P_B', '구매금액_2P_B', '구매금액_1_3P_B',
#        '구매금액_1P_C', '구매금액_2P_C', '구매금액_1_3P_C', '구매금액_1P_D', '구매금액_2P_D',
#        '구매금액_1_3P_D', '가구/가전/전자기기_1P', '가구/가전/전자기기_2P', '가구/가전/전자기기_1_3P',
#        '기타_1P', '기타_2P', '기타_1_3P', '생활/건강_1P', '생활/건강_2P', '생활/건강_1_3P',
#        '식품_1P', '식품_2P', '식품_1_3P', '의류/잡화_1P', '의류/잡화_2P', '의류/잡화_1_3P',
#        '반려/취미/문구/도서_1P', '반려/취미/문구/도서_2P', '반려/취미/문구/도서_1_3P', '스포츠/레저/자동차_1P',
#        '스포츠/레저/자동차_2P', '스포츠/레저/자동차_1_3P', '출산유아동_1P', '출산유아동_2P',
#        '출산유아동_1_3P', '방문횟수_1P', '방문횟수_2P', '방문횟수_1_3P', '중분류갯수_1P', '중분류갯수_2P',
#        '중분류갯수_1_3P', '상위10%물품_1P', '상위10%물품_2P', '상위10%물품_1_3P', '구매변동_1-2',
#        '구매변동_2-3', '구매변동_1-3', '구매변동_1-4', '구매변동_3-4'],
#       dtype='object')

# %%
pizza11 = pizza[['고객번호', '성별', '연령대', '구매금액_1P', '구매금액_1P_A',
        '구매금액_1P_B','구매금액_1P_C','구매금액_1P_D','가구/가전/전자기기_1P',
        '기타_1P','생활/건강_1P','식품_1P','의류/잡화_1P','반려/취미/문구/도서_1P','스포츠/레저/자동차_1P','출산유아동_1P',
        '방문횟수_1P','중분류갯수_1P','상위10%물품_1P','구매변동_1-2','구매변동_1-3']]

# %%
pizza11.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1014/pizza1판_gap.csv',encoding='cp949')

# %%
pizza22 = pizza[['고객번호', '성별', '연령대', '구매금액_2P', '구매금액_2P_A',
        '구매금액_2P_B','구매금액_2P_C','구매금액_2P_D','가구/가전/전자기기_2P',
        '기타_2P','생활/건강_2P','식품_2P','의류/잡화_2P','반려/취미/문구/도서_2P','스포츠/레저/자동차_2P','출산유아동_2P',
        '방문횟수_2P','중분류갯수_2P','상위10%물품_2P','구매변동_2-3','구매변동_2-4']]

# %%
pizza22.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1014/pizza2판_gap.csv',encoding='cp949')

# %%
pizza22
# Out:
#         고객번호  성별  연령대  구매금액_2P  ...  중분류갯수_2P  상위10%물품_2P  구매변동_2-3  구매변동_2-4
# 0          1   1    5        0  ...         0          -1         1         1
# 1          2   1    5        0  ...         0           0         0         0
# 2          3   1    5       -1  ...        -1           1         1         1
# 3          4   0    5       -1  ...        -1          -2         1         1
# 4          5   1    5        1  ...        -1          -1         0         0
# ...      ...  ..  ...      ...  ...       ...         ...       ...       ...
# 19142  19356   0    3        1  ...        -1          -1         0         0
# 19143  19357   0    3        0  ...        -1          -1         1         1
# 19144  19359   1    4       -1  ...         0           0         1         1
# 19145  19360   0    3       -1  ...         0           0         1         1
# 19146  19364   0    1       -4  ...        -1          -5         1         1
#
# [19147 rows x 21 columns]

# %%
pizza33 = pizza[['고객번호', '성별', '연령대', '구매금액_1_3P', '구매금액_1_3P_A',
        '구매금액_1_3P_B','구매금액_1_3P_C','구매금액_1_3P_D','가구/가전/전자기기_1_3P',
        '기타_1_3P','생활/건강_1_3P','식품_1_3P','의류/잡화_1_3P','반려/취미/문구/도서_1_3P','스포츠/레저/자동차_1_3P','출산유아동_1_3P',
        '방문횟수_1_3P','중분류갯수_1_3P','상위10%물품_1_3P','구매변동_1-3','구매변동_1-4']]

# %%
pizza33
# Out:
#         고객번호  성별  연령대  구매금액_1_3P  ...  중분류갯수_1_3P  상위10%물품_1_3P  구매변동_1-3  구매변동_1-4
# 0          1   1    5          0  ...           1            -1         1         1
# 1          2   1    5          0  ...           1             0         0         0
# 2          3   1    5          0  ...          -1             0         1         1
# 3          4   0    5         -2  ...           0            -4         1         1
# 4          5   1    5         -2  ...          -1            -4         1         1
# ...      ...  ..  ...        ...  ...         ...           ...       ...       ...
# 19142  19356   0    3          2  ...           2             0         0         0
# 19143  19357   0    3          3  ...           3             3         0         0
# 19144  19359   1    4          0  ...           2             1         0         0
# 19145  19360   0    3          1  ...           2             2         0         0
# ...

# %%
pizza33.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1014/pizza1_3판_gap.csv',encoding='cp949')

# %%
pizza123 = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1014/pizza1판_gap.csv',encoding='cp949',index_col=0)
pizza123
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  중분류갯수_1P  상위10%물품_1P  구매변동_1-2  구매변동_1-3
# 0          1   1    5        0  ...         1           0         0         1
# 1          2   1    5        0  ...         1           0         1         0
# 2          3   1    5        1  ...         0          -1         0         1
# 3          4   0    5       -1  ...         1          -2         1         1
# 4          5   1    5       -3  ...         0          -3         1         1
# ...      ...  ..  ...      ...  ...       ...         ...       ...       ...
# 19142  19356   0    3        1  ...         3           1         0         0
# 19143  19357   0    3        3  ...         4           4         0         0
# 19144  19359   1    4        1  ...         2           1         0         0
# 19145  19360   0    3        2  ...         2           2         0         0
# 19146  19364   0    1        5  ...         3           7         0         0
#
# [19147 rows x 21 columns]

# %%
# Out:
#         고객번호  성별  연령대  구매금액_1  ...  방문횟수_3  중분류갯수_1  중분류갯수_2  중분류갯수_3
# 0          1   1    5      15  ...       6        5        6        6
# 1          2   1    5      15  ...       5        4        5        5
# 2          3   1    5       2  ...       4        5        5        4
# 3          4   0    5       7  ...       5        5        6        5
# 4          5   1    5       7  ...       3        4        4        3
# ...      ...  ..  ...     ...  ...     ...      ...      ...      ...
# 19142  19356   0    3       2  ...       7        3        6        5
# 19143  19357   0    3       2  ...       8        3        7        6
# 19144  19359   1    4       2  ...       7        3        5        5
# 19145  19360   0    3       2  ...       4        3        5        5
# 19146  19364   0    1       4  ...       5        3        6        5
#
# [19147 rows x 48 columns]

# %%
gap_10 = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1014/상위10%_total.csv',encoding='cp949',index_col=0)
gap_10
# Out:
#         고객번호  상위10%물품_1  상위10%물품_2  ...  상위10%물품_1P  상위10%물품_2P  상위10%물품_1_3P
# 0          1         20         20  ...           0          -1            -1
# 1          2         20         20  ...           0           0             0
# 2          3          2          1  ...          -1           1             0
# 3          4         10          8  ...          -2          -2            -4
# 4          5          8          5  ...          -3          -1            -4
# ...      ...        ...        ...  ...         ...         ...           ...
# 19142  19356          2          3  ...           1          -1             0
# 19143  19357          1          5  ...           4          -1             3
# 19144  19359          1          2  ...           1           0             1
# 19145  19360          2          4  ...           2           0             2
# 19146  19364          5         12  ...           7          -5             2
#
# [19147 rows x 7 columns]

# %%
gap_10_2 = gap_10[['고객번호','상위10%물품_1','상위10%물품_2','상위10%물품_3']]
gap_10_2
# Out:
#         고객번호  상위10%물품_1  상위10%물품_2  상위10%물품_3
# 0          1         20         20         19
# 1          2         20         20         20
# 2          3          2          1          2
# 3          4         10          8          6
# 4          5          8          5          4
# ...      ...        ...        ...        ...
# 19142  19356          2          3          2
# 19143  19357          1          5          4
# 19144  19359          1          2          2
# 19145  19360          2          4          4
# 19146  19364          5         12          7
#
# [19147 rows x 4 columns]

# %%
gap_10_2['상위10%물품_1'].value_counts()
# Out:
# 3     2573
# 4     2139
# 2     1897
# 20    1689
# 5     1653
# 6     1313
# 7     1069
# 8      866
# 9      731
# 10     653
# 12     583
# 13     556
# 11     540
# 15     493
# 14     475
# 16     449
# 17     411
# 1      375
# 18     360
# 19     322
# Name: 상위10%물품_1, dtype: int64

# %%
gap_10_2['상위10%물품_1'].replace({1:0,2:1,3:1,4:1,5:1,6:2,7:2,8:2,9:2,10:2,11:3,12:3,13:3,14:3,15:3,16:4,17:4,18:4,19:4,20:4},inplace=True)
gap_10_2['상위10%물품_2'].replace({1:1,2:1,3:1,4:1,5:1,6:2,7:2,8:2,9:2,10:2,11:3,12:3,13:3,14:3,15:3,16:4,17:4,18:4,19:4,20:4},inplace=True)
gap_10_2['상위10%물품_3'].replace({1:1,2:1,3:1,4:1,5:1,6:2,7:2,8:2,9:2,10:2,11:3,12:3,13:3,14:3,15:3,16:4,17:4,18:4,19:4,20:4},inplace=True)

# %%
gap_10_2
# Out:
#         고객번호  상위10%물품_1  상위10%물품_2  상위10%물품_3
# 0          1          4          4          4
# 1          2          4          4          4
# 2          3          1          1          1
# 3          4          2          2          2
# 4          5          2          1          1
# ...      ...        ...        ...        ...
# 19142  19356          1          1          1
# 19143  19357          1          1          1
# 19144  19359          1          1          1
# 19145  19360          1          1          1
# 19146  19364          1          3          2
#
# [19147 rows x 4 columns]

# %%
gap_10_2['상위10%물품_2'].value_counts()
# Out:
# 1    7972
# 2    4851
# 4    3426
# 3    2898
# Name: 상위10%물품_2, dtype: int64

# %%
gap_10_2['상위10%물품_1P']=gap_10_2['상위10%물품_2']-gap_10_2['상위10%물품_1']
gap_10_2['상위10%물품_2P']=gap_10_2['상위10%물품_3']-gap_10_2['상위10%물품_2']
gap_10_2['상위10%물품_1_3P']=gap_10_2['상위10%물품_3']-gap_10_2['상위10%물품_1']

# %%
gap_10_3=gap_10_2[['고객번호','상위10%물품_1P','상위10%물품_2P','상위10%물품_1_3P']]
gap_10_3
# Out:
#         고객번호  상위10%물품_1P  상위10%물품_2P  상위10%물품_1_3P
# 0          1           0           0             0
# 1          2           0           0             0
# 2          3           0           0             0
# 3          4           0           0             0
# 4          5          -1           0            -1
# ...      ...         ...         ...           ...
# 19142  19356           0           0             0
# 19143  19357           0           0             0
# 19144  19359           0           0             0
# 19145  19360           0           0             0
# 19146  19364           2          -1             1
#
# [19147 rows x 4 columns]

# %%
gap_10_3.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1016/상위10%_4_gap.csv',encoding='cp949')

# %%
import pandas as pd
all_15 = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1013/15등급_all.csv',encoding='cp949',index_col=0)
all_15
# Out:
#         고객번호  성별  연령대  구매금액_1  ...  방문횟수_3  중분류갯수_1  중분류갯수_2  중분류갯수_3
# 0          1   1    5      15  ...       6        5        6        6
# 1          2   1    5      15  ...       5        4        5        5
# 2          3   1    5       2  ...       4        5        5        4
# 3          4   0    5       7  ...       5        5        6        5
# 4          5   1    5       7  ...       3        4        4        3
# ...      ...  ..  ...     ...  ...     ...      ...      ...      ...
# 19142  19356   0    3       2  ...       7        3        6        5
# 19143  19357   0    3       2  ...       8        3        7        6
# 19144  19359   1    4       2  ...       7        3        5        5
# 19145  19360   0    3       2  ...       4        3        5        5
# 19146  19364   0    1       4  ...       5        3        6        5
#
# [19147 rows x 48 columns]

# %%
all_15['가구/가전/전자기기_3'].value_counts()
# Out:
# 1     7678
# 15    3608
# 2     2375
# 3     1507
# 4     1039
# 5      680
# 6      480
# 7      388
# 8      304
# 9      239
# 11     197
# 10     190
# 12     174
# 13     157
# 14     131
# Name: 가구/가전/전자기기_3, dtype: int64

# %%
all_15.columns
# Out:
# Index(['고객번호', '성별', '연령대', '구매금액_1', '구매금액_2', '구매금액_3', '구매금액_1_A',
#        '구매금액_2_A', '구매금액_3_A', '구매금액_1_B', '구매금액_2_B', '구매금액_3_B', '구매금액_1_C',
#        '구매금액_2_C', '구매금액_3_C', '구매금액_1_D', '구매금액_2_D', '구매금액_3_D',
#        '가구/가전/전자기기_1', '가구/가전/전자기기_2', '가구/가전/전자기기_3', '기타_1', '기타_2', '기타_3',
#        '생활/건강_1', '생활/건강_2', '생활/건강_3', '식품_1', '식품_2', '식품_3', '의류/잡화_1',
#        '의류/잡화_2', '의류/잡화_3', '반려/취미/문구/도서_1', '반려/취미/문구/도서_2', '반려/취미/문구/도서_3',
#        '스포츠/레저/자동차_1', '스포츠/레저/자동차_2', '스포츠/레저/자동차_3', '출산유아동_1', '출산유아동_2',
#        '출산유아동_3', '방문횟수_1', '방문횟수_2', '방문횟수_3', '중분류갯수_1', '중분류갯수_2',
#        '중분류갯수_3'],
#       dtype='object')

# %%
all_4_you = all_15.copy()

# %%
s = ['구매금액_1', '구매금액_2', '구매금액_3', '구매금액_1_A',
       '구매금액_2_A', '구매금액_3_A', '구매금액_1_B', '구매금액_2_B', '구매금액_3_B', '구매금액_1_C',
       '구매금액_2_C', '구매금액_3_C', '구매금액_1_D', '구매금액_2_D', '구매금액_3_D',
       '가구/가전/전자기기_1', '가구/가전/전자기기_2', '가구/가전/전자기기_3', '기타_1', '기타_2', '기타_3',
       '생활/건강_1', '생활/건강_2', '생활/건강_3', '식품_1', '식품_2', '식품_3', '의류/잡화_1',
       '의류/잡화_2', '의류/잡화_3', '반려/취미/문구/도서_1', '반려/취미/문구/도서_2', '반려/취미/문구/도서_3',
       '스포츠/레저/자동차_1', '스포츠/레저/자동차_2', '스포츠/레저/자동차_3', '출산유아동_1', '출산유아동_2',
       '출산유아동_3']

# %%
for i in range(0,13):
  all_4_you[s[3*i]].replace({1:1,2:2,3:2,4:2,5:2,6:2,7:3,8:3,9:3,10:3,11:3,12:4,13:4,14:4,15:4},inplace=True)
  all_4_you[s[3*i+1]].replace({1:1,2:2,3:2,4:2,5:2,6:2,7:3,8:3,9:3,10:3,11:3,12:4,13:4,14:4,15:4},inplace=True)
  all_4_you[s[3*i+2]].replace({1:1,2:2,3:2,4:2,5:2,6:2,7:3,8:3,9:3,10:3,11:3,12:4,13:4,14:4,15:4},inplace=True)

# %%
all_4_you
# Out:
#         고객번호  성별  연령대  구매금액_1  ...  방문횟수_3  중분류갯수_1  중분류갯수_2  중분류갯수_3
# 0          1   1    5       4  ...       6        5        6        6
# 1          2   1    5       4  ...       5        4        5        5
# 2          3   1    5       2  ...       4        5        5        4
# 3          4   0    5       3  ...       5        5        6        5
# 4          5   1    5       3  ...       3        4        4        3
# ...      ...  ..  ...     ...  ...     ...      ...      ...      ...
# 19142  19356   0    3       2  ...       7        3        6        5
# 19143  19357   0    3       2  ...       8        3        7        6
# 19144  19359   1    4       2  ...       7        3        5        5
# 19145  19360   0    3       2  ...       4        3        5        5
# 19146  19364   0    1       2  ...       5        3        6        5
#
# [19147 rows x 48 columns]

# %%
all_4_you['방문횟수_2'].value_counts()
# Out:
# 4     3180
# 5     3072
# 6     2478
# 7     2309
# 8     1834
# 3     1624
# 9     1445
# 10     983
# 11     700
# 12     465
# 2      347
# 13     292
# 15     245
# 14     173
# Name: 방문횟수_2, dtype: int64

# %%
all_4_you
# Out:
#         고객번호  성별  연령대  구매금액_1  ...  방문횟수_3  중분류갯수_1  중분류갯수_2  중분류갯수_3
# 0          1   1    5       4  ...       6        5        6        6
# 1          2   1    5       4  ...       5        4        5        5
# 2          3   1    5       2  ...       4        5        5        4
# 3          4   0    5       3  ...       5        5        6        5
# 4          5   1    5       3  ...       3        4        4        3
# ...      ...  ..  ...     ...  ...     ...      ...      ...      ...
# 19142  19356   0    3       2  ...       7        3        6        5
# 19143  19357   0    3       2  ...       8        3        7        6
# 19144  19359   1    4       2  ...       7        3        5        5
# 19145  19360   0    3       2  ...       4        3        5        5
# 19146  19364   0    1       2  ...       5        3        6        5
#
# [19147 rows x 48 columns]

# %%
s2 = ['방문횟수_1', '방문횟수_2', '방문횟수_3']

# %%
for i in range(0,1):
  all_4_you[s2[3*i]].replace({1:1,2:1,3:1,4:1,5:2,6:2,7:2,8:3,9:3,10:3,11:4,12:4,13:4,14:4,15:4},inplace=True)
  all_4_you[s2[3*i+1]].replace({1:1,2:1,3:1,4:1,5:2,6:2,7:2,8:3,9:3,10:3,11:4,12:4,13:4,14:4,15:4},inplace=True)
  all_4_you[s2[3*i+2]].replace({1:1,2:1,3:1,4:1,5:2,6:2,7:2,8:3,9:3,10:3,11:4,12:4,13:4,14:4,15:4},inplace=True)

# %%
all_4_you['중분류갯수_2'].value_counts()
# Out:
# 6     5138
# 7     4296
# 5     3797
# 8     2560
# 4     2311
# 9      497
# 3      423
# 2       97
# 10      27
# 11       1
# Name: 중분류갯수_2, dtype: int64

# %%
s3 = ['중분류갯수_1', '중분류갯수_2', '중분류갯수_3']

# %%
for i in range(0,1):
  all_4_you[s3[3*i]].replace({2:1,3:1,4:1,5:2,6:2,7:3,8:3,9:4,10:4,11:4},inplace=True)
  all_4_you[s3[3*i+1]].replace({2:1,3:1,4:1,5:2,6:2,7:3,8:3,9:4,10:4,11:4},inplace=True)
  all_4_you[s3[3*i+2]].replace({2:1,3:1,4:1,5:2,6:2,7:3,8:3,9:4,10:4,11:4},inplace=True)

# %%
all_4_you
# Out:
#         고객번호  성별  연령대  구매금액_1  ...  방문횟수_3  중분류갯수_1  중분류갯수_2  중분류갯수_3
# 0          1   1    5       4  ...       2        2        2        2
# 1          2   1    5       4  ...       2        1        2        2
# 2          3   1    5       2  ...       1        2        2        1
# 3          4   0    5       3  ...       2        2        2        2
# 4          5   1    5       3  ...       1        1        1        1
# ...      ...  ..  ...     ...  ...     ...      ...      ...      ...
# 19142  19356   0    3       2  ...       2        1        2        2
# 19143  19357   0    3       2  ...       3        1        3        2
# 19144  19359   1    4       2  ...       2        1        2        2
# 19145  19360   0    3       2  ...       1        1        2        2
# 19146  19364   0    1       2  ...       2        1        2        2
#
# [19147 rows x 48 columns]

# %%
all_4 = pd.merge(all_4_you,gap_10_3, on='고객번호', how='left')
all_4
# Out:
#         고객번호  성별  연령대  구매금액_1  ...  중분류갯수_3  상위10%물품_1P  상위10%물품_2P  상위10%물품_1_3P
# 0          1   1    5       4  ...        2           0           0             0
# 1          2   1    5       4  ...        2           0           0             0
# 2          3   1    5       2  ...        1           0           0             0
# 3          4   0    5       3  ...        2           0           0             0
# 4          5   1    5       3  ...        1          -1           0            -1
# ...      ...  ..  ...     ...  ...      ...         ...         ...           ...
# 19142  19356   0    3       2  ...        2           0           0             0
# 19143  19357   0    3       2  ...        2           0           0             0
# 19144  19359   1    4       2  ...        2           0           0             0
# 19145  19360   0    3       2  ...        2           0           0             0
# ...

# %%
ss = ['고객번호', '성별', '연령대', '구매금액_1', '구매금액_2', '구매금액_3', '구매금액_1_A',
       '구매금액_2_A', '구매금액_3_A', '구매금액_1_B', '구매금액_2_B', '구매금액_3_B', '구매금액_1_C',
       '구매금액_2_C', '구매금액_3_C', '구매금액_1_D', '구매금액_2_D', '구매금액_3_D',
       '가구/가전/전자기기_1', '가구/가전/전자기기_2', '가구/가전/전자기기_3', '기타_1', '기타_2', '기타_3',
       '생활/건강_1', '생활/건강_2', '생활/건강_3', '식품_1', '식품_2', '식품_3', '의류/잡화_1',
       '의류/잡화_2', '의류/잡화_3', '반려/취미/문구/도서_1', '반려/취미/문구/도서_2', '반려/취미/문구/도서_3',
       '스포츠/레저/자동차_1', '스포츠/레저/자동차_2', '스포츠/레저/자동차_3', '출산유아동_1', '출산유아동_2',
       '출산유아동_3', '방문횟수_1', '방문횟수_2', '방문횟수_3', '중분류갯수_1', '중분류갯수_2',
       '중분류갯수_3']

# %%
vv = ['고객번호', '성별', '연령대', '구매금액_1P', '구매금액_2P', '구매금액_1_3P', '구매금액_1P_A',
       '구매금액_2P_A', '구매금액_1_3P_A', '구매금액_1P_B', '구매금액_2P_B', '구매금액_1_3P_B', '구매금액_1P_C',
       '구매금액_2P_C', '구매금액_1_3P_C', '구매금액_1P_D', '구매금액_2P_D', '구매금액_1_3P_D',
       '가구/가전/전자기기_1P', '가구/가전/전자기기_2P', '가구/가전/전자기기_1_3P', '기타_1P', '기타_2P', '기타_1_3P',
       '생활/건강_1P', '생활/건강_2P', '생활/건강_1_3P', '식품_1P', '식품_2P', '식품_1_3P', '의류/잡화_1P',
       '의류/잡화_2P', '의류/잡화_1_3P', '반려/취미/문구/도서_1P', '반려/취미/문구/도서_2P', '반려/취미/문구/도서_1_3P',
       '스포츠/레저/자동차_1P', '스포츠/레저/자동차_2P', '스포츠/레저/자동차_1_3P', '출산유아동_1P', '출산유아동_2P',
       '출산유아동_1_3P', '방문횟수_1P', '방문횟수_2P', '방문횟수_1_3P', '중분류갯수_1P', '중분류갯수_2P',
       '중분류갯수_1_3P']

# %%
for i in range(1,16):
    j=3*i
    all_4[vv[j]]=all_4[ss[j+1]]-all_4[ss[j]]
    all_4[vv[j+1]]=all_4[ss[j+2]]-all_4[ss[j+1]]
    all_4[vv[j+2]]=all_4[ss[j+2]]-all_4[ss[j]]

# %%
all_4['상위10%물품_1P']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4       -1
#         ..
# 19142    0
# 19143    0
# 19144    0
# 19145    0
# 19146    2
# Name: 상위10%물품_1P, Length: 19147, dtype: int64

# %%
all_5=all_4[['고객번호', '성별', '연령대', '구매금액_1P', '구매금액_2P', '구매금액_1_3P', '구매금액_1P_A', '구매금액_2P_A',
       '구매금액_1_3P_A', '구매금액_1P_B', '구매금액_2P_B', '구매금액_1_3P_B', '구매금액_1P_C',
       '구매금액_2P_C', '구매금액_1_3P_C', '구매금액_1P_D', '구매금액_2P_D', '구매금액_1_3P_D',
       '가구/가전/전자기기_1P', '가구/가전/전자기기_2P', '가구/가전/전자기기_1_3P', '기타_1P', '기타_2P',
       '기타_1_3P', '생활/건강_1P', '생활/건강_2P', '생활/건강_1_3P', '식품_1P', '식품_2P',
       '식품_1_3P', '의류/잡화_1P', '의류/잡화_2P', '의류/잡화_1_3P', '반려/취미/문구/도서_1P',
       '반려/취미/문구/도서_2P', '반려/취미/문구/도서_1_3P', '스포츠/레저/자동차_1P', '스포츠/레저/자동차_2P',
       '스포츠/레저/자동차_1_3P', '출산유아동_1P', '출산유아동_2P', '출산유아동_1_3P', '방문횟수_1P','방문횟수_2P', '방문횟수_1_3P', '중분류갯수_1P', '중분류갯수_2P', '중분류갯수_1_3P','상위10%물품_1P','상위10%물품_2P','상위10%물품_1_3P']]

# %%
all_5
# Out:
#         고객번호  성별  연령대  ...  상위10%물품_1P  상위10%물품_2P  상위10%물품_1_3P
# 0          1   1    5  ...           0           0             0
# 1          2   1    5  ...           0           0             0
# 2          3   1    5  ...           0           0             0
# 3          4   0    5  ...           0           0             0
# 4          5   1    5  ...          -1           0            -1
# ...      ...  ..  ...  ...         ...         ...           ...
# 19142  19356   0    3  ...           0           0             0
# 19143  19357   0    3  ...           0           0             0
# 19144  19359   1    4  ...           0           0             0
# 19145  19360   0    3  ...           0           0             0
# 19146  19364   0    1  ...           2          -1             1
#
# [19147 rows x 51 columns]

# %%
p2 = pizza[['고객번호','구매변동_1-2','구매변동_2-3','구매변동_1-3','구매변동_1-4','구매변동_3-4','구매변동_2-4']]
p2
# Out:
#         고객번호  구매변동_1-2  구매변동_2-3  구매변동_1-3  구매변동_1-4  구매변동_3-4  구매변동_2-4
# 0          1         0         1         1         1         1         1
# 1          2         1         0         0         0         1         0
# 2          3         0         1         1         1         0         1
# 3          4         1         1         1         1         0         1
# 4          5         1         0         1         1         1         0
# ...      ...       ...       ...       ...       ...       ...       ...
# 19142  19356         0         0         0         0         0         0
# 19143  19357         0         1         0         0         1         1
# 19144  19359         0         1         0         0         0         1
# 19145  19360         0         1         0         0         1         1
# 19146  19364         0         1         0         0         0         1
#
# [19147 rows x 7 columns]

# %%
pizza = pd.merge(all_5,p2,on='고객번호',how='left')
pizza
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  구매변동_1-3  구매변동_1-4  구매변동_3-4  구매변동_2-4
# 0          1   1    5        0  ...         1         1         1         1
# 1          2   1    5        0  ...         0         0         1         0
# 2          3   1    5        0  ...         1         1         0         1
# 3          4   0    5       -1  ...         1         1         0         1
# 4          5   1    5       -1  ...         1         1         1         0
# ...      ...  ..  ...      ...  ...       ...       ...       ...       ...
# 19142  19356   0    3        0  ...         0         0         0         0
# 19143  19357   0    3        0  ...         0         0         1         1
# 19144  19359   1    4        0  ...         0         0         0         1
# 19145  19360   0    3        0  ...         0         0         1         1
# 19146  19364   0    1        1  ...         0         0         0         1
#
# [19147 rows x 57 columns]

# %%
pizza['가구/가전/전자기기_1P'].value_counts()
# Out:
#  0    11772
#  1     3427
#  2     1292
# -1     1056
# -2      927
#  3      673
# Name: 가구/가전/전자기기_1P, dtype: int64

# %%
pizza.columns
# Out:
# Index(['고객번호', '성별', '연령대', '구매금액_1P', '구매금액_2P', '구매금액_1_3P', '구매금액_1P_A',
#        '구매금액_2P_A', '구매금액_1_3P_A', '구매금액_1P_B', '구매금액_2P_B', '구매금액_1_3P_B',
#        '구매금액_1P_C', '구매금액_2P_C', '구매금액_1_3P_C', '구매금액_1P_D', '구매금액_2P_D',
#        '구매금액_1_3P_D', '가구/가전/전자기기_1P', '가구/가전/전자기기_2P', '가구/가전/전자기기_1_3P',
#        '기타_1P', '기타_2P', '기타_1_3P', '생활/건강_1P', '생활/건강_2P', '생활/건강_1_3P',
#        '식품_1P', '식품_2P', '식품_1_3P', '의류/잡화_1P', '의류/잡화_2P', '의류/잡화_1_3P',
#        '반려/취미/문구/도서_1P', '반려/취미/문구/도서_2P', '반려/취미/문구/도서_1_3P', '스포츠/레저/자동차_1P',
#        '스포츠/레저/자동차_2P', '스포츠/레저/자동차_1_3P', '출산유아동_1P', '출산유아동_2P',
#        '출산유아동_1_3P', '방문횟수_1P', '방문횟수_2P', '방문횟수_1_3P', '중분류갯수_1P', '중분류갯수_2P',
#        '중분류갯수_1_3P', '상위10%물품_1P', '상위10%물품_2P', '상위10%물품_1_3P', '구매변동_1-2',
#        '구매변동_2-3', '구매변동_1-3', '구매변동_1-4', '구매변동_3-4', '구매변동_2-4'],
#       dtype='object')

# %%
pizza11 = pizza[['고객번호', '성별', '연령대', '구매금액_1P', '구매금액_1P_A',
        '구매금액_1P_B','구매금액_1P_C','구매금액_1P_D','가구/가전/전자기기_1P',
        '기타_1P','생활/건강_1P','식품_1P','의류/잡화_1P','반려/취미/문구/도서_1P','스포츠/레저/자동차_1P','출산유아동_1P',
        '방문횟수_1P','중분류갯수_1P','상위10%물품_1P','구매변동_1-2','구매변동_1-3']]

# %%
pizza11
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  중분류갯수_1P  상위10%물품_1P  구매변동_1-2  구매변동_1-3
# 0          1   1    5        0  ...         0           0         0         1
# 1          2   1    5        0  ...         1           0         1         0
# 2          3   1    5        0  ...         0           0         0         1
# 3          4   0    5       -1  ...         0           0         1         1
# 4          5   1    5       -1  ...         0          -1         1         1
# ...      ...  ..  ...      ...  ...       ...         ...       ...       ...
# 19142  19356   0    3        0  ...         1           0         0         0
# 19143  19357   0    3        0  ...         2           0         0         0
# 19144  19359   1    4        0  ...         1           0         0         0
# 19145  19360   0    3        0  ...         1           0         0         0
# 19146  19364   0    1        1  ...         1           2         0         0
#
# [19147 rows x 21 columns]

# %%
pizza11.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1016/zza1개_gap.csv',encoding='cp949')

# %%
pizza22 = pizza[['고객번호', '성별', '연령대', '구매금액_2P', '구매금액_2P_A',
        '구매금액_2P_B','구매금액_2P_C','구매금액_2P_D','가구/가전/전자기기_2P',
        '기타_2P','생활/건강_2P','식품_2P','의류/잡화_2P','반려/취미/문구/도서_2P','스포츠/레저/자동차_2P','출산유아동_2P',
        '방문횟수_2P','중분류갯수_2P','상위10%물품_2P','구매변동_2-3','구매변동_2-4']]

# %%
pizza22.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1016/zza2개_gap.csv',encoding='cp949')

# %%
pizza22
# Out:
#         고객번호  성별  연령대  구매금액_2P  ...  중분류갯수_2P  상위10%물품_2P  구매변동_2-3  구매변동_2-4
# 0          1   1    5        0  ...         0           0         1         1
# 1          2   1    5        0  ...         0           0         0         0
# 2          3   1    5        0  ...        -1           0         1         1
# 3          4   0    5        0  ...         0           0         1         1
# 4          5   1    5        0  ...         0           0         0         0
# ...      ...  ..  ...      ...  ...       ...         ...       ...       ...
# 19142  19356   0    3        0  ...         0           0         0         0
# 19143  19357   0    3        0  ...        -1           0         1         1
# 19144  19359   1    4        0  ...         0           0         1         1
# 19145  19360   0    3        0  ...         0           0         1         1
# 19146  19364   0    1       -1  ...         0          -1         1         1
#
# [19147 rows x 21 columns]

# %%
pizza33 = pizza[['고객번호', '성별', '연령대', '구매금액_1_3P', '구매금액_1_3P_A',
        '구매금액_1_3P_B','구매금액_1_3P_C','구매금액_1_3P_D','가구/가전/전자기기_1_3P',
        '기타_1_3P','생활/건강_1_3P','식품_1_3P','의류/잡화_1_3P','반려/취미/문구/도서_1_3P','스포츠/레저/자동차_1_3P','출산유아동_1_3P',
        '방문횟수_1_3P','중분류갯수_1_3P','상위10%물품_1_3P','구매변동_1-3','구매변동_1-4']]

# %%
pizza33
# Out:
#         고객번호  성별  연령대  구매금액_1_3P  ...  중분류갯수_1_3P  상위10%물품_1_3P  구매변동_1-3  구매변동_1-4
# 0          1   1    5          0  ...           0             0         1         1
# 1          2   1    5          0  ...           1             0         0         0
# 2          3   1    5          0  ...          -1             0         1         1
# 3          4   0    5         -1  ...           0             0         1         1
# 4          5   1    5         -1  ...           0            -1         1         1
# ...      ...  ..  ...        ...  ...         ...           ...       ...       ...
# 19142  19356   0    3          0  ...           1             0         0         0
# 19143  19357   0    3          0  ...           1             0         0         0
# 19144  19359   1    4          0  ...           1             0         0         0
# 19145  19360   0    3          0  ...           1             0         0         0
# ...

# %%
pizza33.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1016/zza1_3개_gap.csv',encoding='cp949')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')

def modeling(data,model):
  y = data[['구매변동_1-3']]
  x = data.drop(['구매변동_1-3','고객번호'], axis=1)

  scaler = StandardScaler()

  new_x = scaler.fit_transform(x)

  X_train, X_test, y_train, y_test = train_test_split(new_x,y,test_size=0.2,random_state=0)


  if model == 'rf':  
    rf_clf = RandomForestClassifier(random_state=0)
    rf_clf.fit(X_train,y_train)
    rf_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test,rf_pred)
    print(model,'정확도 : ',round(accuracy,4))

  elif model == 'lr':
    lr_clf = LogisticRegression(random_state=0)
    lr_clf.fit(X_train,y_train)
    lr_pred = lr_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lr_pred)
    print(model,'정확도 : ',round(accuracy,4))

  elif model == 'xgb':
    xgb_clf = XGBClassifier(random_state=0)
    evals = [(X_test,y_test)]
    xgb_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    xgb_pred = xgb_clf.predict(X_test)
    accuracy = accuracy_score(y_test,xgb_pred)
    print(model,'정확도 : ',round(accuracy,4))
  
  elif model == 'lgbm':
    lgbm_clf = LGBMClassifier(random_state=0)
    evals = [(X_test,y_test)]
    lgbm_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    lgbm_pred = lgbm_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lgbm_pred)
    print(model,'정확도 : ',round(accuracy,4))

  else :
    print('모델 인자 값을 확인하세요')

# %%
li = ['lr','rf','xgb','lgbm']
for i in li:
  modeling(donut1,i)
# Out:
# lr 정확도 :  0.7185
# rf 정확도 :  0.7021
# xgb 정확도 :  0.7222
# lgbm 정확도 :  0.7209

# %%
donut1 = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1016/ga1개_gap.csv',encoding='cp949',index_col=0)
donut1
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  상위10%물품_1P  구매변동_1-2  구매변동_1-3  총변동등급
# 0          1   1    5        0  ...           0         0         1      3
# 1          2   1    5        0  ...           0         1         0      2
# 2          3   1    5        0  ...          -1         0         1      3
# 3          4   0    5        0  ...           0         1         1      3
# 4          5   1    5       -1  ...          -1         1         1      1
# ...      ...  ..  ...      ...  ...         ...       ...       ...    ...
# 19142  19356   0    3        0  ...           0         0         0      4
# 19143  19357   0    3        1  ...           1         0         0      5
# 19144  19359   1    4        0  ...           1         0         0      4
# 19145  19360   0    3        0  ...           0         0         0      4
# 19146  19364   0    1        2  ...           2         0         0      4
#
# [19147 rows x 22 columns]

# %%
donut1.columns
# Out:
# Index(['고객번호', '성별', '연령대', '구매금액_1P', '구매금액_1P_A', '구매금액_1P_B', '구매금액_1P_C',
#        '구매금액_1P_D', '가구/가전/전자기기_1P', '기타_1P', '생활/건강_1P', '식품_1P', '의류/잡화_1P',
#        '반려/취미/문구/도서_1P', '스포츠/레저/자동차_1P', '출산유아동_1P', '방문횟수_1P', '중분류갯수_1P',
#        '상위10%물품_1P', '구매변동_1-2', '구매변동_1-3'],
#       dtype='object')

# %%
dn = ['구매금액_1P', '구매금액_1P_A', '구매금액_1P_B', '구매금액_1P_C',
       '구매금액_1P_D', '가구/가전/전자기기_1P', '기타_1P', '생활/건강_1P', '식품_1P', '의류/잡화_1P',
       '반려/취미/문구/도서_1P', '스포츠/레저/자동차_1P', '출산유아동_1P', '방문횟수_1P', '중분류갯수_1P',
       '상위10%물품_1P']

# %%
dns = ['구매금액_1P_S', '구매금액_1P_A_S', '구매금액_1P_B_S', '구매금액_1P_C_S',
       '구매금액_1P_D_S', '가구/가전/전자기기_1P_S', '기타_1P_S', '생활/건강_1P_S', '식품_1P_S', '의류/잡화_1P_S',
       '반려/취미/문구/도서_1P_S', '스포츠/레저/자동차_1P_S', '출산유아동_1P_S', '방문횟수_1P_S', '중분류갯수_1P_S',
       '상위10%물품_1P_S']

# %%
def ms(x):
  ''
  if x==0:
    y = 0
  elif x>0:
    y = 1
  elif x<0:
    y = -1
    ''
  return y

# %%
for i in range(16):
  donut1[dns[i]]=donut1[dn[i]].apply(lambda x : ms(x))

# %%
donut1
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  출산유아동_1P_S  방문횟수_1P_S  중분류갯수_1P_S  상위10%물품_1P_S
# 0          1   1    5        0  ...           0          0           1             0
# 1          2   1    5        0  ...          -1          0           0             0
# 2          3   1    5        0  ...           0          0           0            -1
# 3          4   0    5        0  ...           1         -1           1             0
# 4          5   1    5       -1  ...           0         -1           0            -1
# ...      ...  ..  ...      ...  ...         ...        ...         ...           ...
# 19142  19356   0    3        0  ...           0          1           1             0
# 19143  19357   0    3        1  ...           1          1           1             1
# 19144  19359   1    4        0  ...           0          1           1             1
# 19145  19360   0    3        0  ...           0          1           1             0
# ...

# %%
donut1['총변동등급'] = donut1['구매금액_1P_S']+donut1['구매금액_1P_A_S']+donut1['구매금액_1P_B_S']+donut1['구매금액_1P_C_S']+donut1['구매금액_1P_D_S']+donut1['가구/가전/전자기기_1P_S']+donut1['기타_1P_S']+donut1['생활/건강_1P_S']+donut1['식품_1P_S']+donut1['의류/잡화_1P_S']+donut1['반려/취미/문구/도서_1P_S']+donut1['스포츠/레저/자동차_1P_S']+donut1['출산유아동_1P_S']+donut1['방문횟수_1P_S']+donut1['중분류갯수_1P_S']+donut1['상위10%물품_1P_S']
donut1
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  방문횟수_1P_S  중분류갯수_1P_S  상위10%물품_1P_S  총변동등급
# 0          1   1    5        0  ...          0           1             0      3
# 1          2   1    5        0  ...          0           0             0     -2
# 2          3   1    5        0  ...          0           0            -1      0
# 3          4   0    5        0  ...         -1           1             0      1
# 4          5   1    5       -1  ...         -1           0            -1     -8
# ...      ...  ..  ...      ...  ...        ...         ...           ...    ...
# 19142  19356   0    3        0  ...          1           1             0     10
# 19143  19357   0    3        1  ...          1           1             1     14
# 19144  19359   1    4        0  ...          1           1             1      6
# 19145  19360   0    3        0  ...          1           1             0      9
# 19146  19364   0    1        2  ...          1           1             1      9
#
# ...

# %%
donut1.columns
# Out:
# Index(['고객번호', '성별', '연령대', '구매금액_1P', '구매금액_1P_A', '구매금액_1P_B', '구매금액_1P_C',
#        '구매금액_1P_D', '가구/가전/전자기기_1P', '기타_1P', '생활/건강_1P', '식품_1P', '의류/잡화_1P',
#        '반려/취미/문구/도서_1P', '스포츠/레저/자동차_1P', '출산유아동_1P', '방문횟수_1P', '중분류갯수_1P',
#        '상위10%물품_1P', '구매변동_1-2', '구매변동_1-3', '구매금액_1P_S', '구매금액_1P_A_S',
#        '구매금액_1P_B_S', '구매금액_1P_C_S', '구매금액_1P_D_S', '가구/가전/전자기기_1P_S',
#        '기타_1P_S', '생활/건강_1P_S', '식품_1P_S', '의류/잡화_1P_S', '반려/취미/문구/도서_1P_S',
#        '스포츠/레저/자동차_1P_S', '출산유아동_1P_S', '방문횟수_1P_S', '중분류갯수_1P_S',
#        '상위10%물품_1P_S', '총변동등급'],
#       dtype='object')

# %%
donut11 = donut1[['고객번호', '성별', '연령대', '구매금액_1P', '구매금액_1P_A', '구매금액_1P_B', '구매금액_1P_C',
       '구매금액_1P_D', '가구/가전/전자기기_1P', '기타_1P', '생활/건강_1P', '식품_1P', '의류/잡화_1P',
       '반려/취미/문구/도서_1P', '스포츠/레저/자동차_1P', '출산유아동_1P', '방문횟수_1P', '중분류갯수_1P',
       '상위10%물품_1P', '구매변동_1-2', '구매변동_1-3','총변동등급']]

# %%
for i in range(16):
  donut1[dn[i]]=donut1[dn[i]].apply(lambda x : mst(x))

# %%
donut1
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  출산유아동_1P_S  방문횟수_1P_S  중분류갯수_1P_S  상위10%물품_1P_S
# 0          1   1    5        0  ...           0          0           1             0
# 1          2   1    5        0  ...           2          0           0             0
# 2          3   1    5        0  ...           0          0           0             2
# 3          4   0    5        0  ...           1          2           1             0
# 4          5   1    5        1  ...           0          2           0             2
# ...      ...  ..  ...      ...  ...         ...        ...         ...           ...
# 19142  19356   0    3        0  ...           0          1           1             0
# 19143  19357   0    3        1  ...           1          1           1             1
# 19144  19359   1    4        0  ...           0          1           1             1
# 19145  19360   0    3        0  ...           0          1           1             0
# ...

# %%
donut11.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1016/ga1개_gap.csv',encoding='cp949')

# %%
1     2212
 2     2064
 0     1950
 3     1767
-1     1722
 4     1476
-2     1358
 5     1199
-3      974
 6      896
-4      722
 7      606
-5      424
 8      412
-6      309
 9      299
 10     199
-7      150
 11     114
-8       99
 12      53
-9       49
 13      33
-10      28
 14      12
-11       9
-12       7
 15       4

# %%
donut11
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  상위10%물품_1P  구매변동_1-2  구매변동_1-3  총변동등급
# 0          1   1    5        0  ...           0         0         1      3
# 1          2   1    5        0  ...           0         1         0      2
# 2          3   1    5        0  ...          -1         0         1      3
# 3          4   0    5        0  ...           0         1         1      3
# 4          5   1    5       -1  ...          -1         1         1      1
# ...      ...  ..  ...      ...  ...         ...       ...       ...    ...
# 19142  19356   0    3        0  ...           0         0         0      4
# 19143  19357   0    3        1  ...           1         0         0      5
# 19144  19359   1    4        0  ...           1         0         0      4
# 19145  19360   0    3        0  ...           0         0         0      4
# 19146  19364   0    1        2  ...           2         0         0      4
#
# [19147 rows x 22 columns]

# %%
donut11['총변동등급'].replace({-12:1,-11:1,-10:1,-9:1,-8:1,-7:1,-6:2,-5:2,-4:2,-3:2,-2:2,-1:2,0:3,1:3,2:3,3:3,4:3,5:3,6:4,7:4,8:4,9:4,10:4,11:4,12:5,13:5,14:5,15:5},inplace=True)

# %%
# Out:
#         고객번호  성별  연령대  구매금액_1P  ...  중분류갯수_1P  상위10%물품_1P  구매변동_1-2  구매변동_1-3
# 0          1   1    5        0  ...         1           0         0         1
# 1          2   1    5        0  ...         1           0         1         0
# 2          3   1    5        1  ...         0          -1         0         1
# 3          4   0    5       -1  ...         1          -2         1         1
# 4          5   1    5       -3  ...         0          -3         1         1
# ...      ...  ..  ...      ...  ...       ...         ...       ...       ...
# 19142  19356   0    3        1  ...         3           1         0         0
# 19143  19357   0    3        3  ...         4           4         0         0
# 19144  19359   1    4        1  ...         2           1         0         0
# 19145  19360   0    3        2  ...         2           2         0         0
# 19146  19364   0    1        5  ...         3           7         0         0
#
# [19147 rows x 21 columns]
