# %%
import pandas as pd
the_new_df = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1010/차액_등급_중간저장(1011).csv',encoding='cp949',index_col=0)

# %%
the_new_df
# Out:
#         고객번호 성별  연령대  1P  2P  ...  2D_의류/잡화  3D_의류/잡화  1D_출산유아동  2D_출산유아동  3D_출산유아동
# 0          1  M  60대   0   1  ...    -27290  -3610470         0         0         0
# 1          2  M  60대   1   0  ...   2728190    176690   -355710    928420   -967190
# 2          3  M  60대   0   1  ...         0         0         0         0         0
# 3          4  F  60대   1   1  ...   -156610    443850     17900     51100    -69000
# 4          5  M  60대   1   0  ...    227400    264650         0         0         0
# ...      ... ..  ...  ..  ..  ...       ...       ...       ...       ...       ...
# 19142  19356  F  40대   0   0  ...     25030    113400         0         0         0
# 19143  19357  F  40대   0   1  ...   -266150   -273810    340000   -156500    -43900
# 19144  19359  M  50대   0   1  ...     -1990      2990         0         0         0
# 19145  19360  F  40대   0   1  ...    174400    147200         0         0         0
# ...

# %%
shee = the_new_df[['1D_가구/가전/전자기기','1D_기타','1D_반려/취미/문구/도서','1D_생활/건강','1D_스포츠/레저/자동차','1D_식품','1D_의류/잡화','1D_출산유아동']]
shee
# Out:
#        1D_가구/가전/전자기기    1D_기타  1D_반려/취미/문구/도서  ...    1D_식품  1D_의류/잡화  1D_출산유아동
# 0           13654690  -521550               0  ... -1667013   1983010         0
# 1           -1225400 -3298060            -500  ... -1674260   3149480   -355710
# 2              26900        0               0  ...   157469         0         0
# 3             404000   542500               0  ...  -752076  -1283730     17900
# 4             162400  -673510               0  ... -1869680   -429270         0
# ...              ...      ...             ...  ...      ...       ...       ...
# 19142          16000    48900               0  ...  1181720      2970         0
# 19143          13750   125900           29280  ...  1726946    805050    340000
# 19144              0        0               0  ...  1147887      1990         0
# 19145           3050  1014150               0  ...   387530     13000         0
# 19146          14250  1919910               0  ...   308170   2566550    127700
#
# ...

# %%
thee = the_new_df[['2D_가구/가전/전자기기','2D_기타','2D_반려/취미/문구/도서','2D_생활/건강','2D_스포츠/레저/자동차','2D_식품','2D_의류/잡화','2D_출산유아동']]
thee
# Out:
#        2D_가구/가전/전자기기    2D_기타  2D_반려/취미/문구/도서  ...   2D_식품  2D_의류/잡화  2D_출산유아동
# 0          -12964090  -589400               0  ... -178407    -27290         0
# 1            1232120  3184010           54800  ... -836040   2728190    928420
# 2             -26900        0               0  ... -367474         0         0
# 3            -404000  -370350               0  ...  943017   -156610     51100
# 4            -212300   254050               0  ...  562550    227400         0
# ...              ...      ...             ...  ...     ...       ...       ...
# 19142         -10510   -37940               0  ...  443698     25030         0
# 19143          -9150    13100           -8030  ...  197438   -266150   -156500
# 19144              0        0               0  ... -465107     -1990         0
# 19145          -3050  -469810               0  ... -180430    174400         0
# 19146         -14250 -1094090               0  ...  102740  -2416010    -82900
#
# ...

# %%
thee2 = thee.rename(columns={'2D_가구/가전/전자기기':'1D_가구/가전/전자기기','2D_기타':'1D_기타','2D_반려/취미/문구/도서':'1D_반려/취미/문구/도서','2D_생활/건강':'1D_생활/건강','2D_스포츠/레저/자동차':'1D_스포츠/레저/자동차','2D_식품':'1D_식품','2D_의류/잡화':'1D_의류/잡화','2D_출산유아동':'1D_출산유아동'})

# %%
thee2
# Out:
#        1D_가구/가전/전자기기    1D_기타  1D_반려/취미/문구/도서  ...   1D_식품  1D_의류/잡화  1D_출산유아동
# 0          -12964090  -589400               0  ... -178407    -27290         0
# 1            1232120  3184010           54800  ... -836040   2728190    928420
# 2             -26900        0               0  ... -367474         0         0
# 3            -404000  -370350               0  ...  943017   -156610     51100
# 4            -212300   254050               0  ...  562550    227400         0
# ...              ...      ...             ...  ...     ...       ...       ...
# 19142         -10510   -37940               0  ...  443698     25030         0
# 19143          -9150    13100           -8030  ...  197438   -266150   -156500
# 19144              0        0               0  ... -465107     -1990         0
# 19145          -3050  -469810               0  ... -180430    174400         0
# 19146         -14250 -1094090               0  ...  102740  -2416010    -82900
#
# ...

# %%
new_line= pd.concat([shee,thee2],axis=0)
new_line
# Out:
#        1D_가구/가전/전자기기    1D_기타  1D_반려/취미/문구/도서  ...    1D_식품  1D_의류/잡화  1D_출산유아동
# 0           13654690  -521550               0  ... -1667013   1983010         0
# 1           -1225400 -3298060            -500  ... -1674260   3149480   -355710
# 2              26900        0               0  ...   157469         0         0
# 3             404000   542500               0  ...  -752076  -1283730     17900
# 4             162400  -673510               0  ... -1869680   -429270         0
# ...              ...      ...             ...  ...      ...       ...       ...
# 19142         -10510   -37940               0  ...   443698     25030         0
# 19143          -9150    13100           -8030  ...   197438   -266150   -156500
# 19144              0        0               0  ...  -465107     -1990         0
# 19145          -3050  -469810               0  ...  -180430    174400         0
# 19146         -14250 -1094090               0  ...   102740  -2416010    -82900
#
# ...

# %%
print(new_line['1D_가구/가전/전자기기'].describe())
print(new_line['1D_기타'].describe())
print(new_line['1D_반려/취미/문구/도서'].describe())
print(new_line['1D_생활/건강'].describe())
print(new_line['1D_스포츠/레저/자동차'].describe())
print(new_line['1D_식품'].describe())
print(new_line['1D_의류/잡화'].describe())
print(new_line['1D_출산유아동'].describe())
# Out:
# count    3.829400e+04
# mean     2.393598e+04
# std      2.915965e+06
# min     -1.050012e+08
# 25%     -3.780000e+04
# 50%      0.000000e+00
# 75%      3.510000e+04
# max      1.321866e+08
# Name: 1D_가구/가전/전자기기, dtype: float64
# count    3.829400e+04
# mean     1.771410e+04
# std      1.565370e+06
# min     -1.906685e+08
# 25%     -8.724750e+04
# 50%      3.800000e+03
# 75%      1.236000e+05
# max      4.167789e+07
# Name: 1D_기타, dtype: float64
# count    3.829400e+04
# mean     1.269760e+04
# std      3.881839e+05
# min     -2.757673e+07
# 25%     -2.800000e+03
# 50%      0.000000e+00
# 75%      1.065000e+04
# max      3.392545e+07
# Name: 1D_반려/취미/문구/도서, dtype: float64
# count    3.829400e+04
# mean     3.200373e+02
# std      1.518794e+06
# min     -2.001674e+08
# 25%     -8.572250e+04
# 50%      0.000000e+00
# 75%      8.562500e+04
# max      1.037102e+08
# Name: 1D_생활/건강, dtype: float64
# count    3.829400e+04
# mean    -3.025983e+04
# std      2.462598e+06
# ...

# %%
new_col = list(new_line.columns)
new_col
# Out:
# ['1D_가구/가전/전자기기',
#  '1D_기타',
#  '1D_반려/취미/문구/도서',
#  '1D_생활/건강',
#  '1D_스포츠/레저/자동차',
#  '1D_식품',
#  '1D_의류/잡화',
#  '1D_출산유아동']

# %%
s= []
s2=[]
for i in new_col:
  new_line[i].describe()
  iqr = new_line[i].describe()['75%']-new_line[i].describe()['25%']
  stan = round(iqr/4)
  a = new_line[i].describe()['75%']+1.5*iqr
  b = new_line[i].describe()['25%']-1.5*iqr
  c = round((a-b)/2)  
  s.append(stan)
  s2.append(c)

# %%
def cats(x,j):
  if x <-s2[j]: 
    y= -4
  elif x <-2*s[j]:
    y = -3
  elif x <-1*s[j]:
    y = -2
  elif -1*s[j]<=x <0:
    y = -1
  elif x ==0:
    y = 0  
  elif s[j]>=x >0:
    y = 1
  elif 2*s[j]>= x > s[j]:
    y = 2
  elif s2[j]>= x > 2*s[j]:
    y = 3
  else:
    y = 4
  return y

# %%
the_new_df['1D_가구/가전/전자기기_rank'] = the_new_df['1D_가구/가전/전자기기'].apply(lambda x: cats(x,0))
the_new_df['2D_가구/가전/전자기기_rank'] = the_new_df['2D_가구/가전/전자기기'].apply(lambda x: cats(x,0))
the_new_df['3D_가구/가전/전자기기_rank'] = the_new_df['3D_가구/가전/전자기기'].apply(lambda x: cats(x,0))

the_new_df['1D_기타_rank'] = the_new_df['1D_기타'].apply(lambda x: cats(x,1))
the_new_df['2D_기타_rank'] = the_new_df['2D_기타'].apply(lambda x: cats(x,1))
the_new_df['3D_기타_rank'] = the_new_df['3D_기타'].apply(lambda x: cats(x,1))

the_new_df['1D_반려/취미/문구/도서_rank'] = the_new_df['1D_반려/취미/문구/도서'].apply(lambda x: cats(x,2))
the_new_df['2D_반려/취미/문구/도서_rank'] = the_new_df['2D_반려/취미/문구/도서'].apply(lambda x: cats(x,2))
the_new_df['3D_반려/취미/문구/도서_rank'] = the_new_df['3D_반려/취미/문구/도서'].apply(lambda x: cats(x,2))

the_new_df['1D_생활/건강_rank'] = the_new_df['1D_생활/건강'].apply(lambda x: cats(x,3))
the_new_df['2D_생활/건강_rank'] = the_new_df['2D_생활/건강'].apply(lambda x: cats(x,3))
the_new_df['3D_생활/건강_rank'] = the_new_df['3D_생활/건강'].apply(lambda x: cats(x,3))

the_new_df['1D_스포츠/레저/자동차_rank'] = the_new_df['1D_스포츠/레저/자동차'].apply(lambda x: cats(x,4))
the_new_df['2D_스포츠/레저/자동차_rank'] = the_new_df['2D_스포츠/레저/자동차'].apply(lambda x: cats(x,4))
the_new_df['3D_스포츠/레저/자동차_rank'] = the_new_df['3D_스포츠/레저/자동차'].apply(lambda x: cats(x,4))

the_new_df['1D_식품_rank'] = the_new_df['1D_식품'].apply(lambda x: cats(x,5))
the_new_df['2D_식품_rank'] = the_new_df['2D_식품'].apply(lambda x: cats(x,5))
the_new_df['3D_식품_rank'] = the_new_df['3D_식품'].apply(lambda x: cats(x,5))

the_new_df['1D_의류/잡화_rank'] = the_new_df['1D_의류/잡화'].apply(lambda x: cats(x,6))
the_new_df['2D_의류/잡화_rank'] = the_new_df['2D_의류/잡화'].apply(lambda x: cats(x,6))
the_new_df['3D_의류/잡화_rank'] = the_new_df['3D_의류/잡화'].apply(lambda x: cats(x,6))

the_new_df['1D_출산유아동_rank'] = the_new_df['1D_출산유아동'].apply(lambda x: cats(x,7))
the_new_df['2D_출산유아동_rank'] = the_new_df['2D_출산유아동'].apply(lambda x: cats(x,7))
the_new_df['3D_출산유아동_rank'] = the_new_df['3D_출산유아동'].apply(lambda x: cats(x,7))

# %%
the_new_df['2D_출산유아동_rank'].value_counts()
# Out:
#  0    8235
# -4    4460
#  4    2638
# -3    1633
#  3     762
# -1     512
# -2     490
#  1     226
#  2     191
# Name: 2D_출산유아동_rank, dtype: int64

# %%
the_new_df
# Out:
#         고객번호 성별  연령대  ...  1D_출산유아동_rank  2D_출산유아동_rank  3D_출산유아동_rank
# 0          1  M  60대  ...              0              0              0
# 1          2  M  60대  ...             -4              4             -4
# 2          3  M  60대  ...              0              0              0
# 3          4  F  60대  ...              3              4             -4
# 4          5  M  60대  ...              0              0              0
# ...      ... ..  ...  ...            ...            ...            ...
# 19142  19356  F  40대  ...              0              0              0
# 19143  19357  F  40대  ...              4             -4             -3
# 19144  19359  M  50대  ...              0              0              0
# 19145  19360  F  40대  ...              0              0              0
# 19146  19364  F  20대  ...              4             -4             -2
#
# [19147 rows x 57 columns]

# %%
the_new_df11 = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/the_new_df11.csv',encoding='cp949',index_col=0)
the_new_df11
# Out:
#         고객번호 성별  연령대  ...  1D_출산유아동_rank  2D_출산유아동_rank  3D_출산유아동_rank
# 0          1  M  60대  ...              0              0              0
# 1          2  M  60대  ...             -4              4             -4
# 2          3  M  60대  ...              0              0              0
# 3          4  F  60대  ...              3              4             -4
# 4          5  M  60대  ...              0              0              0
# ...      ... ..  ...  ...            ...            ...            ...
# 19142  19356  F  40대  ...              0              0              0
# 19143  19357  F  40대  ...              4             -4             -3
# 19144  19359  M  50대  ...              0              0              0
# 19145  19360  F  40대  ...              0              0              0
# 19146  19364  F  20대  ...              4             -4             -2
#
# [19147 rows x 57 columns]

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(the_new_df11['성별'])
the_new_df11['성별'] = encoder.transform(the_new_df11['성별'])

# %%
encoder = LabelEncoder()
encoder.fit(the_new_df11['연령대'])
the_new_df11['연령대'] = encoder.transform(the_new_df11['연령대'])

# %%
the_new_df11_1 = the_new_df11.drop(['1D_가구/가전/전자기기',	'2D_가구/가전/전자기기','3D_가구/가전/전자기기','1D_기타','2D_기타','3D_기타','1D_반려/취미/문구/도서','2D_반려/취미/문구/도서','3D_반려/취미/문구/도서','1D_생활/건강','2D_생활/건강','3D_생활/건강','1D_스포츠/레저/자동차','2D_스포츠/레저/자동차','3D_스포츠/레저/자동차','1D_식품','2D_식품','3D_식품','1D_의류/잡화','2D_의류/잡화','3D_의류/잡화','1D_출산유아동','2D_출산유아동','3D_출산유아동'],axis=1)

# %%
the_new_df11_1
# Out:
#         고객번호  성별  연령대  ...  1D_출산유아동_rank  2D_출산유아동_rank  3D_출산유아동_rank
# 0          1   1    5  ...              0              0              0
# 1          2   1    5  ...             -4              4             -4
# 2          3   1    5  ...              0              0              0
# 3          4   0    5  ...              3              4             -4
# 4          5   1    5  ...              0              0              0
# ...      ...  ..  ...  ...            ...            ...            ...
# 19142  19356   0    3  ...              0              0              0
# 19143  19357   0    3  ...              4             -4             -3
# 19144  19359   1    4  ...              0              0              0
# 19145  19360   0    3  ...              0              0              0
# 19146  19364   0    1  ...              4             -4             -2
#
# [19147 rows x 33 columns]

# %%
the_new_df11_1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')

def modeling(data,model):

  y = data[['3P']]
  x = data.drop(['고객번호','3P','3D_가구/가전/전자기기_rank','3D_기타_rank','3D_반려/취미/문구/도서_rank','3D_생활/건강_rank','3D_스포츠/레저/자동차_rank','3D_식품_rank','3D_의류/잡화_rank','3D_출산유아동_rank','3P_sort_de'],axis=1)

  scaler = StandardScaler()

  new_x = scaler.fit_transform(x)

  X_train, X_test, y_train, y_test = train_test_split(new_x,y,test_size=0.2,random_state=0)


  if model == 'rf':  
    rf_clf = RandomForestClassifier()
    rf_clf.fit(X_train,y_train)
    rf_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test,rf_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'lr':
    lr_clf = LogisticRegression()
    lr_clf.fit(X_train,y_train)
    lr_pred = lr_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lr_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'xgb':
    xgb_clf = XGBClassifier()
    evals = [(X_test,y_test)]
    xgb_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    xgb_pred = xgb_clf.predict(X_test)
    accuracy = accuracy_score(y_test,xgb_pred)
    print(model,'정확도 : ',round(accuracy,2))
  elif model == 'lgbm':
    lgbm_clf = LGBMClassifier()
    evals = [(X_test,y_test)]
    lgbm_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    lgbm_pred = lgbm_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lgbm_pred)
    print(model,'정확도 : ',round(accuracy,2))

# %%
li = ['lr','rf','xgb','lgbm']
for i in li:
  modeling(the_new_df11_1,i)
# Out:
# lr 정확도 :  0.61
# rf 정확도 :  0.6
# xgb 정확도 :  0.61
# lgbm 정확도 :  0.61

# %%
the_drop = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1007/기준_3P_분기제휴사_구매금액_1006_3.csv',index_col=0)
the_drop
# Out:
#         고객번호 성별  연령대   14년 상반기  ...  4_중분류갯수  1P_sort_de  2P_sort_de  3P_sort_de
# 0          1  M  60대  19925355  ...       23          13          -5          -6
# 1          2  M  60대  24323230  ...       21           4           3          -5
# 2          3  M  60대    851215  ...       23           1          -6           7
# 3          4  F  60대   5042106  ...       24           5          -2          -3
# 4          5  M  60대   5460150  ...       13          -4          -2           1
# ...      ... ..  ...       ...  ...      ...         ...         ...         ...
# 19142  19356  F  40대    170160  ...       27          15          -1           0
# 19143  19357  F  40대     91950  ...       32          28          -3          -2
# 19144  19359  M  50대     43190  ...       19          16          -1          -3
# 19145  19360  F  40대    368050  ...       16          14          -4          -5
# 19146  19364  F  20대   2032420  ...       21          20          -5          -6
#
# ...

# %%
the_drop2 = the_drop[['고객번호','1_평균구매시간_cat','2_평균구매시간_cat','3_평균구매시간_cat']]
the_drop2
# Out:
#         고객번호 1_평균구매시간_cat 2_평균구매시간_cat 3_평균구매시간_cat
# 0          1          아침형          아침형          아침형
# 1          2          아침형          아침형          아침형
# 2          3          아침형          아침형          아침형
# 3          4          아침형          아침형          아침형
# 4          5          아침형          아침형          아침형
# ...      ...          ...          ...          ...
# 19142  19356          아침형          아침형          아침형
# 19143  19357          저녁형          저녁형          저녁형
# 19144  19359          아침형          아침형          아침형
# 19145  19360          저녁형          저녁형          저녁형
# 19146  19364          저녁형          저녁형          저녁형
#
# [19147 rows x 4 columns]

# %%
encoder = LabelEncoder()
encoder.fit(the_drop2['1_평균구매시간_cat'])
the_drop2['1_평균구매시간_cat'] = encoder.transform(the_drop2['1_평균구매시간_cat'])

encoder = LabelEncoder()
encoder.fit(the_drop2['2_평균구매시간_cat'])
the_drop2['2_평균구매시간_cat'] = encoder.transform(the_drop2['2_평균구매시간_cat'])

encoder = LabelEncoder()
encoder.fit(the_drop2['3_평균구매시간_cat'])
the_drop2['3_평균구매시간_cat'] = encoder.transform(the_drop2['3_평균구매시간_cat'])

# %%
the_drop2
# Out:
#         고객번호  1_평균구매시간_cat  2_평균구매시간_cat  3_평균구매시간_cat
# 0          1             0             0             0
# 1          2             0             0             0
# 2          3             0             0             0
# 3          4             0             0             0
# 4          5             0             0             0
# ...      ...           ...           ...           ...
# 19142  19356             0             0             0
# 19143  19357             1             1             1
# 19144  19359             0             0             0
# 19145  19360             1             1             1
# 19146  19364             1             1             1
#
# [19147 rows x 4 columns]

# %%
ddf = pd.merge(the_new_df11_1,the_drop2,on='고객번호',how='left')
ddf
# Out:
#         고객번호  성별  연령대  ...  1_평균구매시간_cat  2_평균구매시간_cat  3_평균구매시간_cat
# 0          1   1    5  ...             0             0             0
# 1          2   1    5  ...             0             0             0
# 2          3   1    5  ...             0             0             0
# 3          4   0    5  ...             0             0             0
# 4          5   1    5  ...             0             0             0
# ...      ...  ..  ...  ...           ...           ...           ...
# 19142  19356   0    3  ...             0             0             0
# 19143  19357   0    3  ...             1             1             1
# 19144  19359   1    4  ...             0             0             0
# 19145  19360   0    3  ...             1             1             1
# 19146  19364   0    1  ...             1             1             1
#
# [19147 rows x 36 columns]

# %%
ddf
# Out:
#         고객번호  성별  연령대  ...  1_평균구매시간_cat  2_평균구매시간_cat  3_평균구매시간_cat
# 0          1   1    5  ...             0             0             0
# 1          2   1    5  ...             0             0             0
# 2          3   1    5  ...             0             0             0
# 3          4   0    5  ...             0             0             0
# 4          5   1    5  ...             0             0             0
# ...      ...  ..  ...  ...           ...           ...           ...
# 19142  19356   0    3  ...             0             0             0
# 19143  19357   0    3  ...             1             1             1
# 19144  19359   1    4  ...             0             0             0
# 19145  19360   0    3  ...             1             1             1
# 19146  19364   0    1  ...             1             1             1
#
# [19147 rows x 36 columns]

# %%
ddf.corr()
# Out:
#                          고객번호        성별  ...  2_평균구매시간_cat  3_평균구매시간_cat
# 고객번호                 1.000000  0.060889  ...      0.089087      0.086324
# 성별                   0.060889  1.000000  ...     -0.018372     -0.009855
# 연령대                 -0.382660 -0.040771  ...     -0.003522      0.004879
# 1P                  -0.034264 -0.005205  ...     -0.008794     -0.011213
# 2P                  -0.022348 -0.005386  ...     -0.026791     -0.009766
# 3P                   0.004356  0.013259  ...     -0.000120     -0.014811
# 1P_sort_de           0.053525  0.000741  ...      0.023829      0.016650
# 2P_sort_de          -0.003859 -0.003575  ...     -0.038243     -0.020746
# 3P_sort_de           0.009568 -0.004671  ...      0.003329     -0.002649
# 1D_가구/가전/전자기기_rank   0.010558 -0.000793  ...     -0.003515     -0.003567
# 2D_가구/가전/전자기기_rank   0.003082  0.003900  ...      0.008819      0.008054
# 3D_가구/가전/전자기기_rank  -0.007463 -0.010279  ...     -0.007738     -0.009613
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')

def modeling(data,model):

  y = data[['3P']]
  x = data.drop(['고객번호','3P','3D_가구/가전/전자기기_rank','3D_기타_rank','3D_반려/취미/문구/도서_rank','3D_생활/건강_rank','3D_스포츠/레저/자동차_rank','3D_식품_rank','3D_의류/잡화_rank','3D_출산유아동_rank','3P_sort_de'],axis=1)

  scaler = StandardScaler()

  new_x = scaler.fit_transform(x)

  X_train, X_test, y_train, y_test = train_test_split(new_x,y,test_size=0.2,random_state=0)


  if model == 'rf':  
    rf_clf = RandomForestClassifier()
    rf_clf.fit(X_train,y_train)
    rf_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test,rf_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'lr':
    lr_clf = LogisticRegression()
    lr_clf.fit(X_train,y_train)
    lr_pred = lr_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lr_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'xgb':
    xgb_clf = XGBClassifier()
    evals = [(X_test,y_test)]
    xgb_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    xgb_pred = xgb_clf.predict(X_test)
    accuracy = accuracy_score(y_test,xgb_pred)
    print(model,'정확도 : ',round(accuracy,2))
  elif model == 'lgbm':
    lgbm_clf = LGBMClassifier()
    evals = [(X_test,y_test)]
    lgbm_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    lgbm_pred = lgbm_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lgbm_pred)
    print(model,'정확도 : ',round(accuracy,2))

# %%
li = ['lr','rf','xgb','lgbm']
for i in li:
  modeling(ddf,i)
# Out:
# lr 정확도 :  0.61
# rf 정확도 :  0.59
# xgb 정확도 :  0.61
# lgbm 정확도 :  0.61

# %%
cust_good=pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/dataset_유지고객_증감여부_1006.csv',encoding='cp949',index_col=0)
cust_good
# Out:
#         고객번호      구매금액   14년 1분기   14년 2분기  ...   15년 상반기   15년 하반기      증감 여부  증감
# 0          1  85042550   9141590  10783765  ...  17898365  13102518  -0.342420  감소
# 1          2  99880760  14123470  10199760  ...  27791610  25843820   0.062516  증가
# 2          3   3165167    302782    548433  ...    592280    679118  -0.202178  감소
# 3          4  16693810   1309643   3732463  ...   3656937   3737257  -0.258790  감소
# 4          5  13237070   3145330   2314820  ...   2934930   2616260  -0.520845  감소
# ...      ...       ...       ...       ...  ...       ...       ...        ...  ..
# 19355  19356   6245805         0    170160  ...   2104968   2434587  13.307634  증가
# 19356  19357   8664915         0     91950  ...   3044944   2246675  23.433660  증가
# 19358  19359   3259137         0     43190  ...    837240   1092380  24.292429  증가
# 19359  19360   4726290         0    368050  ...   1412140    886060   1.407445  증가
# ...

# %%
cust_good1 = cust_good[['14년 상반기','14년 하반기','15년 상반기','15년 하반기']]
cust_good1
# Out:
#         14년 상반기   14년 하반기   15년 상반기   15년 하반기
# 0      19925355  34116312  17898365  13102518
# 1      24323230  21922100  27791610  25843820
# 2        851215   1042554    592280    679118
# 3       5042106   4257510   3656937   3737257
# 4       5460150   2225730   2934930   2616260
# ...         ...       ...       ...       ...
# 19355    170160   1536090   2104968   2434587
# 19356     91950   3281346   3044944   2246675
# 19358     43190   1286327    837240   1092380
# 19359    368050   2060040   1412140    886060
# 19363   2032420   6743370   3218130   4270200
#
# [19147 rows x 4 columns]

# %%
cust_good1['1P고객평균매출']=(cust_good1['14년 상반기']+cust_good1['14년 하반기'])/2
cust_good1['2P고객평균매출']=(cust_good1['14년 하반기']+cust_good1['15년 상반기'])/2
cust_good1['3P고객평균매출']=(cust_good1['15년 상반기']+cust_good1['15년 하반기'])/2

# %%
cust_good1['1P고객평균매출'].describe()
# Out:
# count    1.914700e+04
# mean     8.594790e+06
# std      1.735247e+07
# min      1.598000e+04
# 25%      2.620112e+06
# 50%      4.232810e+06
# 75%      9.635104e+06
# max      1.051659e+09
# Name: 1P고객평균매출, dtype: float64

# %%
cust_good1
# Out:
#         14년 상반기   14년 하반기   15년 상반기  ...    1P고객평균매출    2P고객평균매출    3P고객평균매출
# 0      19925355  34116312  17898365  ...  27020833.5  26007338.5  15500441.5
# 1      24323230  21922100  27791610  ...  23122665.0  24856855.0  26817715.0
# 2        851215   1042554    592280  ...    946884.5    817417.0    635699.0
# 3       5042106   4257510   3656937  ...   4649808.0   3957223.5   3697097.0
# 4       5460150   2225730   2934930  ...   3842940.0   2580330.0   2775595.0
# ...         ...       ...       ...  ...         ...         ...         ...
# 19355    170160   1536090   2104968  ...    853125.0   1820529.0   2269777.5
# 19356     91950   3281346   3044944  ...   1686648.0   3163145.0   2645809.5
# 19358     43190   1286327    837240  ...    664758.5   1061783.5    964810.0
# 19359    368050   2060040   1412140  ...   1214045.0   1736090.0   1149100.0
# 19363   2032420   6743370   3218130  ...   4387895.0   4980750.0   3744165.0
#
# [19147 rows x 7 columns]

# %%
cust_go =pd.read_excel('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/고객매출2.xlsx',index_col=0)
cust_go
# Out:
#         14년 상반기   14년 하반기   15년 상반기   15년 하반기  ...    3P고객평균매출  1P_등급  2P_등급  3P_등급
# 고객번호                                           ...
# 0      19925355  34116312  17898365  13102518  ...  15500441.5   1017   1183   2923
# 1      24323230  21922100  27791610  25843820  ...  26817715.0   1397   1304   1165
# 2        851215   1042554    592280    679118  ...    635699.0  18738  18920  18970
# 3       5042106   4257510   3656937   3737257  ...   3697097.0   8747  10546  11275
# 4       5460150   2225730   2934930   2616260  ...   2775595.0  10459  15012  14250
# ...         ...       ...       ...       ...  ...         ...    ...    ...    ...
# 19355    170160   1536090   2104968   2434587  ...   2269777.5  18796  17558  16052
# 19356     91950   3281346   3044944   2246675  ...   2645809.5  17486  12918  14693
# 19358     43190   1286327    837240   1092380  ...    964810.0  18904  18782  18795
# 19359    368050   2060040   1412140    886060  ...   1149100.0  18430  17747  18657
# ...

# %%
cust_go.reset_index(inplace=True)

# %%
cust_go
# Out:
#         고객번호   14년 상반기   14년 하반기   15년 상반기  ...    3P고객평균매출  1P_등급  2P_등급  3P_등급
# 0          0  19925355  34116312  17898365  ...  15500441.5   1017   1183   2923
# 1          1  24323230  21922100  27791610  ...  26817715.0   1397   1304   1165
# 2          2    851215   1042554    592280  ...    635699.0  18738  18920  18970
# 3          3   5042106   4257510   3656937  ...   3697097.0   8747  10546  11275
# 4          4   5460150   2225730   2934930  ...   2775595.0  10459  15012  14250
# ...      ...       ...       ...       ...  ...         ...    ...    ...    ...
# 19142  19355    170160   1536090   2104968  ...   2269777.5  18796  17558  16052
# 19143  19356     91950   3281346   3044944  ...   2645809.5  17486  12918  14693
# 19144  19358     43190   1286327    837240  ...    964810.0  18904  18782  18795
# 19145  19359    368050   2060040   1412140  ...   1149100.0  18430  17747  18657
# 19146  19363   2032420   6743370   3218130  ...   3744165.0   9258   8502  11129
#
# ...

# %%
cust_go['1P_등급'].describe()
# Out:
# count    19147.000000
# mean      9573.999530
# std       5527.406899
# min          1.000000
# 25%       4787.500000
# 50%       9574.000000
# 75%      14360.500000
# max      19147.000000
# Name: 1P_등급, dtype: float64

# %%
def cats2(x):
  ''
  a = 1915
  if x< a:
    y=1
  elif x< 2*a:
    y=2
  elif x< 3*a:
    y=3
  elif x< 4*a:
    y=4
  elif x< 5*a:
    y=5
  elif x< 6*a:
    y=6
  elif x< 7*a:
    y=7
  elif x< 8*a:
    y=8
  elif x< 9*a:
    y=9
  else:
    y=10
    ''
  return y

# %%
cust_go['1P고객매출등급'] = cust_go['1P_등급'].apply(lambda x:cats2(x))
cust_go['2P고객매출등급'] = cust_go['2P_등급'].apply(lambda x:cats2(x))
cust_go['3P고객매출등급'] = cust_go['3P_등급'].apply(lambda x:cats2(x))

# %%
cust_go['1P고객매출등급'].value_counts()
# Out:
# 9     1915
# 8     1915
# 7     1915
# 6     1915
# 5     1915
# 4     1915
# 3     1915
# 2     1915
# 1     1914
# 10    1913
# Name: 1P고객매출등급, dtype: int64

# %%
cust_go['고객번호']=cust_go['고객번호']+1

# %%
cust_go
# Out:
#         고객번호   14년 상반기   14년 하반기   15년 상반기  ...  3P_등급  1P고객매출등급  2P고객매출등급  3P고객매출등급
# 0          1  19925355  34116312  17898365  ...   2923         1         1         2
# 1          2  24323230  21922100  27791610  ...   1165         1         1         1
# 2          3    851215   1042554    592280  ...  18970        10        10        10
# 3          4   5042106   4257510   3656937  ...  11275         5         6         6
# 4          5   5460150   2225730   2934930  ...  14250         6         8         8
# ...      ...       ...       ...       ...  ...    ...       ...       ...       ...
# 19142  19356    170160   1536090   2104968  ...  16052        10        10         9
# 19143  19357     91950   3281346   3044944  ...  14693        10         7         8
# 19144  19359     43190   1286327    837240  ...  18795        10        10        10
# 19145  19360    368050   2060040   1412140  ...  18657        10        10        10
# ...

# %%
cust_go2 = cust_go[['고객번호','1P고객매출등급','2P고객매출등급','3P고객매출등급']]
cust_go2
# Out:
#         고객번호  1P고객매출등급  2P고객매출등급  3P고객매출등급
# 0          1         1         1         2
# 1          2         1         1         1
# 2          3        10        10        10
# 3          4         5         6         6
# 4          5         6         8         8
# ...      ...       ...       ...       ...
# 19142  19356        10        10         9
# 19143  19357        10         7         8
# 19144  19359        10        10        10
# 19145  19360        10        10        10
# 19146  19364         5         5         6
#
# [19147 rows x 4 columns]

# %%
ddf2 = pd.merge(ddf,cust_go2,on='고객번호',how = 'left')
ddf2
# Out:
#         고객번호  성별  연령대  1P  ...  3_평균구매시간_cat  1P고객매출등급  2P고객매출등급  3P고객매출등급
# 0          1   1    5   0  ...             0         1         1         2
# 1          2   1    5   1  ...             0         1         1         1
# 2          3   1    5   0  ...             0        10        10        10
# 3          4   0    5   1  ...             0         5         6         6
# 4          5   1    5   1  ...             0         6         8         8
# ...      ...  ..  ...  ..  ...           ...       ...       ...       ...
# 19142  19356   0    3   0  ...             0        10        10         9
# 19143  19357   0    3   0  ...             1        10         7         8
# 19144  19359   1    4   0  ...             0        10        10        10
# 19145  19360   0    3   0  ...             1        10        10        10
# 19146  19364   0    1   0  ...             1         5         5         6
#
# [19147 rows x 39 columns]

# %%
ddf2.drop(columns= ['1_평균구매시간_cat','2_평균구매시간_cat','3_평균구매시간_cat'],inplace=True)

# %%
ddf2
# Out:
#         고객번호  성별  연령대  1P  ...  3D_출산유아동_rank  1P고객매출등급  2P고객매출등급  3P고객매출등급
# 0          1   1    5   0  ...              0         1         1         2
# 1          2   1    5   1  ...             -4         1         1         1
# 2          3   1    5   0  ...              0        10        10        10
# 3          4   0    5   1  ...             -4         5         6         6
# 4          5   1    5   1  ...              0         6         8         8
# ...      ...  ..  ...  ..  ...            ...       ...       ...       ...
# 19142  19356   0    3   0  ...              0        10        10         9
# 19143  19357   0    3   0  ...             -3        10         7         8
# 19144  19359   1    4   0  ...              0        10        10        10
# 19145  19360   0    3   0  ...              0        10        10        10
# 19146  19364   0    1   0  ...             -2         5         5         6
#
# [19147 rows x 36 columns]

# %%
ddf2['1P고객매출등급'].value_counts()
# Out:
# 9     1915
# 8     1915
# 7     1915
# 6     1915
# 5     1915
# 4     1915
# 3     1915
# 2     1915
# 1     1914
# 10    1913
# Name: 1P고객매출등급, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')

def modeling(data,model):

  y = data[['3P']]
  x = data.drop(['3P고객구매갯수등급','3P고객방문등급','3P고객매출등급','고객번호','3P','3D_가구/가전/전자기기_rank','3D_기타_rank','3D_반려/취미/문구/도서_rank','3D_생활/건강_rank','3D_스포츠/레저/자동차_rank','3D_식품_rank','3D_의류/잡화_rank','3D_출산유아동_rank','3P_sort_de'],axis=1)

  scaler = StandardScaler()

  new_x = scaler.fit_transform(x)

  X_train, X_test, y_train, y_test = train_test_split(new_x,y,test_size=0.2,random_state=0)


  if model == 'rf':  
    rf_clf = RandomForestClassifier(random_state=0)
    rf_clf.fit(X_train,y_train)
    rf_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test,rf_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'lr':
    lr_clf = LogisticRegression(random_state=0)
    lr_clf.fit(X_train,y_train)
    lr_pred = lr_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lr_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'xgb':
    xgb_clf = XGBClassifier(random_state=0)
    evals = [(X_test,y_test)]
    xgb_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    xgb_pred = xgb_clf.predict(X_test)
    accuracy = accuracy_score(y_test,xgb_pred)
    print(model,'정확도 : ',round(accuracy,2))
  elif model == 'lgbm':
    lgbm_clf = LGBMClassifier(random_state=0)
    evals = [(X_test,y_test)]
    lgbm_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    lgbm_pred = lgbm_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lgbm_pred)
    print(model,'정확도 : ',round(accuracy,2))

  else :
    print('모델 인자 값을 확인하세요')

# %%
li = ['lr','rf','xgb','lgbm']
for i in li:
  modeling(ddf2,i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-185-eff76c8ba294> in <module>()
#       1 li = ['lr','rf','xgb','lgbm']
#       2 for i in li:
# ----> 3   modeling(ddf2,i)
#
# <ipython-input-184-312b36bc4d0b> in modeling(data, model)
#      13
#      14   y = data[['3P']]
# ---> 15   x = data.drop(['3P고객방문등급','3P고객매출등급','고객번호','3P','3D_가구/가전/전자기기_rank','3D_기타_rank','3D_반려/취미/문구/도서_rank','3D_생활/건강_rank','3D_스포츠/레저/자동차_rank','3D_식품_rank','3D_의류/잡화_rank','3D_출산유아동_rank','3P_sort_de'],axis=1)
#      16
#      17   scaler = StandardScaler()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# ...

# %%
ddf2.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/the_new_ddf',encoding='cp949')

# %%
result_df2 =pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/result_df2.csv',encoding='cp949',index_col=0)
result_df2
# Out:
#         고객번호  성별  연령대  1P  ...  3P고객매출등급  1P_구매횟수_RANK  2P_구매횟수_RANK  3P_구매횟수_RANK
# 0          1   1    5   0  ...         2         10532          9852         13730
# 1          2   1    5   1  ...         1         10232         12350         12829
# 2          3   1    5   0  ...        10          7969         10862         13950
# 3          4   0    5   1  ...         6         13647         14357         13194
# 4          5   1    5   1  ...         8         12210         18373         18601
# ...      ...  ..  ...  ..  ...       ...           ...           ...           ...
# 19142  19356   0    3   0  ...         9         13974          7436          6965
# 19143  19357   0    3   0  ...         8         13759          6444          7801
# 19144  19359   1    4   0  ...        10         11362          5538          8011
# 19145  19360   0    3   0  ...        10         16704         14626         18422
# ...

# %%
result_df2['1P고객방문등급'] = result_df2['1P_구매횟수_RANK'].apply(lambda x:cats2(x))
result_df2['2P고객방문등급'] = result_df2['2P_구매횟수_RANK'].apply(lambda x:cats2(x))
result_df2['3P고객방문등급'] = result_df2['3P_구매횟수_RANK'].apply(lambda x:cats2(x))

# %%
result_df2.drop(['1P_구매횟수_RANK','2P_구매횟수_RANK','3P_구매횟수_RANK'],axis=1,inplace=True)

# %%
result_df2.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/the_new_ver.csv',encoding='cp949')

# %%
import pandas as pd
a = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/the_new_ver.csv',encoding='cp949',index_col=0)
a
# Out:
#         고객번호  성별  연령대  1P  2P  ...  2P고객매출등급  3P고객매출등급  1P고객방문등급  2P고객방문등급  3P고객방문등급
# 0          1   1    5   0   1  ...         1         2         6         6         8
# 1          2   1    5   1   0  ...         1         1         6         7         7
# 2          3   1    5   0   1  ...        10        10         5         6         8
# 3          4   0    5   1   1  ...         6         6         8         8         7
# 4          5   1    5   1   0  ...         8         8         7        10        10
# ...      ...  ..  ...  ..  ..  ...       ...       ...       ...       ...       ...
# 19142  19356   0    3   0   0  ...        10         9         8         4         4
# 19143  19357   0    3   0   1  ...         7         8         8         4         5
# 19144  19359   1    4   0   1  ...        10        10         6         3         5
# 19145  19360   0    3   0   1  ...        10        10         9         8        10
# ...

# %%
li = ['lr','rf','xgb','lgbm']
for i in li:
  modeling(result_df2,i)
# Out:
# lr 정확도 :  0.63
# rf 정확도 :  0.61
# xgb 정확도 :  0.63
# lgbm 정확도 :  0.62

# %%
rank_over = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/rettt.csv',encoding='cp949',index_col=0)
rank_over.reset_index(inplace=True)
rank_over
# Out:
#         고객번호  1_구매갯수  2_구매갯수  3_구매갯수  4_구매갯수
# 0      17218    4773    5996    2631    3733
# 1      17674    6480    7807   10336    9235
# 2      14388    6500   11884   18112   18366
# 3      15773    3781    6569    3776    3777
# 4      17829    4370    4025    3526    3137
# ...      ...     ...     ...     ...     ...
# 19142  12669   14341   15685   16422   18487
# 19143   1074   18667   19121   19069   19034
# 19144  17017    5369    8855   11632   11507
# 19145  12136   18995   19035   19133   19010
# 19146   7812   19136   19112   19142   19080
#
# [19147 rows x 5 columns]

# %%
rank_over['1P고객구매갯수등급'] = rank_over['1_구매갯수'].apply(lambda x:cats2(x))
rank_over['2P고객구매갯수등급'] = rank_over['2_구매갯수'].apply(lambda x:cats2(x))
rank_over['3P고객구매갯수등급'] = rank_over['3_구매갯수'].apply(lambda x:cats2(x))

# %%
rank_over2 = rank_over[['고객번호','1P고객구매갯수등급','2P고객구매갯수등급','3P고객구매갯수등급']]
rank_over2
# Out:
#         고객번호  1P고객구매갯수등급  2P고객구매갯수등급  3P고객구매갯수등급
# 0      17218           3           4           2
# 1      17674           4           5           6
# 2      14388           4           7          10
# 3      15773           2           4           2
# 4      17829           3           3           2
# ...      ...         ...         ...         ...
# 19142  12669           8           9           9
# 19143   1074          10          10          10
# 19144  17017           3           5           7
# 19145  12136          10          10          10
# 19146   7812          10          10          10
#
# [19147 rows x 4 columns]

# %%
rank_v = pd.merge(a,rank_over2,on='고객번호',how='left')
rank_v
# Out:
#         고객번호  성별  연령대  1P  ...  3P고객방문등급  1P고객구매갯수등급  2P고객구매갯수등급  3P고객구매갯수등급
# 0          1   1    5   0  ...         8           7           5           6
# 1          2   1    5   1  ...         7           5           7           7
# 2          3   1    5   0  ...         8           5           4           8
# 3          4   0    5   1  ...         7           6           9           7
# 4          5   1    5   1  ...        10           4          10          10
# ...      ...  ..  ...  ..  ...       ...         ...         ...         ...
# 19142  19356   0    3   0  ...         4          10           5           4
# 19143  19357   0    3   0  ...         5          10           4           4
# 19144  19359   1    4   0  ...         5          10           3           4
# 19145  19360   0    3   0  ...        10          10           7           9
# 19146  19364   0    1   0  ...         8          10           7           7
#
# [19147 rows x 42 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')

def modeling(data,model):
  y = data[['3P']]
  x = data.drop(['3P_방문횟수_RANK','3P_매출등급_RANK','고객번호','3P','3D_가구/가전/전자기기_rank','3D_기타_rank','3D_반려/취미/문구/도서_rank','3D_생활/건강_rank','3D_스포츠/레저/자동차_rank','3D_식품_rank','3D_의류/잡화_rank','3D_출산유아동_rank','3P_sort_de'],axis=1)

  scaler = StandardScaler()

  new_x = scaler.fit_transform(x)

  X_train, X_test, y_train, y_test = train_test_split(new_x,y,test_size=0.2,random_state=0)


  if model == 'rf':  
    rf_clf = RandomForestClassifier(random_state=0)
    rf_clf.fit(X_train,y_train)
    rf_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test,rf_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'lr':
    lr_clf = LogisticRegression(random_state=0)
    lr_clf.fit(X_train,y_train)
    lr_pred = lr_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lr_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'xgb':
    xgb_clf = XGBClassifier(random_state=0)
    evals = [(X_test,y_test)]
    xgb_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    xgb_pred = xgb_clf.predict(X_test)
    accuracy = accuracy_score(y_test,xgb_pred)
    print(model,'정확도 : ',round(accuracy,2))
  elif model == 'lgbm':
    lgbm_clf = LGBMClassifier(random_state=0)
    evals = [(X_test,y_test)]
    lgbm_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    lgbm_pred = lgbm_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lgbm_pred)
    print(model,'정확도 : ',round(accuracy,2))

  else :
    print('모델 인자 값을 확인하세요')

# %%
li = ['lr','rf','xgb','lgbm']
for i in li:
  modeling(aaa,i)
# Out:
# lr 정확도 :  0.62
# rf 정확도 :  0.6
# xgb 정확도 :  0.62
# lgbm 정확도 :  0.62

# %%
x = rank_v.drop(['3P고객구매갯수등급','3P고객방문등급','3P고객매출등급','고객번호','3P','3D_가구/가전/전자기기_rank','3D_기타_rank','3D_반려/취미/문구/도서_rank','3D_생활/건강_rank','3D_스포츠/레저/자동차_rank','3D_식품_rank','3D_의류/잡화_rank','3D_출산유아동_rank','3P_sort_de'],axis=1)
x
# Out:
#        성별  연령대  1P  2P  ...  1P고객방문등급  2P고객방문등급  1P고객구매갯수등급  2P고객구매갯수등급
# 0       1    5   0   1  ...         6         6           7           5
# 1       1    5   1   0  ...         6         7           5           7
# 2       1    5   0   1  ...         5         6           5           4
# 3       0    5   1   1  ...         8         8           6           9
# 4       1    5   1   0  ...         7        10           4          10
# ...    ..  ...  ..  ..  ...       ...       ...         ...         ...
# 19142   0    3   0   0  ...         8         4          10           5
# 19143   0    3   0   1  ...         8         4          10           4
# 19144   1    4   0   1  ...         6         3          10           3
# 19145   0    3   0   1  ...         9         8          10           7
# 19146   0    1   0   1  ...         9         7          10           7
#
# [19147 rows x 28 columns]

# %%
import seaborn as sns
import pandas as pd

# VIF기능을 제공하는 라이브러리 불러오기
from statsmodels.stats.outliers_influence import variance_inflation_factor


# 범주형 변수 제거(type)
#x.drop(['1P고객구매갯수등급','2P고객구매갯수등급','1P고객방문등급','2P고객방문등급'],inplace = True,axis=1)

vif = []



# values atribution(속성) 이용해 train 데이터의 값만 추출

train_val = aaa.values



#  variance_inflation_factor 함수에 인자로 train_val (train 데이터의 값)과 인덱스 번호 지정  

# for문 이용

for i in range(len(aaa.columns)):
  vif.append(variance_inflation_factor(aaa.values, i))

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def vif(data):

  vif = []

  data_val = data.values

  for i in range(len(data.columns)):
    vif.append(variance_inflation_factor(data_val, i))

  vif_dataframe = pd.DataFrame()
  vif_dataframe['columns'] = data.columns
  vif_dataframe['VIF'] = vif
  return vif_dataframe

# %%
aa22 = aaa.drop(columns = ['고객번호','3P'])

# %%
vif(aa22)
# Out:
#                 columns       VIF
# 0                    성별  1.194120
# 1                   연령대  4.301476
# 2                    1P  3.364170
# 3                    2P  3.946387
# 4            1P_sort_de  1.921471
# 5            2P_sort_de  1.985000
# 6            3P_sort_de  1.716801
# 7    1D_가구/가전/전자기기_rank  1.292457
# 8    2D_가구/가전/전자기기_rank  1.479858
# 9    3D_가구/가전/전자기기_rank  1.277653
# 10           1D_기타_rank  1.265790
# 11           2D_기타_rank  1.408185
# 12           3D_기타_rank  1.241812
# 13  1D_반려/취미/문구/도서_rank  1.193238
# 14  2D_반려/취미/문구/도서_rank  1.256312
# 15  3D_반려/취미/문구/도서_rank  1.167097
# 16        1D_생활/건강_rank  1.337512
# 17        2D_생활/건강_rank  1.550388
# 18        3D_생활/건강_rank  1.339916
# 19   1D_스포츠/레저/자동차_rank  1.258999
# 20   2D_스포츠/레저/자동차_rank  1.447747
# 21   3D_스포츠/레저/자동차_rank  1.222456
# 22           1D_식품_rank  1.990132
# 23           2D_식품_rank  2.128142
# 24           3D_식품_rank  1.850457
# 25        1D_의류/잡화_rank  1.747420
# ...

# %%
b = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/end.csv',encoding='cp949',index_col=0)
b.reset_index(inplace=True)
b
# Out:
#         고객번호  14년 상반기_RANK  14년 하반기_RANK  ...  구매횟수_2_RANK  구매횟수_3_RANK  구매횟수_4_RANK
# 0          1          1733           684  ...         8831        10796        16802
# 1          2          1225          1659  ...        11884        12592        12772
# 2          3         18509         18679  ...         7639        14255        13320
# 3          4          7745          9679  ...        16095        12517        13600
# 4          5          7209         15910  ...        17831        18159        18470
# ...      ...           ...           ...  ...          ...          ...          ...
# 19142  19356         19008         17922  ...         7981         6916         7033
# 19143  19357         19073         12284  ...         6569         6377         9339
# 19144  19359         19115         18384  ...         3911         7590         8439
# 19145  19360         18882         16481  ...        11884        17227        18586
# ...

# %%
import pandas as pd
a = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/the_new_ver.csv',encoding='cp949',index_col=0)
a
# Out:
#         고객번호  성별  연령대  1P  2P  ...  2P고객매출등급  3P고객매출등급  1P고객방문등급  2P고객방문등급  3P고객방문등급
# 0          1   1    5   0   1  ...         1         2         6         6         8
# 1          2   1    5   1   0  ...         1         1         6         7         7
# 2          3   1    5   0   1  ...        10        10         5         6         8
# 3          4   0    5   1   1  ...         6         6         8         8         7
# 4          5   1    5   1   0  ...         8         8         7        10        10
# ...      ...  ..  ...  ..  ..  ...       ...       ...       ...       ...       ...
# 19142  19356   0    3   0   0  ...        10         9         8         4         4
# 19143  19357   0    3   0   1  ...         7         8         8         4         5
# 19144  19359   1    4   0   1  ...        10        10         6         3         5
# 19145  19360   0    3   0   1  ...        10        10         9         8        10
# ...

# %%
a.columns
# Out:
# Index(['고객번호', '성별', '연령대', '1P', '2P', '3P', '1P_sort_de', '2P_sort_de',
#        '3P_sort_de', '1D_가구/가전/전자기기_rank', '2D_가구/가전/전자기기_rank',
#        '3D_가구/가전/전자기기_rank', '1D_기타_rank', '2D_기타_rank', '3D_기타_rank',
#        '1D_반려/취미/문구/도서_rank', '2D_반려/취미/문구/도서_rank', '3D_반려/취미/문구/도서_rank',
#        '1D_생활/건강_rank', '2D_생활/건강_rank', '3D_생활/건강_rank', '1D_스포츠/레저/자동차_rank',
#        '2D_스포츠/레저/자동차_rank', '3D_스포츠/레저/자동차_rank', '1D_식품_rank', '2D_식품_rank',
#        '3D_식품_rank', '1D_의류/잡화_rank', '2D_의류/잡화_rank', '3D_의류/잡화_rank',
#        '1D_출산유아동_rank', '2D_출산유아동_rank', '3D_출산유아동_rank', '1P고객매출등급',
#        '2P고객매출등급', '3P고객매출등급', '1P고객방문등급', '2P고객방문등급', '3P고객방문등급'],
#       dtype='object')

# %%
a2 = a[['고객번호', '성별', '연령대', '1P', '2P', '3P', '1P_sort_de', '2P_sort_de',
       '3P_sort_de', '1D_가구/가전/전자기기_rank', '2D_가구/가전/전자기기_rank',
       '3D_가구/가전/전자기기_rank', '1D_기타_rank', '2D_기타_rank', '3D_기타_rank',
       '1D_반려/취미/문구/도서_rank', '2D_반려/취미/문구/도서_rank', '3D_반려/취미/문구/도서_rank',
       '1D_생활/건강_rank', '2D_생활/건강_rank', '3D_생활/건강_rank', '1D_스포츠/레저/자동차_rank',
       '2D_스포츠/레저/자동차_rank', '3D_스포츠/레저/자동차_rank', '1D_식품_rank', '2D_식품_rank',
       '3D_식품_rank', '1D_의류/잡화_rank', '2D_의류/잡화_rank', '3D_의류/잡화_rank',
       '1D_출산유아동_rank', '2D_출산유아동_rank', '3D_출산유아동_rank']]
a2
# Out:
#         고객번호  성별  연령대  ...  1D_출산유아동_rank  2D_출산유아동_rank  3D_출산유아동_rank
# 0          1   1    5  ...              0              0              0
# 1          2   1    5  ...             -4              4             -4
# 2          3   1    5  ...              0              0              0
# 3          4   0    5  ...              3              4             -4
# 4          5   1    5  ...              0              0              0
# ...      ...  ..  ...  ...            ...            ...            ...
# 19142  19356   0    3  ...              0              0              0
# 19143  19357   0    3  ...              4             -4             -3
# 19144  19359   1    4  ...              0              0              0
# 19145  19360   0    3  ...              0              0              0
# 19146  19364   0    1  ...              4             -4             -2
#
# [19147 rows x 33 columns]

# %%
b['14년 상반기_RANK'] = b['14년 상반기_RANK'].apply(lambda x:cats2(x))
b['15년 상반기_RANK'] = b['15년 상반기_RANK'].apply(lambda x:cats2(x))
b['14년 하반기_RANK'] = b['14년 하반기_RANK'].apply(lambda x:cats2(x))
b['15년 하반기_RANK'] = b['15년 하반기_RANK'].apply(lambda x:cats2(x))
b['1_구매갯수_RANK'] = b['1_구매갯수_RANK'].apply(lambda x:cats2(x))
b['2_구매갯수_RANK'] = b['2_구매갯수_RANK'].apply(lambda x:cats2(x))
b['3_구매갯수_RANK'] = b['3_구매갯수_RANK'].apply(lambda x:cats2(x))
b['4_구매갯수_RANK'] = b['4_구매갯수_RANK'].apply(lambda x:cats2(x))
b['구매횟수_1_RANK'] = b['구매횟수_1_RANK'].apply(lambda x:cats2(x))
b['구매횟수_2_RANK'] = b['구매횟수_2_RANK'].apply(lambda x:cats2(x))
b['구매횟수_3_RANK'] = b['구매횟수_3_RANK'].apply(lambda x:cats2(x))
b['구매횟수_4_RANK'] = b['구매횟수_4_RANK'].apply(lambda x:cats2(x))

# %%
b
# Out:
#         고객번호  14년 상반기_RANK  14년 하반기_RANK  ...  구매횟수_2_RANK  구매횟수_3_RANK  구매횟수_4_RANK
# 0          1             1             1  ...            5            6            9
# 1          2             1             1  ...            7            7            7
# 2          3            10            10  ...            4            8            7
# 3          4             5             6  ...            9            7            8
# 4          5             4             9  ...           10           10           10
# ...      ...           ...           ...  ...          ...          ...          ...
# 19142  19356            10            10  ...            5            4            4
# 19143  19357            10             7  ...            4            4            5
# 19144  19359            10            10  ...            3            4            5
# 19145  19360            10             9  ...            7            9           10
# ...

# %%
b['1P_매출등급_RANK']=b['14년 하반기_RANK']-b['14년 상반기_RANK']
b['2P_매출등급_RANK']=b['15년 상반기_RANK']-b['14년 하반기_RANK']
b['3P_매출등급_RANK']=b['15년 하반기_RANK']-b['15년 상반기_RANK']

b['1P_구매갯수_RANK']=b['2_구매갯수_RANK']-b['1_구매갯수_RANK']
b['2P_구매갯수_RANK']=b['3_구매갯수_RANK']-b['2_구매갯수_RANK']
b['3P_구매갯수_RANK']=b['4_구매갯수_RANK']-b['3_구매갯수_RANK']

b['1P_방문횟수_RANK']=b['구매횟수_2_RANK']-b['구매횟수_1_RANK']
b['2P_방문횟수_RANK']=b['구매횟수_3_RANK']-b['구매횟수_2_RANK']
b['3P_방문횟수_RANK']=b['구매횟수_4_RANK']-b['구매횟수_3_RANK']

# %%
b
# Out:
#         고객번호  14년 상반기_RANK  ...  2P_방문횟수_RANK  3P_방문횟수_RANK
# 0          1             1  ...             1             3
# 1          2             1  ...             0             0
# 2          3            10  ...             4            -1
# 3          4             5  ...            -2             1
# 4          5             4  ...             0             0
# ...      ...           ...  ...           ...           ...
# 19142  19356            10  ...            -1             0
# 19143  19357            10  ...             0             1
# 19144  19359            10  ...             1             1
# 19145  19360            10  ...             2             1
# 19146  19364             9  ...             0             1
#
# [19147 rows x 22 columns]

# %%
b.columns
# Out:
# Index(['고객번호', '14년 상반기_RANK', '14년 하반기_RANK', '15년 상반기_RANK', '15년 하반기_RANK',
#        '1_구매갯수_RANK', '2_구매갯수_RANK', '3_구매갯수_RANK', '4_구매갯수_RANK',
#        '구매횟수_1_RANK', '구매횟수_2_RANK', '구매횟수_3_RANK', '구매횟수_4_RANK',
#        '1P_매출등급_RANK', '2P_매출등급_RANK', '3P_매출등급_RANK', '1P_구매갯수_RANK',
#        '2P_구매갯수_RANK', '3P_구매갯수_RANK', '1P_방문횟수_RANK', '2P_방문횟수_RANK',
#        '3P_방문횟수_RANK'],
#       dtype='object')

# %%
sort2 =b[['고객번호','1P_매출등급_RANK', '2P_매출등급_RANK', '3P_매출등급_RANK','1P_방문횟수_RANK', '2P_방문횟수_RANK',
       '3P_방문횟수_RANK']]

sort2
# Out:
#         고객번호  1P_매출등급_RANK  ...  2P_방문횟수_RANK  3P_방문횟수_RANK
# 0          1             0  ...             1             3
# 1          2             0  ...             0             0
# 2          3             0  ...             4            -1
# 3          4             1  ...            -2             1
# 4          5             5  ...             0             0
# ...      ...           ...  ...           ...           ...
# 19142  19356             0  ...            -1             0
# 19143  19357            -3  ...             0             1
# 19144  19359             0  ...             1             1
# 19145  19360            -1  ...             2             1
# 19146  19364            -5  ...             0             1
#
# [19147 rows x 7 columns]

# %%
aaa = pd.merge(a2, sort2, on='고객번호', how='left')
aaa
# Out:
#         고객번호  성별  연령대  ...  1P_방문횟수_RANK  2P_방문횟수_RANK  3P_방문횟수_RANK
# 0          1   1    5  ...            -2             1             3
# 1          2   1    5  ...             2             0             0
# 2          3   1    5  ...            -1             4            -1
# 3          4   0    5  ...             3            -2             1
# 4          5   1    5  ...             6             0             0
# ...      ...  ..  ...  ...           ...           ...           ...
# 19142  19356   0    3  ...            -5            -1             0
# 19143  19357   0    3  ...            -6             0             1
# 19144  19359   1    4  ...            -7             1             1
# 19145  19360   0    3  ...            -3             2             1
# 19146  19364   0    1  ...            -3             0             1
#
# [19147 rows x 39 columns]

# %%
a33 = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/a12.csv',encoding='cp949',index_col=0)
a33
# Out:
#         고객번호  성별  연령대  ...  1P_방문횟수_RANK  2P_방문횟수_RANK  3P_방문횟수_RANK
# 0          1   1    5  ...            -2             1             3
# 1          2   1    5  ...             2             0             0
# 2          3   1    5  ...            -1             4            -1
# 3          4   0    5  ...             3            -2             1
# 4          5   1    5  ...             6             0             0
# ...      ...  ..  ...  ...           ...           ...           ...
# 19142  19356   0    3  ...            -5            -1             0
# 19143  19357   0    3  ...            -6             0             1
# 19144  19359   1    4  ...            -7             1             1
# 19145  19360   0    3  ...            -3             2             1
# 19146  19364   0    1  ...            -3             0             1
#
# [19147 rows x 39 columns]

# %%
a33.columns
# Out:
# Index(['고객번호', '성별', '연령대', '1P', '2P', '3P', '1P_sort_de', '2P_sort_de',
#        '3P_sort_de', '1D_가구/가전/전자기기_rank', '2D_가구/가전/전자기기_rank',
#        '3D_가구/가전/전자기기_rank', '1D_기타_rank', '2D_기타_rank', '3D_기타_rank',
#        '1D_반려/취미/문구/도서_rank', '2D_반려/취미/문구/도서_rank', '3D_반려/취미/문구/도서_rank',
#        '1D_생활/건강_rank', '2D_생활/건강_rank', '3D_생활/건강_rank', '1D_스포츠/레저/자동차_rank',
#        '2D_스포츠/레저/자동차_rank', '3D_스포츠/레저/자동차_rank', '1D_식품_rank', '2D_식품_rank',
#        '3D_식품_rank', '1D_의류/잡화_rank', '2D_의류/잡화_rank', '3D_의류/잡화_rank',
#        '1D_출산유아동_rank', '2D_출산유아동_rank', '3D_출산유아동_rank', '1P_매출등급_RANK',
#        '2P_매출등급_RANK', '3P_매출등급_RANK', '1P_방문횟수_RANK', '2P_방문횟수_RANK',
#        '3P_방문횟수_RANK'],
#       dtype='object')

# %%
a44 = a33[['고객번호', '성별', '연령대', '1P', '2P', '3P', '1P_sort_de', '2P_sort_de',
       '3P_sort_de','1P_매출등급_RANK',
       '2P_매출등급_RANK', '3P_매출등급_RANK', '1P_방문횟수_RANK', '2P_방문횟수_RANK',
       '3P_방문횟수_RANK']]

# %%
a44
# Out:
#         고객번호  성별  연령대  ...  1P_방문횟수_RANK  2P_방문횟수_RANK  3P_방문횟수_RANK
# 0          1   1    5  ...            -2             1             3
# 1          2   1    5  ...             2             0             0
# 2          3   1    5  ...            -1             4            -1
# 3          4   0    5  ...             3            -2             1
# 4          5   1    5  ...             6             0             0
# ...      ...  ..  ...  ...           ...           ...           ...
# 19142  19356   0    3  ...            -5            -1             0
# 19143  19357   0    3  ...            -6             0             1
# 19144  19359   1    4  ...            -7             1             1
# 19145  19360   0    3  ...            -3             2             1
# 19146  19364   0    1  ...            -3             0             1
#
# [19147 rows x 15 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')

def modeling(data,model):
  y = data[['3P']]
  x = data.drop(['3P_방문횟수_RANK','3P_매출등급_RANK','고객번호','3P','3D_가구/가전/전자기기_rank','3D_기타_rank','3D_반려/취미/문구/도서_rank','3D_생활/건강_rank','3D_스포츠/레저/자동차_rank','3D_식품_rank','3D_의류/잡화_rank','3D_출산유아동_rank','3P_sort_de'],axis=1)

  scaler = StandardScaler()

  new_x = scaler.fit_transform(x)

  X_train, X_test, y_train, y_test = train_test_split(new_x,y,test_size=0.2,random_state=0)


  if model == 'rf':  
    rf_clf = RandomForestClassifier(random_state=0)
    rf_clf.fit(X_train,y_train)
    rf_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test,rf_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'lr':
    lr_clf = LogisticRegression(random_state=0)
    lr_clf.fit(X_train,y_train)
    lr_pred = lr_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lr_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'xgb':
    xgb_clf = XGBClassifier(random_state=0)
    evals = [(X_test,y_test)]
    xgb_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    xgb_pred = xgb_clf.predict(X_test)
    accuracy = accuracy_score(y_test,xgb_pred)
    print(model,'정확도 : ',round(accuracy,2))
  elif model == 'lgbm':
    lgbm_clf = LGBMClassifier(random_state=0)
    evals = [(X_test,y_test)]
    lgbm_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    lgbm_pred = lgbm_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lgbm_pred)
    print(model,'정확도 : ',round(accuracy,2))

  else :
    print('모델 인자 값을 확인하세요')

# %%
li = ['lr','rf','xgb','lgbm']
for i in li:
  modeling(aaa,i)
# Out:
# lr 정확도 :  0.62
# rf 정확도 :  0.6
# xgb 정확도 :  0.62
# lgbm 정확도 :  0.62

# %%
import pandas as pd
get = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1011/sort_rank.csv',encoding='cp949')
get
# Out:
#         고객번호  1P_가구/가전/전자기기  2P_가구/가전/전자기기  ...  2P_출산유아동  3P_출산유아동  4P_출산유아동
# 0          1          14896          19181  ...         1         1         1
# 1          2          18123          16822  ...     13385     18025     13531
# 2          3              1           8747  ...         1         1         1
# 3          4              1          15860  ...      9944     13302         1
# 4          5          12338          14598  ...         1         1         1
# ...      ...            ...            ...  ...       ...       ...       ...
# 19293  19376              1              1  ...         1         1         1
# 19294  19377              1              1  ...         1         1         1
# 19295  19378              1              1  ...         1         1         1
# 19296  19379              1              1  ...         1         1         1
# 19297  19380              1           6481  ...         1         1         1
#
# [19298 rows x 33 columns]

# %%
get

# %%
get['1P_가구/가전/전자기기'].min()

# %%
def cats2(x):
  ''
  a = 7720
  if x== 1:
    y=10
  elif x< 2*a:
    y=9
  elif x< 3*a:
    y=8
  elif x< 4*a:
    y=7
  elif x< 5*a:
    y=6
  elif x< 6*a:
    y=5
  elif x< 7*a:
    y=4
  elif x< 8*a:
    y=3
  elif x< 9*a:
    y=2
  else:
    y=1
    ''
  return y

# %%
end_game.columns
# Out:
# Index(['1P_가구/가전/전자기기', '2P_가구/가전/전자기기', '3P_가구/가전/전자기기', '4P_가구/가전/전자기기',
#        '1P_기타', '2P_기타', '3P_기타', '4P_기타', '1P_반려/취미/문구/도서', '2P_반려/취미/문구/도서',
#        '3P_반려/취미/문구/도서', '4P_반려/취미/문구/도서', '1P_생활/건강', '2P_생활/건강', '3P_생활/건강',
#        '4P_생활/건강', '1P_스포츠/레저/자동차', '2P_스포츠/레저/자동차', '3P_스포츠/레저/자동차',
#        '4P_스포츠/레저/자동차', '1P_식품', '2P_식품', '3P_식품', '4P_식품', '1P_의류/잡화',
#        '2P_의류/잡화', '3P_의류/잡화', '4P_의류/잡화', '1P_출산유아동', '2P_출산유아동', '3P_출산유아동',
#        '4P_출산유아동'],
#       dtype='object')

# %%
get = endless.copy()

# %%
get['1P_가구/가전/전자기기'].max()
# Out:
# 77189

# %%
get['1P_가구/가전/전자기기'] = get['1P_가구/가전/전자기기'].apply(lambda x:cats2(x))
get['2P_가구/가전/전자기기'] = get['2P_가구/가전/전자기기'].apply(lambda x:cats2(x))
get['3P_가구/가전/전자기기'] = get['3P_가구/가전/전자기기'].apply(lambda x:cats2(x))
get['4P_가구/가전/전자기기'] = get['4P_가구/가전/전자기기'].apply(lambda x:cats2(x))

get['1P_기타'] = get['1P_기타'].apply(lambda x:cats2(x))
get['2P_기타'] = get['2P_기타'].apply(lambda x:cats2(x))
get['3P_기타'] = get['3P_기타'].apply(lambda x:cats2(x))
get['4P_기타'] = get['4P_기타'].apply(lambda x:cats2(x))

get['1P_반려/취미/문구/도서'] = get['1P_반려/취미/문구/도서'].apply(lambda x:cats2(x))
get['2P_반려/취미/문구/도서'] = get['2P_반려/취미/문구/도서'].apply(lambda x:cats2(x))
get['3P_반려/취미/문구/도서'] = get['3P_반려/취미/문구/도서'].apply(lambda x:cats2(x))
get['4P_반려/취미/문구/도서'] = get['4P_반려/취미/문구/도서'].apply(lambda x:cats2(x))

get['1P_생활/건강'] = get['1P_생활/건강'].apply(lambda x:cats2(x))
get['2P_생활/건강'] = get['2P_생활/건강'].apply(lambda x:cats2(x))
get['3P_생활/건강'] = get['3P_생활/건강'].apply(lambda x:cats2(x))
get['4P_생활/건강'] = get['4P_생활/건강'].apply(lambda x:cats2(x))

get['1P_스포츠/레저/자동차'] = get['1P_스포츠/레저/자동차'].apply(lambda x:cats2(x))
get['2P_스포츠/레저/자동차'] = get['2P_스포츠/레저/자동차'].apply(lambda x:cats2(x))
get['3P_스포츠/레저/자동차'] = get['3P_스포츠/레저/자동차'].apply(lambda x:cats2(x))
get['4P_스포츠/레저/자동차'] = get['4P_스포츠/레저/자동차'].apply(lambda x:cats2(x))

get['1P_식품'] = get['1P_식품'].apply(lambda x:cats2(x))
get['2P_식품'] = get['2P_식품'].apply(lambda x:cats2(x))
get['3P_식품'] = get['3P_식품'].apply(lambda x:cats2(x))
get['4P_식품'] = get['4P_식품'].apply(lambda x:cats2(x))

get['1P_의류/잡화'] = get['1P_의류/잡화'].apply(lambda x:cats2(x))
get['2P_의류/잡화'] = get['2P_의류/잡화'].apply(lambda x:cats2(x))
get['3P_의류/잡화'] = get['3P_의류/잡화'].apply(lambda x:cats2(x))
get['4P_의류/잡화'] = get['4P_의류/잡화'].apply(lambda x:cats2(x))

get['1P_출산유아동'] = get['1P_출산유아동'].apply(lambda x:cats2(x))
get['2P_출산유아동'] = get['2P_출산유아동'].apply(lambda x:cats2(x))
get['3P_출산유아동'] = get['3P_출산유아동'].apply(lambda x:cats2(x))
get['4P_출산유아동'] = get['4P_출산유아동'].apply(lambda x:cats2(x))

# %%
get.reset_index(inplace=True)

# %%
get['3P_가구/가전/전자기기'].value_counts()
# Out:
# 10    7795
# 6     1911
# 4     1884
# 5     1856
# 1     1821
# 2     1797
# 3     1783
# 7      451
# Name: 3P_가구/가전/전자기기, dtype: int64

# %%
get.columns
# Out:
# Index(['고객번호', '1P_가구/가전/전자기기', '2P_가구/가전/전자기기', '3P_가구/가전/전자기기',
#        '4P_가구/가전/전자기기', '1P_기타', '2P_기타', '3P_기타', '4P_기타', '1P_반려/취미/문구/도서',
#        '2P_반려/취미/문구/도서', '3P_반려/취미/문구/도서', '4P_반려/취미/문구/도서', '1P_생활/건강',
#        '2P_생활/건강', '3P_생활/건강', '4P_생활/건강', '1P_스포츠/레저/자동차', '2P_스포츠/레저/자동차',
#        '3P_스포츠/레저/자동차', '4P_스포츠/레저/자동차', '1P_식품', '2P_식품', '3P_식품', '4P_식품',
#        '1P_의류/잡화', '2P_의류/잡화', '3P_의류/잡화', '4P_의류/잡화', '1P_출산유아동', '2P_출산유아동',
#        '3P_출산유아동', '4P_출산유아동'],
#       dtype='object')

# %%
get['1PP_가구/가전/전자기기']=get['2P_가구/가전/전자기기']-get['1P_가구/가전/전자기기']
get['2PP_가구/가전/전자기기']=get['3P_가구/가전/전자기기']-get['2P_가구/가전/전자기기']
get['3PP_가구/가전/전자기기']=get['4P_가구/가전/전자기기']-get['3P_가구/가전/전자기기']

get['1PP_기타']=get['2P_기타']-get['1P_기타']
get['2PP_기타']=get['3P_기타']-get['2P_기타']
get['3PP_기타']=get['4P_기타']-get['3P_기타']

get['1PP_반려/취미/문구/도서']=get['2P_반려/취미/문구/도서']-get['1P_반려/취미/문구/도서']
get['2PP_반려/취미/문구/도서']=get['3P_반려/취미/문구/도서']-get['2P_반려/취미/문구/도서']
get['3PP_반려/취미/문구/도서']=get['4P_반려/취미/문구/도서']-get['3P_반려/취미/문구/도서']

get['1PP_생활/건강']=get['2P_생활/건강']-get['1P_생활/건강']
get['2PP_생활/건강']=get['3P_생활/건강']-get['2P_생활/건강']
get['3PP_생활/건강']=get['4P_생활/건강']-get['3P_생활/건강']

get['1PP_스포츠/레저/자동차']=get['2P_스포츠/레저/자동차']-get['1P_스포츠/레저/자동차']
get['2PP_스포츠/레저/자동차']=get['3P_스포츠/레저/자동차']-get['2P_스포츠/레저/자동차']
get['3PP_스포츠/레저/자동차']=get['4P_스포츠/레저/자동차']-get['3P_스포츠/레저/자동차']

get['1PP_식품']=get['2P_식품']-get['1P_식품']
get['2PP_식품']=get['3P_식품']-get['2P_식품']
get['3PP_식품']=get['4P_식품']-get['3P_식품']

get['1PP_의류/잡화']=get['2P_의류/잡화']-get['1P_의류/잡화']
get['2PP_의류/잡화']=get['3P_의류/잡화']-get['2P_의류/잡화']
get['3PP_의류/잡화']=get['4P_의류/잡화']-get['3P_의류/잡화']

get['1PP_출산유아동']=get['2P_출산유아동']-get['1P_출산유아동']
get['2PP_출산유아동']=get['3P_출산유아동']-get['2P_출산유아동']
get['3PP_출산유아동']=get['4P_출산유아동']-get['3P_출산유아동']

# %%
get.columns
# Out:
# Index(['고객번호', '1P_가구/가전/전자기기', '2P_가구/가전/전자기기', '3P_가구/가전/전자기기',
#        '4P_가구/가전/전자기기', '1P_기타', '2P_기타', '3P_기타', '4P_기타', '1P_반려/취미/문구/도서',
#        '2P_반려/취미/문구/도서', '3P_반려/취미/문구/도서', '4P_반려/취미/문구/도서', '1P_생활/건강',
#        '2P_생활/건강', '3P_생활/건강', '4P_생활/건강', '1P_스포츠/레저/자동차', '2P_스포츠/레저/자동차',
#        '3P_스포츠/레저/자동차', '4P_스포츠/레저/자동차', '1P_식품', '2P_식품', '3P_식품', '4P_식품',
#        '1P_의류/잡화', '2P_의류/잡화', '3P_의류/잡화', '4P_의류/잡화', '1P_출산유아동', '2P_출산유아동',
#        '3P_출산유아동', '4P_출산유아동', '1PP_가구/가전/전자기기', '2PP_가구/가전/전자기기',
#        '3PP_가구/가전/전자기기', '1PP_기타', '2PP_기타', '1PP_반려/취미/문구/도서',
#        '2PP_반려/취미/문구/도서', '3PP_반려/취미/문구/도서', '1PP_생활/건강', '2PP_생활/건강',
#        '3PP_생활/건강', '1PP_스포츠/레저/자동차', '2PP_스포츠/레저/자동차', '3PP_스포츠/레저/자동차',
#        '1PP_식품', '2PP_식품', '3PP_식품', '1PP_의류/잡화', '2PP_의류/잡화', '3PP_의류/잡화',
#        '1PP_출산유아동', '2PP_출산유아동', '3PP_출산유아동', '3PP_기타'],
#       dtype='object')

# %%
get2 = get[['고객번호','1PP_가구/가전/전자기기', '2PP_가구/가전/전자기기',
       '3PP_가구/가전/전자기기', '1PP_기타', '2PP_기타', '1PP_반려/취미/문구/도서',
       '2PP_반려/취미/문구/도서', '3PP_반려/취미/문구/도서', '1PP_생활/건강', '2PP_생활/건강',
       '3PP_생활/건강', '1PP_스포츠/레저/자동차', '2PP_스포츠/레저/자동차', '3PP_스포츠/레저/자동차',
       '1PP_식품', '2PP_식품', '3PP_식품', '1PP_의류/잡화', '2PP_의류/잡화', '3PP_의류/잡화',
       '1PP_출산유아동', '2PP_출산유아동', '3PP_출산유아동', '3PP_기타']]

# %%
get2
# Out:
#         고객번호  1PP_가구/가전/전자기기  2PP_가구/가전/전자기기  ...  2PP_출산유아동  3PP_출산유아동  3PP_기타
# 0          1               2               0  ...          0          0      -2
# 1          2              -1               1  ...          2         -2       0
# 2          3               5              -5  ...          0          0       0
# 3          4               8              -8  ...          1         -7      -5
# 4          5               2              -8  ...          0          0      -4
# ...      ...             ...             ...  ...        ...        ...     ...
# 19293  19376               0               0  ...          0          0       0
# 19294  19377               0               0  ...          0          0      -1
# 19295  19378               0               0  ...          0          0       0
# 19296  19379               0               0  ...          0          0      -1
# 19297  19380               4               0  ...          0          0       2
#
# ...

# %%
good = pd.merge(a44,get2,on='고객번호',how='left')
good
# Out:
#         고객번호  성별  연령대  1P  ...  1PP_출산유아동  2PP_출산유아동  3PP_출산유아동  3PP_기타
# 0          1   1    5   0  ...          0          0          0      -2
# 1          2   1    5   1  ...         -1          2         -2       0
# 2          3   1    5   0  ...          0          0          0       0
# 3          4   0    5   1  ...          6          1         -7      -5
# 4          5   1    5   1  ...          0          0          0      -4
# ...      ...  ..  ...  ..  ...        ...        ...        ...     ...
# 19142  19356   0    3   0  ...          0          0          0       1
# 19143  19357   0    3   0  ...          8         -1          0       0
# 19144  19359   1    4   0  ...          0          0          0       0
# 19145  19360   0    3   0  ...          0          0          0      -2
# 19146  19364   0    1   0  ...          7         -1          0       0
#
# [19147 rows x 39 columns]

# %%
good.columns
# Out:
# Index(['고객번호', '성별', '연령대', '1P', '2P', '3P', '1P_sort_de', '2P_sort_de',
#        '3P_sort_de', '1P_매출등급_RANK', '2P_매출등급_RANK', '3P_매출등급_RANK',
#        '1P_방문횟수_RANK', '2P_방문횟수_RANK', '3P_방문횟수_RANK', '1PP_가구/가전/전자기기',
#        '2PP_가구/가전/전자기기', '3PP_가구/가전/전자기기', '1PP_기타', '2PP_기타',
#        '1PP_반려/취미/문구/도서', '2PP_반려/취미/문구/도서', '3PP_반려/취미/문구/도서', '1PP_생활/건강',
#        '2PP_생활/건강', '3PP_생활/건강', '1PP_스포츠/레저/자동차', '2PP_스포츠/레저/자동차',
#        '3PP_스포츠/레저/자동차', '1PP_식품', '2PP_식품', '3PP_식품', '1PP_의류/잡화',
#        '2PP_의류/잡화', '3PP_의류/잡화', '1PP_출산유아동', '2PP_출산유아동', '3PP_출산유아동',
#        '3PP_기타'],
#       dtype='object')

# %%
good.to_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1012/good_o2nam.csv',encoding='cp949')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import warnings

warnings.filterwarnings('ignore')

def modeling(data,model):
  y = data[['3P']]
  x = data.drop(['고객번호','3P','3P_매출등급_RANK','3P_sort_de','3P_방문횟수_RANK','3PP_가구/가전/전자기기','3PP_가구/가전/전자기기','3PP_반려/취미/문구/도서','3PP_생활/건강','3PP_스포츠/레저/자동차','3PP_식품','3PP_의류/잡화','3PP_출산유아동','3PP_기타'],axis=1)

  scaler = StandardScaler()

  new_x = scaler.fit_transform(x)

  X_train, X_test, y_train, y_test = train_test_split(new_x,y,test_size=0.2,random_state=0)


  if model == 'rf':  
    rf_clf = RandomForestClassifier(random_state=0)
    rf_clf.fit(X_train,y_train)
    rf_pred = rf_clf.predict(X_test)
    accuracy = accuracy_score(y_test,rf_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'lr':
    lr_clf = LogisticRegression(random_state=0)
    lr_clf.fit(X_train,y_train)
    lr_pred = lr_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lr_pred)
    print(model,'정확도 : ',round(accuracy,2))

  elif model == 'xgb':
    xgb_clf = XGBClassifier(random_state=0)
    evals = [(X_test,y_test)]
    xgb_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    xgb_pred = xgb_clf.predict(X_test)
    accuracy = accuracy_score(y_test,xgb_pred)
    print(model,'정확도 : ',round(accuracy,2))
  elif model == 'lgbm':
    lgbm_clf = LGBMClassifier(random_state=0)
    evals = [(X_test,y_test)]
    lgbm_clf.fit(X_train,y_train,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=False)
    lgbm_pred = lgbm_clf.predict(X_test)
    accuracy = accuracy_score(y_test,lgbm_pred)
    print(model,'정확도 : ',round(accuracy,2))

  else :
    print('모델 인자 값을 확인하세요')

# %%
li = ['lr','rf','xgb','lgbm']
for i in li:
  modeling(good,i)
# Out:
# lr 정확도 :  0.61
# rf 정확도 :  0.62
# xgb 정확도 :  0.61
# lgbm 정확도 :  0.61

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def vif(data):
  vif = []
  data_val = data.values
  for i in range(len(data.columns)):
    vif.append(variance_inflation_factor(data_val, i))
  vif_dataframe = pd.DataFrame()
  vif_dataframe['columns'] = data.columns
  vif_dataframe['VIF'] = vif
  return vif_dataframe

# %%
good2=good.drop(columns = ['고객번호','3P','3P_sort_de','3P_매출등급_RANK','','','','','','','','','','','',])

# %%
vif(good)
# Out:
#             columns       VIF
# 0              고객번호  3.006361
# 1                성별  1.215091
# 2               연령대  4.940879
# 3                1P  2.968321
# 4                2P  3.433358
# 5                3P  3.444795
# 6        1P_sort_de  2.118205
# 7        2P_sort_de  2.160886
# 8        3P_sort_de  1.904909
# 9      1P_매출등급_RANK  3.323309
# 10     2P_매출등급_RANK  3.978529
# 11     3P_매출등급_RANK  3.341824
# 12     1P_방문횟수_RANK  2.667749
# 13     2P_방문횟수_RANK  3.109694
# 14     3P_방문횟수_RANK  2.544100
# 15   1PP_가구/가전/전자기기  1.319779
# 16   2PP_가구/가전/전자기기  1.881548
# 17   3PP_가구/가전/전자기기  1.707249
# 18           1PP_기타  1.449923
# 19           2PP_기타  1.733565
# 20  1PP_반려/취미/문구/도서  1.329707
# 21  2PP_반려/취미/문구/도서  1.674285
# 22  3PP_반려/취미/문구/도서  1.424111
# 23        1PP_생활/건강  1.576534
# 24        2PP_생활/건강  1.969692
# 25        3PP_생활/건강  1.556487
# 26   1PP_스포츠/레저/자동차  1.411430
# 27   2PP_스포츠/레저/자동차  1.832374
# 28   3PP_스포츠/레저/자동차  1.526190
# 29           1PP_식품  2.476839
# ...

# %%
import pandas as pd
end_game =pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1012/end_game.csv',encoding='cp949',index_col=0)
end_game
# Out:
#        1P_가구/가전/전자기기  2P_가구/가전/전자기기  ...  3P_출산유아동  4P_출산유아동
# 고객번호                                 ...
# 1              59004          76711  ...         1         1
# 2              72161          68011  ...     71970     52440
# 3                  1          41288  ...         1         1
# 4                  1          64764  ...     52113         1
# 5              47362          60400  ...         1         1
# ...              ...            ...  ...       ...       ...
# 19376              1              1  ...         1         1
# 19377              1              1  ...         1         1
# 19378              1              1  ...         1         1
# 19379              1              1  ...         1         1
# 19380              1          33578  ...         1         1
#
# [19298 rows x 32 columns]

# %%
endless = pd.read_csv('/content/drive/MyDrive/LMEMBERS 프로젝트(1차)/dataset/1012/end_game_rank.csv',encoding='cp949',index_col=0)
endless
# Out:
#         고객번호  1P_가구/가전/전자기기  2P_가구/가전/전자기기  ...  2P_출산유아동  3P_출산유아동  4P_출산유아동
# 0          1              8             10  ...         1         1         1
# 1          2             10              9  ...         8        10         8
# 2          3              1              6  ...         1         1         1
# 3          4              1              9  ...         7         8         1
# 4          5              7              9  ...         1         1         1
# ...      ...            ...            ...  ...       ...       ...       ...
# 19293  19376              1              1  ...         1         1         1
# 19294  19377              1              1  ...         1         1         1
# 19295  19378              1              1  ...         1         1         1
# 19296  19379              1              1  ...         1         1         1
# 19297  19380              1              5  ...         1         1         1
#
# [19298 rows x 33 columns]

# %%
endless['4P_가구/가전/전자기기'].value_counts()
# Out:
# 1     7780
# 10    2149
# 7     2053
# 6     2031
# 9     2015
# 8     1989
# 5     1281
# Name: 4P_가구/가전/전자기기, dtype: int64
